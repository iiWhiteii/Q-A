# %%
import requests
import os
from datasets import load_dataset
import pandas as pd
import json 

dataset = load_dataset("PatronusAI/financebench")
df = dataset['train'].to_pandas()

# %%
finetuning_data = df.rename(columns = {'question':'instruction', 'answer':'output', 'evidence_text': 'input'})

# %%
finetuning_data = finetuning_data[['instruction', 'input', 'output']]

# %%
finetuning_data
# Out:
#                                            instruction  \
# 0    What is the FY2018 capital expenditure amount ...
# 1    Assume that you are a public equities analyst....
# 2    Is 3M a capital-intensive business based on FY...
# 3    What drove operating margin change as of FY202...
# 4    If we exclude the impact of M&A, which segment...
# ..                                                 ...
# 145  Is Verizon a capital intensive business based ...
# 146  Has Verizon increased its debt on balance shee...
# 147  What is FY2018 days payable outstanding (DPO) ...
# 148  Based on the information provided primarily in...
# 149  What is the FY2018 - FY2020 3 year average una...
#
#                                                  input  \
# 0    Table of Contents \n3M Company and Subsidiarie...
# 1    Table of Contents \n3M Company and Subsidiarie...
# 2    3M Company and Subsidiaries\n Consolidated Sta...
# 3    SG&A, measured as a percent of sales, increase...
# 4    Worldwide Sales Change\nBy Business Segment Or...
# ..                                                 ...
# 145  Consolidated Balance Sheets \nVerizon Communic...
# 146  At December 31, Maturities \nInterest \nRates ...
# 147  Walmart Inc.\nConsolidated Statements of Incom...
# 148  Walmart�Inc.\nConsolidated�Statements�of�Incom...
# 149  Walmart Inc.\nConsolidated Statements of Incom...
#
#                                                 output
# 0                                             $1577.00
# 1                                                $8.70
# 2    No, the company is managing its CAPEX and Fixe...
# 3    Operating Margin for 3M in FY2022 has decrease...
# 4     The consumer segment shrunk by 0.9% organically.
# ..                                                 ...
# 145  Yes. Verizon's capital intensity ratio was app...
# 146      No. Verizon's debt decreased by $229 million.
# 147                                              42.69
# 148                                               0.2%
# 149                                               6.2%
#
# [150 rows x 3 columns]

# %%
text_col = []
for _,row in finetuning_data.iterrows():
    prompt = "You are a financial chatbot trained to answer questions based on the information provided in 10-K documents. Your responses should be directly sourced from the content of these documents. When asked a question, ensure that your answer is explicitly supported by the text in the 10-K filing, and do not include any external information, interpretations, or assumptions not clearly stated in the document. If a question pertains to financial data or analysis that is not explicitly covered in the 10-K filing provided, respond by stating that the information is not available in the document. Your primary focus should be on accuracy, specificity, and adherence to the information in 10-K documents, particularly regarding financial statements, company performance, and market positions.\n"
    instruction = str(row["instruction"])
    input_query = str(row['input'])
    response = str(row['output'])
    
    text = prompt + "### Instruction:\n" +  instruction + "\n### Input: \n" + input_query + "\n### Response: \n " + response
    
    text_col.append(text)

# %%
finetuning_data.loc[:,'text'] = text_col
finetuning_data
# Out:
#                                            instruction  \
# 0    What is the FY2018 capital expenditure amount ...
# 1    Assume that you are a public equities analyst....
# 2    Is 3M a capital-intensive business based on FY...
# 3    What drove operating margin change as of FY202...
# 4    If we exclude the impact of M&A, which segment...
# ..                                                 ...
# 145  Is Verizon a capital intensive business based ...
# 146  Has Verizon increased its debt on balance shee...
# 147  What is FY2018 days payable outstanding (DPO) ...
# 148  Based on the information provided primarily in...
# 149  What is the FY2018 - FY2020 3 year average una...
#
#                                                  input  \
# 0    Table of Contents \n3M Company and Subsidiarie...
# 1    Table of Contents \n3M Company and Subsidiarie...
# 2    3M Company and Subsidiaries\n Consolidated Sta...
# 3    SG&A, measured as a percent of sales, increase...
# 4    Worldwide Sales Change\nBy Business Segment Or...
# ..                                                 ...
# 145  Consolidated Balance Sheets \nVerizon Communic...
# 146  At December 31, Maturities \nInterest \nRates ...
# 147  Walmart Inc.\nConsolidated Statements of Incom...
# 148  Walmart�Inc.\nConsolidated�Statements�of�Incom...
# 149  Walmart Inc.\nConsolidated Statements of Incom...
#
#                                                 output  \
# 0                                             $1577.00
# 1                                                $8.70
# 2    No, the company is managing its CAPEX and Fixe...
# 3    Operating Margin for 3M in FY2022 has decrease...
# 4     The consumer segment shrunk by 0.9% organically.
# ..                                                 ...
# 145  Yes. Verizon's capital intensity ratio was app...
# 146      No. Verizon's debt decreased by $229 million.
# 147                                              42.69
# 148                                               0.2%
# 149                                               6.2%
#
#                                                   text
# 0    You are a financial chatbot trained to answer ...
# 1    You are a financial chatbot trained to answer ...
# 2    You are a financial chatbot trained to answer ...
# 3    You are a financial chatbot trained to answer ...
# 4    You are a financial chatbot trained to answer ...
# ..                                                 ...
# 145  You are a financial chatbot trained to answer ...
# 146  You are a financial chatbot trained to answer ...
# 147  You are a financial chatbot trained to answer ...
# 148  You are a financial chatbot trained to answer ...
# 149  You are a financial chatbot trained to answer ...
#
# [150 rows x 4 columns]

# %%
finetuning_data.to_csv("train.csv", index = False)

# %%
# !autotrain llm --train Anote_benchmarking finetuned_model --model meta-llama/Llama-2-7b-hf --data_path . --use-peft --use-4bit --learning_rate 2e-4 --train_batch_size 4 --num_train_epochs 3 --trainer sft
# Out:
# 'autotrain' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !pip install autotrain-advanced
# Out:
# Requirement already satisfied: autotrain-advanced in c:\users\spurt\appdata\roaming\python\python39\site-packages (0.6.79)
# Requirement already satisfied: albumentations==1.3.1 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from autotrain-advanced) (1.3.1)
# Requirement already satisfied: codecarbon==2.2.3 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from autotrain-advanced) (2.2.3)
# Requirement already satisfied: datasets[vision]~=2.14.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from autotrain-advanced) (2.14.5)
# Requirement already satisfied: evaluate==0.3.0 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from autotrain-advanced) (0.3.0)
# Requirement already satisfied: ipadic==1.0.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from autotrain-advanced) (1.0.0)
# Requirement already satisfied: jiwer==3.0.2 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from autotrain-advanced) (3.0.2)
# Requirement already satisfied: joblib==1.3.1 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from autotrain-advanced) (1.3.1)
# Requirement already satisfied: loguru==0.7.0 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from autotrain-advanced) (0.7.0)
# Requirement already satisfied: pandas>=1.4 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from autotrain-advanced) (2.1.1)
# Requirement already satisfied: nltk==3.8.1 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from autotrain-advanced) (3.8.1)
# Requirement already satisfied: optuna==3.3.0 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from autotrain-advanced) (3.3.0)
# Requirement already satisfied: Pillow==10.0.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from autotrain-advanced) (10.0.0)
# Requirement already satisfied: protobuf==4.23.4 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from autotrain-advanced) (4.23.4)
# Requirement already satisfied: sacremoses==0.0.53 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from autotrain-advanced) (0.0.53)
# Requirement already satisfied: scikit-learn==1.3.0 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from autotrain-advanced) (1.3.0)
# Requirement already satisfied: sentencepiece==0.1.99 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from autotrain-advanced) (0.1.99)
# Requirement already satisfied: tqdm==4.65.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from autotrain-advanced) (4.65.0)
# Requirement already satisfied: werkzeug==2.3.6 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from autotrain-advanced) (2.3.6)
# Requirement already satisfied: xgboost==1.7.6 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from autotrain-advanced) (1.7.6)
# Requirement already satisfied: huggingface-hub>=0.16.4 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from autotrain-advanced) (0.20.1)
# Requirement already satisfied: requests==2.31.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from autotrain-advanced) (2.31.0)
# Requirement already satisfied: einops==0.6.1 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from autotrain-advanced) (0.6.1)
# Requirement already satisfied: invisible-watermark==0.2.0 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from autotrain-advanced) (0.2.0)
# Requirement already satisfied: packaging==23.1 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from autotrain-advanced) (23.1)
# Requirement already satisfied: tensorboard in c:\users\spurt\.conda\envs\anote\lib\site-packages (from autotrain-advanced) (2.14.1)
# Requirement already satisfied: peft==0.7.1 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from autotrain-advanced) (0.7.1)
# Requirement already satisfied: trl==0.7.4 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from autotrain-advanced) (0.7.4)
# Requirement already satisfied: tiktoken==0.5.1 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from autotrain-advanced) (0.5.1)
# Collecting transformers==4.36.1 (from autotrain-advanced)
#   Obtaining dependency information for transformers==4.36.1 from https://files.pythonhosted.org/packages/fc/04/0aad491cd98b09236c54ab849863ee85421eeda5138bbf9d33ecc594652b/transformers-4.36.1-py3-none-any.whl.metadata
#   Using cached transformers-4.36.1-py3-none-any.whl.metadata (126 kB)
# Requirement already satisfied: accelerate==0.25.0 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from autotrain-advanced) (0.25.0)
# Requirement already satisfied: diffusers==0.21.4 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from autotrain-advanced) (0.21.4)
# Requirement already satisfied: bitsandbytes==0.41.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from autotrain-advanced) (0.41.0)
# Requirement already satisfied: rouge-score==0.1.2 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from autotrain-advanced) (0.1.2)
# Requirement already satisfied: py7zr==0.20.6 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from autotrain-advanced) (0.20.6)
# Requirement already satisfied: fastapi==0.104.1 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from autotrain-advanced) (0.104.1)
# Requirement already satisfied: uvicorn==0.22.0 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from autotrain-advanced) (0.22.0)
# Requirement already satisfied: python-multipart==0.0.6 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from autotrain-advanced) (0.0.6)
# Requirement already satisfied: gradio==3.41.0 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from autotrain-advanced) (3.41.0)
# Requirement already satisfied: pydantic==2.4.2 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from autotrain-advanced) (2.4.2)
# Requirement already satisfied: hf-transfer in c:\users\spurt\appdata\roaming\python\python39\site-packages (from autotrain-advanced) (0.1.4)
# Requirement already satisfied: pyngrok==7.0.3 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from autotrain-advanced) (7.0.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from accelerate==0.25.0->autotrain-advanced) (1.26.0)
# Requirement already satisfied: psutil in c:\users\spurt\.conda\envs\anote\lib\site-packages (from accelerate==0.25.0->autotrain-advanced) (5.9.5)
# Requirement already satisfied: pyyaml in c:\users\spurt\.conda\envs\anote\lib\site-packages (from accelerate==0.25.0->autotrain-advanced) (6.0)
# Requirement already satisfied: torch>=1.10.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from accelerate==0.25.0->autotrain-advanced) (2.1.0)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from accelerate==0.25.0->autotrain-advanced) (0.4.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from albumentations==1.3.1->autotrain-advanced) (1.11.3)
# Requirement already satisfied: scikit-image>=0.16.1 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from albumentations==1.3.1->autotrain-advanced) (0.22.0)
# Requirement already satisfied: qudida>=0.0.4 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from albumentations==1.3.1->autotrain-advanced) (0.0.4)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from albumentations==1.3.1->autotrain-advanced) (4.8.1.78)
# Requirement already satisfied: arrow in c:\users\spurt\appdata\roaming\python\python39\site-packages (from codecarbon==2.2.3->autotrain-advanced) (1.3.0)
# Requirement already satisfied: pynvml in c:\users\spurt\.conda\envs\anote\lib\site-packages (from codecarbon==2.2.3->autotrain-advanced) (11.5.0)
# Requirement already satisfied: py-cpuinfo in c:\users\spurt\.conda\envs\anote\lib\site-packages (from codecarbon==2.2.3->autotrain-advanced) (9.0.0)
# Requirement already satisfied: fuzzywuzzy in c:\users\spurt\.conda\envs\anote\lib\site-packages (from codecarbon==2.2.3->autotrain-advanced) (0.18.0)
# Requirement already satisfied: click in c:\users\spurt\appdata\roaming\python\python39\site-packages (from codecarbon==2.2.3->autotrain-advanced) (8.1.7)
# Requirement already satisfied: filelock in c:\users\spurt\.conda\envs\anote\lib\site-packages (from diffusers==0.21.4->autotrain-advanced) (3.12.4)
# Requirement already satisfied: importlib-metadata in c:\users\spurt\.conda\envs\anote\lib\site-packages (from diffusers==0.21.4->autotrain-advanced) (6.8.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from diffusers==0.21.4->autotrain-advanced) (2023.10.3)
# Requirement already satisfied: dill in c:\users\spurt\.conda\envs\anote\lib\site-packages (from evaluate==0.3.0->autotrain-advanced) (0.3.7)
# Requirement already satisfied: xxhash in c:\users\spurt\.conda\envs\anote\lib\site-packages (from evaluate==0.3.0->autotrain-advanced) (3.4.1)
# Requirement already satisfied: multiprocess in c:\users\spurt\.conda\envs\anote\lib\site-packages (from evaluate==0.3.0->autotrain-advanced) (0.70.15)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from evaluate==0.3.0->autotrain-advanced) (2023.6.0)
# Requirement already satisfied: responses<0.19 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from evaluate==0.3.0->autotrain-advanced) (0.18.0)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from fastapi==0.104.1->autotrain-advanced) (3.7.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from fastapi==0.104.1->autotrain-advanced) (0.27.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from fastapi==0.104.1->autotrain-advanced) (4.8.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from gradio==3.41.0->autotrain-advanced) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from gradio==3.41.0->autotrain-advanced) (5.1.2)
# Requirement already satisfied: ffmpy in c:\users\spurt\.conda\envs\anote\lib\site-packages (from gradio==3.41.0->autotrain-advanced) (0.3.1)
# Requirement already satisfied: gradio-client==0.5.0 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from gradio==3.41.0->autotrain-advanced) (0.5.0)
# Requirement already satisfied: httpx in c:\users\spurt\.conda\envs\anote\lib\site-packages (from gradio==3.41.0->autotrain-advanced) (0.25.2)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from gradio==3.41.0->autotrain-advanced) (6.1.1)
# Requirement already satisfied: jinja2<4.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from gradio==3.41.0->autotrain-advanced) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from gradio==3.41.0->autotrain-advanced) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from gradio==3.41.0->autotrain-advanced) (3.8.2)
# Requirement already satisfied: orjson~=3.0 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from gradio==3.41.0->autotrain-advanced) (3.9.10)
# Requirement already satisfied: pydub in c:\users\spurt\.conda\envs\anote\lib\site-packages (from gradio==3.41.0->autotrain-advanced) (0.25.1)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from gradio==3.41.0->autotrain-advanced) (2.10.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from gradio==3.41.0->autotrain-advanced) (11.0.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from invisible-watermark==0.2.0->autotrain-advanced) (1.5.0)
# Requirement already satisfied: opencv-python>=4.1.0.25 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from invisible-watermark==0.2.0->autotrain-advanced) (4.8.1.78)
# Requirement already satisfied: rapidfuzz==2.13.7 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from jiwer==3.0.2->autotrain-advanced) (2.13.7)
# Requirement already satisfied: colorama>=0.3.4 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from loguru==0.7.0->autotrain-advanced) (0.4.6)
# Requirement already satisfied: win32-setctime>=1.0.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from loguru==0.7.0->autotrain-advanced) (1.1.0)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from optuna==3.3.0->autotrain-advanced) (1.13.1)
# Requirement already satisfied: cmaes>=0.10.0 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from optuna==3.3.0->autotrain-advanced) (0.10.0)
# Requirement already satisfied: colorlog in c:\users\spurt\appdata\roaming\python\python39\site-packages (from optuna==3.3.0->autotrain-advanced) (6.8.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from optuna==3.3.0->autotrain-advanced) (2.0.21)
# Requirement already satisfied: texttable in c:\users\spurt\.conda\envs\anote\lib\site-packages (from py7zr==0.20.6->autotrain-advanced) (1.7.0)
# Requirement already satisfied: pycryptodomex>=3.6.6 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from py7zr==0.20.6->autotrain-advanced) (3.19.0)
# Requirement already satisfied: pyzstd>=0.14.4 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from py7zr==0.20.6->autotrain-advanced) (0.15.9)
# Requirement already satisfied: pyppmd<1.1.0,>=0.18.1 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from py7zr==0.20.6->autotrain-advanced) (1.0.0)
# Requirement already satisfied: pybcj>=0.6.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from py7zr==0.20.6->autotrain-advanced) (1.0.2)
# Requirement already satisfied: multivolumefile>=0.2.3 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from py7zr==0.20.6->autotrain-advanced) (0.2.3)
# Requirement already satisfied: brotli>=1.0.9 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from py7zr==0.20.6->autotrain-advanced) (1.1.0)
# Requirement already satisfied: inflate64>=0.3.1 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from py7zr==0.20.6->autotrain-advanced) (1.0.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from pydantic==2.4.2->autotrain-advanced) (0.5.0)
# Requirement already satisfied: pydantic-core==2.10.1 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from pydantic==2.4.2->autotrain-advanced) (2.10.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from requests==2.31.0->autotrain-advanced) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from requests==2.31.0->autotrain-advanced) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from requests==2.31.0->autotrain-advanced) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from requests==2.31.0->autotrain-advanced) (2023.7.22)
# Requirement already satisfied: absl-py in c:\users\spurt\.conda\envs\anote\lib\site-packages (from rouge-score==0.1.2->autotrain-advanced) (2.0.0)
# Requirement already satisfied: six>=1.14.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from rouge-score==0.1.2->autotrain-advanced) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from scikit-learn==1.3.0->autotrain-advanced) (3.2.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from transformers==4.36.1->autotrain-advanced) (0.15.0)
# Requirement already satisfied: tyro>=0.5.11 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from trl==0.7.4->autotrain-advanced) (0.6.2)
# Requirement already satisfied: h11>=0.8 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from uvicorn==0.22.0->autotrain-advanced) (0.14.0)
# Requirement already satisfied: pyarrow>=8.0.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from datasets[vision]~=2.14.0->autotrain-advanced) (13.0.0)
# Requirement already satisfied: aiohttp in c:\users\spurt\.conda\envs\anote\lib\site-packages (from datasets[vision]~=2.14.0->autotrain-advanced) (3.9.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from pandas>=1.4->autotrain-advanced) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from pandas>=1.4->autotrain-advanced) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from pandas>=1.4->autotrain-advanced) (2023.3)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from tensorboard->autotrain-advanced) (1.59.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from tensorboard->autotrain-advanced) (2.23.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from tensorboard->autotrain-advanced) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from tensorboard->autotrain-advanced) (3.5)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from tensorboard->autotrain-advanced) (68.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from tensorboard->autotrain-advanced) (0.7.1)
# Requirement already satisfied: Mako in c:\users\spurt\appdata\roaming\python\python39\site-packages (from alembic>=1.5.0->optuna==3.3.0->autotrain-advanced) (1.3.0)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from altair<6.0,>=4.2.0->gradio==3.41.0->autotrain-advanced) (4.19.1)
# Requirement already satisfied: toolz in c:\users\spurt\.conda\envs\anote\lib\site-packages (from altair<6.0,>=4.2.0->gradio==3.41.0->autotrain-advanced) (0.12.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from anyio<4.0.0,>=3.7.1->fastapi==0.104.1->autotrain-advanced) (1.3.0)
# Requirement already satisfied: exceptiongroup in c:\users\spurt\.conda\envs\anote\lib\site-packages (from anyio<4.0.0,>=3.7.1->fastapi==0.104.1->autotrain-advanced) (1.1.3)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from aiohttp->datasets[vision]~=2.14.0->autotrain-advanced) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from aiohttp->datasets[vision]~=2.14.0->autotrain-advanced) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from aiohttp->datasets[vision]~=2.14.0->autotrain-advanced) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from aiohttp->datasets[vision]~=2.14.0->autotrain-advanced) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from aiohttp->datasets[vision]~=2.14.0->autotrain-advanced) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from aiohttp->datasets[vision]~=2.14.0->autotrain-advanced) (4.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard->autotrain-advanced) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard->autotrain-advanced) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard->autotrain-advanced) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->autotrain-advanced) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from importlib-resources<7.0,>=1.3->gradio==3.41.0->autotrain-advanced) (3.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from matplotlib~=3.0->gradio==3.41.0->autotrain-advanced) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from matplotlib~=3.0->gradio==3.41.0->autotrain-advanced) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from matplotlib~=3.0->gradio==3.41.0->autotrain-advanced) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from matplotlib~=3.0->gradio==3.41.0->autotrain-advanced) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from matplotlib~=3.0->gradio==3.41.0->autotrain-advanced) (3.1.1)
# Requirement already satisfied: networkx>=2.8 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from scikit-image>=0.16.1->albumentations==1.3.1->autotrain-advanced) (3.1)
# Requirement already satisfied: imageio>=2.27 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from scikit-image>=0.16.1->albumentations==1.3.1->autotrain-advanced) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from scikit-image>=0.16.1->albumentations==1.3.1->autotrain-advanced) (2023.12.9)
# Requirement already satisfied: lazy_loader>=0.3 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from scikit-image>=0.16.1->albumentations==1.3.1->autotrain-advanced) (0.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from sqlalchemy>=1.3.0->optuna==3.3.0->autotrain-advanced) (2.0.2)
# Requirement already satisfied: sympy in c:\users\spurt\.conda\envs\anote\lib\site-packages (from torch>=1.10.0->accelerate==0.25.0->autotrain-advanced) (1.12)
# Requirement already satisfied: docstring-parser>=0.14.1 in c:\users\spurt\appdata\roaming\python\python39\site-packages (from tyro>=0.5.11->trl==0.7.4->autotrain-advanced) (0.15)
# Requirement already satisfied: rich>=11.1.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from tyro>=0.5.11->trl==0.7.4->autotrain-advanced) (13.6.0)
# Requirement already satisfied: shtab>=1.5.6 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from tyro>=0.5.11->trl==0.7.4->autotrain-advanced) (1.6.5)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from arrow->codecarbon==2.2.3->autotrain-advanced) (2.8.19.14)
# Requirement already satisfied: httpcore==1.* in c:\users\spurt\.conda\envs\anote\lib\site-packages (from httpx->gradio==3.41.0->autotrain-advanced) (1.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.41.0->autotrain-advanced) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.41.0->autotrain-advanced) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.41.0->autotrain-advanced) (0.10.4)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->autotrain-advanced) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->autotrain-advanced) (3.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from rich>=11.1.0->tyro>=0.5.11->trl==0.7.4->autotrain-advanced) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from rich>=11.1.0->tyro>=0.5.11->trl==0.7.4->autotrain-advanced) (2.16.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from sympy->torch>=1.10.0->accelerate==0.25.0->autotrain-advanced) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\spurt\.conda\envs\anote\lib\site-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl==0.7.4->autotrain-advanced) (0.1.2)
# Using cached transformers-4.36.1-py3-none-any.whl (8.3 MB)
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.34.0
#     Uninstalling transformers-4.34.0:
#       Successfully uninstalled transformers-4.34.0
# Successfully installed transformers-4.36.1
# WARNING: Ignoring invalid distribution -illow (c:\users\spurt\.conda\envs\anote\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\spurt\.conda\envs\anote\lib\site-packages)

# %%
# !autotrain setup --update-torch
# Out:
# 'autotrain' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !autotrain llm --train Anote_benchmarking finetuned_model --model meta-llama/Llama-2-7b-hf --data_path . --use-peft --use-4bit --learning_rate 2e-4 --train_batch_size 4 --num_train_epochs 3 --trainer sft

# %%
# !autotrain --help
# Out:
# 'autotrain' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !pip install autotrain
# Out:
# WARNING: Ignoring invalid distribution -illow (c:\users\spurt\.conda\envs\anote\lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement autotrain (from versions: none)
# ERROR: No matching distribution found for autotrain
