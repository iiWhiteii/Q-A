# %%
from langchain.document_loaders import UnstructuredPDFLoader, PyPDFDirectoryLoader, PyPDFLoader
from langchain.indexes import VectorstoreIndexCreator
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.chains.question_answering import load_qa_chain
import openai
import pandas as pd
import requests
import json
import datetime
import shutil
import os
from datasets import load_dataset
import time

# %%
dataset = load_dataset("PatronusAI/financebench")

# %%
df = pd.DataFrame(dataset['train'])

# %%
OPENAI_KEY = os.getenv('OPENAI_KEY')
openai.api_key = OPENAI_KEY

# %%
OPENAI_KEY
# Out:
# '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'

# %%
df.head(2)
# Out:
#          financebench_id     doc_name  \
# 0  financebench_id_03029  3M_2018_10K
# 1  financebench_id_04672  3M_2018_10K
#
#                                             doc_link  doc_period  \
# 0  https://investors.3m.com/financials/sec-filing...        2018
# 1  https://investors.3m.com/financials/sec-filing...        2018
#
#        question_type                                           question  \
# 0  metrics-generated  What is the FY2018 capital expenditure amount ...
# 1  metrics-generated  Assume that you are a public equities analyst....
#
#      answer                                      evidence_text page_number
# 0  $1577.00  Table of Contents \n3M Company and Subsidiarie...          60
# 1     $8.70  Table of Contents \n3M Company and Subsidiarie...          58

# %%
def text_to_openai_json(data,filename):
    """
    Converts a given dataset into a JSON Lines (JSONL) file suitable for OpenAI's GPT-3.5 turbo model.
    
    Args:
        data (DataFrame or similar data structure): Input data containing text and labels.

    The function processes the input data row by row, constructing conversations for each row with a system message, user message, and an assistant message. It then writes the generated conversation data to a JSONL file.
 
    """
    # Initialize an empty list to store conversation data
    message_list = []

    # Iterate through the rows in the input data
    for _, row in data.iterrows():
        # Create a system message as an initial instruction
        system_message = {
            "role": "system",
            "content":  f"You are a factual chatbot that answers questions about 10-K documents. You only answer with answers you find in the text, no outside information." 
        }

        # Append the system message to the conversation
        message_list.append({"messages": [system_message]})

        # Create a user message based on the 'text' column from the data
        user_message = {
            "role": "user",
            "content": f"{row['evidence_text']} based on {row['question']}  "
        }

        # Append the user message to the conversation
        message_list[-1]["messages"].append(user_message)

        # Create an assistant message based on the 'coarse_label' column from the data
        assistant_message = {
            "role": 'assistant',
            "content": row['answer']
        }

        # Append the assistant message to the conversation
        message_list[-1]["messages"].append(assistant_message)

    # Write the conversation data to a JSON Lines (JSONL) file
    with open(filename, "w") as json_file:
        for message in message_list:
            # Serialize the conversation data to JSON and write it to the file
            json.dump(message, json_file)
            json_file.write("\n")

# %%
df.head(2)
# Out:
#          financebench_id     doc_name  \
# 0  financebench_id_03029  3M_2018_10K
# 1  financebench_id_04672  3M_2018_10K
#
#                                             doc_link  doc_period  \
# 0  https://investors.3m.com/financials/sec-filing...        2018
# 1  https://investors.3m.com/financials/sec-filing...        2018
#
#        question_type                                           question  \
# 0  metrics-generated  What is the FY2018 capital expenditure amount ...
# 1  metrics-generated  Assume that you are a public equities analyst....
#
#      answer                                      evidence_text page_number
# 0  $1577.00  Table of Contents \n3M Company and Subsidiarie...          60
# 1     $8.70  Table of Contents \n3M Company and Subsidiarie...          58

# %%
def fine_tune_model(model_id,num_label,pandas_df):
    df = pandas_df.iloc[:num_label]
    filename = f'ft_increment_{num_label}.jsonl'
    text_to_openai_json(df, filename)
    loader = openai.File.create(file=open(filename, "rb"), purpose='fine-tune')
    fine_tuning_job = openai.FineTuningJob.create(training_file=loader.id, model="gpt-3.5-turbo-1106")
    return fine_tuning_job.id

# %%
def wait_for_fine_tuning(job_id):
    while True:
        response = openai.FineTuningJob.retrieve(job_id)
        print(response["fine_tuned_model"])
        if response["fine_tuned_model"]:
            print(response["fine_tuned_model"])
            return response["fine_tuned_model"]
        time.sleep(30)

# %%
system_content = "You are a factual chatbot that answers questions about 10-K documents. You only answer with answers you find in the text, no outside information."

# %%
df['question']
# Out:
# 0      What is the FY2018 capital expenditure amount ...
# 1      Assume that you are a public equities analyst....
# 2      Is 3M a capital-intensive business based on FY...
# 3      What drove operating margin change as of FY202...
# 4      If we exclude the impact of M&A, which segment...
#                              ...
# 145    Is Verizon a capital intensive business based ...
# 146    Has Verizon increased its debt on balance shee...
# 147    What is FY2018 days payable outstanding (DPO) ...
# 148    Based on the information provided primarily in...
# 149    What is the FY2018 - FY2020 3 year average una...
# Name: question, Length: 150, dtype: object

# %%
def generate_10K_responses(data,model_id):
    syntheses = []
    system_content = "You are a factual chatbot that answers questions about 10-K documents. You only answer with answers you find in the text, no outside information." 
    for idx, row in data.iterrows():
        completion = openai.ChatCompletion.create(
            model= model_id ,
            messages=[
                {"role": "system", "content": system_content},
                {"role": "user", "content": f"{row['question']} based on {row['evidence_text']}" }
            ])
        
        #print(f'text: {row}')
        print(completion.choices[0].message.content)
        syntheses.append(completion.choices[0].message.content)
    syntheses_df = pd.DataFrame({'evidence_text': data['evidence_text'], 'answer' : data['answer'], 'syntheses' : syntheses })
    
    return syntheses_df

# %%
count = 0
label_count = [] 
model_ids = []

# %%
for i in range(5):
    count += 10
    label_count.append(count)
    ft_id = fine_tune_model(model_id = 'gpt-3.5-turbo-1106', num_label=count, pandas_df=df)
    if wait_for_fine_tuning(ft_id) is not None:
        model_ids.append(wait_for_fine_tuning(ft_id))
        syntheses_df = generate_10K_responses(data = df, model_id = wait_for_fine_tuning(ft_id))
        syntheses_df.to_csv(f'syntheses_df{count}.csv',index=False)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ft:gpt-3.5-turbo-1106:liangzhang::8bYkDRZK
# ft:gpt-3.5-turbo-1106:liangzhang::8bYkDRZK
# ft:gpt-3.5-turbo-1106:liangzhang::8bYkDRZK
# ft:gpt-3.5-turbo-1106:liangzhang::8bYkDRZK
# ft:gpt-3.5-turbo-1106:liangzhang::8bYkDRZK
# ft:gpt-3.5-turbo-1106:liangzhang::8bYkDRZK
# $1577.00
# $8.70
# No, 3M is a technology-driven company with a significant manufacturing and marketing presence. It is less capital-intensive than traditional chemical companies.
# The decrease in operating margin for 3M in FY2022 was primarily due to the impact of special items, including:
# -Decreased by 2.2%, primarily due to the impact of special items
# The Consumer segment shrunk by 0.9% organically.
# No. The quick ratio is not relevant to measure liquidity.
# The 1.500% Notes due 2026 (Trading Symbol: MMM26) and
# 1.750% Notes due 2030 (Trading Symbol: MMM30) are registered to trade on the New York Stock Exchange.
# Yes, 3M has a good track record of consistently increasing its dividend distribution.
# 24.05
# 1.9%
# 18.29
# 38.7%
# 1.04
# Operating margin of Adobe has improved from 45.3% in FY2021 to 46.2% in FY2022.
# No.  It dipped to 87.80% in FY 2022 from 88.18% in FY 2021
# $1,404
# Inventory Turnover=Cost of Goods Sold/Average Inventory
# =($10,069+$8,430)/2/$830.5
# =19.42x
#
# AES does not provide the frequency of inventory turnover. Moreover, given the nature of its operations and industry, which mostly relates to services and construction projects rather than manufacturing and sales of goods, the conventional inventory management and its ratios do not hold significant importance.
# 1.56%
# 52.31
# 23.7%
# $11588
# $1615.9
# The agenda was to substitute the former issuer with a new one and assume the covenants of the former issuer under the Indentures.
# The quick ratio has improved from 0.94 in FY2022 to 1.01 in FY2023.
# The company has not made any major acquisition in FY2023.Following were the major acquisitions in FY2022 and FY2021:
# 1. FY2022: A flexible packaging manufacturing business in Malaysia for a cash consideration of $40 million, and the acquisition of a South American flexible packaging distributor for a cash consideration of $18 million.
# 2. FY2021: A South American flexible packaging manufacturer for a cash consideration of $210 million, and a European manufacturer of biodegradable packaging products for a cash consideration of $17 million
# AMCOR primarily operates in the packaging industry, focusing on food, beverage, pharmaceutical, medical, home and personal-care, and other products.
# No. The gross margin for FY2023 is slightly lower than FY2022.
# The liability for employee-related costs, fixed assets, and other costs from the closure of facilities and staff reductions.
# $2,117 million
# $720M.
# 0.93%
# No. The quick ratio is not relevant to assess AMD's liquidity position as it excludes the majority of the company's current assets.
# The major products and services sold by AMD as of FY22 are:
# • server microprocessors (CPUs) and graphics processing units (GPUs), data processing units (DPUs), Field Programmable Gate Arrays (FPGAs), and Adaptive System-on-Chip (SoC) products for data centers;
# • CPUs, accelerated processing units (APUs) that integrate CPUs and GPUs, and chipsets for desktop and notebook personal computers;
# • discrete GPUs, and semi-custom SoC products and development services; and
# • embedded CPUs, GPUs, APUs, FPGAs, and Adaptive SoC products.
# The increase in net revenue was primarily driven by:
# - A 64% increase in Data Center segment revenue
# - A 21% increase in Gaming segment revenue
# - A significant increase in Embedded segment revenue
# Operating margin for 2022 was not meaningful as "Operating margin is not a useful metric for the company like us where the operating income is primarily adjusted for special items that do not relate to the core operating performance of our business."
# $4,310
# Gaming
# Yes, one customer accounted for 16% of AMD’s consolidated net revenue for the year ended December 31, 2022.
# 8.125% Debentures due 2041
# 6.200% Debentures due 2037
# What are the geographies that American Express primarily operates in as of 2022?
# -United States
# -EMEA
# -APAC
# -LACC
# No. The Company has experienced a decrease in its operating margin for 2022 as opposed to the previous year.
# Operating Margin
# 2022: 15.9%
# 2021: 25.2%
# 2020: 22.3%
# Gross margin improved due to a higher proportion of discount revenue within non-interest revenues.
# 21.6%
# Customer deposits
# Yes, the company was able to retain card members at high rates.
# $389.00
# $1832.00
# No. Working capital is positive and amounting to $ (1,561) millions.
# 10.7%
# $5409.00
# No. Gross margins seem to be fluctuating more than 2% each year. The gross margin percentages for the respective years are:
# 2023: 21.4%
# 2022: 22.5%
# 2021: 22.3%
# What are major acquisitions that Best Buy has done in FY2023, FY2022 and FY2021?
# -Current Health Ltd.
# -Two Peaks, LLC d/b/a Yardbird Furniture
# Best Buy's operating activities.
# No.
# No, there were no changes.
# Entertainment
# 1.74
# 69.8%
# $381603.00
# $12,645.00
# Yes, only the "Commercial Airplanes" service category represents more than 20% of Boeing's revenue for FY2022
# Yes, their ongoing legal battles relating to 737 MAX accidents are continually being reported.
# No. The gross margin for Boeing has improved. It stood at 5.3% in FY2022 compared to 4.8% in FY2021 and (9.8%) in FY2020.
# The U.S. government and commercial airlines.
# Yes,
# What is 31 per month?
# Boeing's effective tax rate for FY2022 is -0.62% compared to 14.75% in FY2021.
# 2.04%
# 15.7%
# 168.65%
# 42.70
# 10.9%
# The effective tax rate has decreased by 3% (from 23% to 20%)
# No. The current liabilities exceed current assets by $722 Million.
# $59,268.
# 16.01
# No. The company has efficiently managed its capital requirements, primarily through working capital management and monitoring of capital expenditure.
# From the information provided, the Company has not reported any materially important ongoing legal battles based on Usual and Customary Pricing Litigation for 2020 or 2021, however, based on such litigations, in 2022 CVS Health has become involved in several class-action lawsuits and also settled a Mammoth deal to resolve opioid claims.
# No, they have not.
# Yes, Mary N. Dillon was the Chief Executive Officer of Ulta Beauty, Inc.
# No.
# The FY2019 cash conversion cycle (CCC) for General Mills is 65.38. Calculations are below:
# DIO: 23.26
# DSO: 30.11
# DPO: -88.99
# 57.76
# $3037.7
# 88.27%
# No, the growth isn't that impressive
# Gross margin decreased by 1.3% primarily due to:
# •
# One-time COVID-19 vaccine manufacturing exit related costs
# •
# Currency impacts in the Pharmaceutical segment
# •
# Commodity inflation in the MedTech and Consumer Health segments
# Inventory turnover: 2.29 times
# Explain the conventional inventory management is not meaningful for the company.:
# This metric is not particularly meaningful for Johnson & Johnson, primarily because the company generally does not maintain significant amounts of finished goods due to the nature of its business.
# No, the growth in JnJ's adjusted EPS is expected to decelerate in FY2023.
# The growth in the US sales outpaced the growth in international sales by 3.6% in FY2022.
# The Consumer Health business.
# $20 billion
# $13.2 billion
# No. The net earnings as a percent of sales decreased from 20.0% to 20.1%.
# Corporate. It had a negative net revenue of $473 million.
# $74.10
# Gross margin has ranged from 39% to 63% over the past 5 years, thus showing significant variation.
# Asset & Wealth Management
# No
# 5.17
# 0.73
# $5,818.00
# 2.3%
# $302.6
# 1.8%
# No, the company only paid $0.01 per share as dividends
# The Las Vegas Strip Resorts segment.
# 29:1
# MGM China
# Corporate bonds
# $17,880.00
# No. The long-term debt of Microsoft has decreased by $6040 million from 2022 to 2023.
# 11.5%
# $5,466.31
# 4.9%
# $16,525.
# 10.48
# Nike's operating activities.
# Yes, $12,416
# $4.6
# PepsiCo primarily operates in more than 200 countries and territories.
# No.
# $0.
# $7552.00
# 26.08%
# The shareholder proposal was defeated with 97,722,8788 votes against it.
# By $400,000,000.
# PepsiCo may increase the commitments under the 2023 364 Day Credit Agreement to up to $4,950,000,000.
# Due to their strong start to the year, with organic revenue and core constant currency EPS growth, being expected to increase by 8% and 9%, respectively.
# 1%
# No. It decreased from $35,067M to $33,276M
# Yes, the gain on completion of Consumer Healthcare JV transaction substantially increased net income in 2019.
# Therachon, Array, Trillium.
# The company expects to pay approximately $700 million.
# Developed Rest of World
# Yes, based on the information provided, the Upjohn segment is being separated.
# 7.625% Senior Notes, due 2030
# The acquisitions made by Ulta Beauty in FY2023 and FY2022 are as follows:
# FY2023: Not applicable
# FY2022: Wemakeup Comercio de Cosmeticos Ltda.
# What drove the reduction in SG&A expense as a percent of net sales in FY2023 was primarily due to lower marketing expenses and leverage of incentive compensation due to higher sales.
# The opening of 47 new stores, inventory to support new brand launches and brand expansions, and inventory cost increases.
# 1.56%
# It decreased to 23.5% from 23.9%
# Cross currency swaps
# $2090 million
# No. The quick ratio is not relevant for Verizon as a measure of liquidity. The components of quick ratio are not really relevant for Verizon's operations.
# No, It is not.
# No. The Verizon Communications shows a decrease to $140,676, down from $143,425 in 2021.
# 64.88
# -0.4%
# 3.6%
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ft:gpt-3.5-turbo-1106:liangzhang::8bYqOTnk
# ft:gpt-3.5-turbo-1106:liangzhang::8bYqOTnk
# ft:gpt-3.5-turbo-1106:liangzhang::8bYqOTnk
# ft:gpt-3.5-turbo-1106:liangzhang::8bYqOTnk
# ft:gpt-3.5-turbo-1106:liangzhang::8bYqOTnk
# ft:gpt-3.5-turbo-1106:liangzhang::8bYqOTnk
# $1,577
# $8.74
# No.
# Operating Margin decreased by 240 bps in 2022 due to an increase in SGA due to significant litigation, divestiture-related restructuring charges, impairment costs, costs related to exiting Russia, and continued investment in key growth initiatives
# Consumer segment has shown a decline of 0.9% organically.
# The quick ratio is calculated as the sum of cash, cash equivalents, and marketable securities divided by current liabilities.
# 1.500% Notes due 2026 - MMM26 - New York Stock Exchange
# 1.750% Notes due 2030 - MMM30 - New York Stock Exchange
# 1.500% Notes due 2031 - MMM31 - New York Stock Exchange
# Yes, 3M maintains a stable trend of dividend distribution.
# 0.02
# 14.5%
# 0.66
# The operating income of Adobe increased by 65.3% from FY 2015 to FY 2016
# 0.83
# Operating margin for Adobe Inc. has decreased from 36.8% in 2021 to 34.6% in 2022 primarily due to an increase of 16% in operating expenses.
# Company seems to have control over working capital, as "Effectively managed working capital, with $1.9 billion of cash flow from operations and 34 days of cash."
# 0
# The inventory turnover for FY2022 is 9.5 times.
# -0.02
# 24.49
# 49.9%
# 11605
# 50
# The key agenda of the 8-K filing was the substitution of the Substitute Issuer for the Former Issuer and the assumption by the Substitute Issuer of the covenants of the Former Issuer under the Indentures.
# Quick ratio declined from FY2022 to FY2023
# A Czech Republic company, a medical device packaging manufacturing site in Shanghai, China, and a New Zealand based leading manufacturer of state-of-the-art, automated protein packaging machines
# Amcor primarily operates in the packaging industry, producing responsible packaging for various products including food, beverage, pharmaceutical, medical, home and personal-care products.
# No, the trend in gross margin for AMCOR is not improving as the same has declined for consecutive years
# The purpose of the restructuring liability is to fund the Company’s cost reduction initiatives through the rationalisation of its cost structure and operational footprint.
# $2,117
# -220
# 8%
# No, the quick ratio might be perceived as in relevant. The ratio recovered would be 1.0x. which might be misleading. It does not account for line of credit facilities available to the ballpen of $500 million.
# Advanced Micro Devices, Inc offers CPUs, GPUs, Data Processing Units, Field Programmable Gate Arrays, Adaptive SoCs, and semi-custom SoCs.
# The following 2 factors primarily drove the increase of AMD’s FY22 net revenue by 44%, as compared to 2021:
# - 64% increase in Data Center segment revenue primarily due to higher sales of our EPYC™ server processors.
# - 21% increase in Gaming segment revenue primarily due to higher semi-custom product sales.
# As of FY22, the decrease in operating margin for AMD was mainly due to the amortization of intangible assets related to the Xilinx acquisition.
# $2,300
# Gaming
# Yes
# 800 debt securities are registered to trade on a national securities exchange_elt(network to calculate the exact number of debt securities)
# United States, EMEA, APAC, LACC
# No .889285. "The company considers that the best way to understand the operating efficiency of Amex is to evaluate adjusted return on tangible equity."
# Not Applicable, after analyzing the report, it is clear that "Gross Margin" is not calculated as it will not be a useful metric for this company.
# 21.6%
# $110,239
# Yes
# $389 million
# $1832
# No, American Water Works Company's current liabilities exceed its current assets by $1,181M on December 31, 2022.
# 3.1%
# $5409.00
# Best Buy's reported gross profit as a percentage of revenues in FY2023, FY2022, and FY2021 is 21.4% , 22.5% and 22.3%
# Explanation: the gross margin percentage of Best Buy does not seem to have been consistent over the last 3 years
# In fiscal 2021, we acquired an e-health platform that connects patients and healthcare providers.
# $1,824 million
# Yes, there was a drop in Cash & Cash Equivalents, from 1,874M to 1,093M
# The information is not conclusive
# Entertainment
# 1.74
# -37.3%
# 381603
# 12645
# The Commercial Airplanes category represents more than 20% of Boeing's revenue for FY2022
# Yes, Boeing has reported and disclosed about multiple ongoing legal battles from FY2022 including legal actions filed against the company in the context of Lion Air and Ethiopian Airlines accidents
# Boeing has improved its gross margin to 5.3% for FY 2022 from negative 9.1% in FY 2020.
# Commercial airlines and U.S. Government
# Yes, it is mentioned in the document that "Historically, the airline industry has been cyclical and very competitive and has experienced significant profit swings and constant challenges to be more cost competitive."
# Production rate in 2023:  787 – 5 aircraft per month
# The fiscal year 2022 effective tax rate was (0.6) percent including approximately $100 million of net benefits primarily due to favorable foreign-derived intangible income of approximately $100 million. The effective tax rate is below the U.S. statutory rate due to ongoing benefits associated with foreign-derived intangible income, excess tax benefits from share-based compensation, recurring favorable settlements, and foreign tax credits. In all, these benefits more than offset the impact of the pre-tax provision loss.
# 0.13
# 24.9%
# 38.51
# 116.50
# 5.0%
# Corning's effective tax rate has increased from 20% in FY2021 to 23% in FY2022
# Yes, Corning's Working Capital based on FY 2022 data is positive at $2,278 million.
# $59,268
# 0.45
# Yes, CVS Health is a capital-intensive business based on FY2022, considering the long-term investments, PPE (Property and Equipment), Goodwill, and Intangible assets.
# Yes, CVS Health is being sued by the state Attorneys General, governmental subdivisions and several putative class actions, regarding drug pricing and its rebate arrangements with drug manufacturers and the Company's retail pharmacies are overcharging for prescription drugs. The company has also settled the opioid claims with a leadership group of a number of state Attorneys General and the Plaintiffs’ Executive Committee for approximately $4.3 billion in opioid remediation and $625 million in attorneys’ fees and costs and additional remediation.
# CVS Health paid out a dividend of $0.50 per common share on August 2, 2022, to shareholders of record on July 22, 2022.
# Mary N. Dillon has previous CEO experience having been the former Executive Chair and Chief Executive Officer of Ulta Beauty, Inc.
# Yes, Alan D. Feldman and Richard A. Johnson were the board nominees that had considerably more votes against joining the board compared to the other nominees.
# 41.87
# 0.68
# $2163.6
# The FY 2022 retention ratio for General Mills is 53.25.
# No, it is not a high growth company
# The main driver of gross margin decrease for JNJ year-over-year was:
# - One-time COVID-19 vaccine manufacturing exit related costs
# - Currency impacts in the Pharmaceutical segment
# - Commodity inflation in the MedTech and Consumer Health segments
# Johnson & Johnson had inventory turnover of 2.6 in FY2022
# Based on the 10-K data for 2022-2023, the expected adjusted EPS growth for FY2023 is 3.5%.
# US sales grew much more compared to international markets(JnJ's FY2022)
# The Company recently completed an exchange offer to finalize the separation of Kenvue Inc., formerly Johnson & Johnson’s Consumer Health business. As a result of the completion of the exchange offer, Johnson & Johnson will now present its Consumer Health business financial results as discontinued operations
# $20 billion
# The company secured $13.2 billion in cash proceeds from the Kenvue debt offering and initial public offering.
# Net earnings as a percentage of sales increased from 20.0% in Q2 of FY2022 to 20.1% in Q2 of FY2023.
# Consumer & Community Banking
# In a theoretical liquidation scenario of the firm, common shareholders could be hypothetically entitled to $66.56 per share based on The Firm's TBVPS.
# It's difficult to know why margins haven't been discussed in the MD&A section of J.P. Morgan's 10-K. This can indicate that the company doesn't consider gross margins as a relevant tool for assessing the firm's profitability, perhaps due to the nature of the industry the company operates in.
# Consumer & Community Banking
# Yes, the logical inference from the provided statement can be that JPM faced less risk related to VaR on a quarterly basis, with moderate reductions in both Credit Portfolio VaR and fixed income portfolios.
# 5.88
# 0.14
# Net Working Capital of Lockheed Martin for the year 2021 is USD5,818 million
# 43.4%
# 302.578
# 12.3%
# No, MGM resorts paid annual dividends of $0.01 per share in 2022
# Regional Operations
# 1.80
# MGM China
# MGM has invested the largest amount in Corporate bonds under Level 2 investments, which amounts to $416,420.
# $17,880 millions
# Yes, Microsoft increased its long-term-debt between FY2023 and the FY2022 period by $8,781 Mn
# Unadjusted EBITDA % margin for FY2015 of Netflix: 5.6%
# $5,466.312.
# 14.3%
# 16,525
# 4.01
# It's operations, at a net of $5,841,000,000
# At the end of the 2022 fiscal year, PayPal's current assets exceeded current liabilities by $12.4B, implying a positive working capital.
# 6.0
# PepsiCo operates in the following geographies: North America, Latin America, Europe, Africa, Middle East and South Asia, and Asia Pacific, Australia and New Zealand and China Region
# No, Pepsico does not have any material ongoing litigation that is important to consider based on the information available.
# 0
# $7,977
# 20.7%
# The proposal was rejected by shareholders
# $400 million
# $8,100,000,000
# PepsiCo raised the full year guidance for FY2023 due to "strong start to the year".
# 9 percentage points
# No, it declinedOrDefault 2021 was 20%, FY 2020 was 24%.
# Yes, the completion of the Consumer Healthcare JV transaction increased the company's net income substantially in 2019
# Trillium, Array, Therachon
# $700
# Developed Rest of World revenues dropped by 74% year over year in Q22023
# No
# The debt securities registered to trade on a national securities exchange, under the name of ULTA Beauty Inc, are as follows ABC.
# Acquisitions, net of cash acquired 0
# Leverage of fixed cost and SG&A improvements including several COVID impacts cessation
# An increase in the opening of new stores, inventory to support new brand launches and brand expansions, and inventory cost increases drove the increase in Ulta Beauty's merchandise inventories balance.
# 27%
# decreased
# The notional value of Cross currency swaps had the highest notional amount in FY 2021 and the value was $32,502.
# $1,097
# No, the quick Ratio for fy 2022 is 0.46, which suggests short-term solvency risk
# Yes, based on the consolidated balance sheets it seems that Verizon is a capital-intensive business. With $379,680 in assets, and 29.4% of their assets in Property, Plant, and Equipment, it indicates that Verizon is engaged in the business of providing services in the field of capitalization---------------------------------------------- As per this document- Is it right to say that Verizon is capital intensive?
# No
# 114.26
# Walmart Unadjusted operating income % margin change between FY2018 and FY2019 is -20.7%
# Please check if this is the correct value: 4.6%
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ft:gpt-3.5-turbo-1106:liangzhang::8bYxbnYG
# ft:gpt-3.5-turbo-1106:liangzhang::8bYxbnYG
# ft:gpt-3.5-turbo-1106:liangzhang::8bYxbnYG
# ft:gpt-3.5-turbo-1106:liangzhang::8bYxbnYG
# ft:gpt-3.5-turbo-1106:liangzhang::8bYxbnYG
# ft:gpt-3.5-turbo-1106:liangzhang::8bYxbnYG
# $1,577.00
# - $8.738
# Yes, 3M is a capital-intensive business.
# SG&A as a percentage of sales rose by 61 bp driven by the aforementioned items. Furthermore,  Operating margin isn't the best for evaluating our business. Our realignment initiatives and associated special items mean the Operating Margin value doesn't reflect our underlying operating results.
# The Safety and Industrial segment has dragged down the growth maximizing the total sales down by (3.2)% due to the translation effect of M&A.
# No, 3M's quick ratio seems quite healthy. The quick ratio has increased from 1.54 on December 31, 2022, to 1.59 on June 30, 2023.
# As of June 30, 2023, 3M’s 1.5% Notes due 2026, 1.75% Notes due 2030 and 1.5% Notes due 2031 are registered to trade on the New York Stock Exchange.
# Yes, 3M has been consistently rewarding its shareholders.
# 9.58
# 2.0%
# 0.66
# 65.1%
# 0.83
# Increases in certain operating expenses prevent Adobe from growing their margins. They're up by the following amounts:
# -Research and development - $447 ($2,987 in 2022 compared to $2,540 in 2021)
# -Sales and marketing - $647 ($4,968 in 2022 compared to $4,321 in 2021).
# Yes, for Adobe Inc. , the Free cash flow conversion has improved to $7,838M at FY 22 from $5,727M at FY 20
# 0
# Inventory turnover was 9.56 in 2022, clearly indicating which item is turning over almost every month.
# -0.02
# 140.95
# 50.3%
# 11588
# 50
# It is to inform about the substitution of the Substitute Issuer for the Former Issuer and the assumption by the Substitute Issuer of the covenants of the Former Issuer under the Indentures.
# It has declined from 1.15 in FY22 to 1.06 in FY23
# AMCOR had six acquisitions during 2023. These acquisitions include manufacturing of barrels, cap liner production, production of specialized packaging, and caps and closures as well as in merchandise protection and labeling products.
# The company primarily operates in the packaging industry, producing sustainable packaging across various sectors.
# The gross margin has slowed down at 14.9% in FY2023 as compared to 19.3% in FY 2022 and 21.2% in FY2021.
# Employee Severance Payments
# Based on the information, AMCOR's Adjusted Non GAAP EBITDA for Twelve Months Ended June 30, 2023 is $2,018 million.
# For the year ended 30 June 2023, Amcor's net sales grew by 1% in constant currency terms for flexibles, while it declined by 3% for rigid packaging.
# 4%
# Insignificant as the quick ratio might not accurately represent liquidity due to the inclusion of both total stockholders' equity and average balance of Networking revenue contracts as per the 25th year algorithm under ASC 606.
# AMD sells the following products and services:
# -Server microprocessors (CPUs) and graphics processing units (GPUs), DPUs, FPGAs, and SoC for data centers. -CPUs, accelerated processing units (APUs), and chipsets for desktop and notebook personal computers. -Discrete GPUs, semi-custom SoC products, and development services. -Embedded CPUs, GPUs, APUs, FPGAs, and Adaptive SoC products. -They may also sell or license an portions of their IP portfolio.
# Net revenue increase of 44% was due to 64% increase in Data Center Exhibit by Hi? Segment revenue.
# The amortization of intangible assets for the Xilinx acquisition was the primary reason for reduction in Operating income for AMD.
# - Financing activities earned the most cash for AMD in FY22, bringing in $4.835 billion
# From FY21 to FY22, Client segment has seen a proportional decrease in net revenue
# Yes, AMD reported customer concentration as one customer accounted for 16% of their consolidated net revenue.
# Securities registered pursuant to Section 12(b) of the Act: 종목코드 AXP America Exchange
# United States, EMEA, APAC, LACC
# No, it does not, AMEX's operating margin profiles have been deteriorating over the last 3 years, with operating margins going down from 30% in 2020 to 24.5% in 2022
# Gross margin expansion for American Express from 2021 to 2022 was largely driven by higher non-interest revenues. Non-interest revenues for the company increased by $8.3 billion or roughly 24% this year, primarily driven by increased discount revenue. Moreover, cost of revenues grew only by 19% and 17% for operating expenses, which also helped improve the gross margins.
#
# The Gross margin figure is diluted to 81% as in 2022.
# The effective tax rate has reduced by 3% from year 2021 to 2022.
# Customer Deposits
# Yes.
# 389.00
# $1832.00
# Current assets are $1,250, and current liabilities are $2,811, so the company has a negative working capital of approximately $1,561 million.
# 3.2%
# 5409.00
# Best Buy's Gross Margins are not historically consistent. The company's gross margins fluctuate from 25.26% to 21.92% to 22.34% between 2023, 2022, and 2021 respectively.
# In fiscal 2023
# Current Health Ltd.
# In fiscal 2022
# Two Peaks, LLC d/b/a Yardbird Furniture
# Operating activities (highest)
# Based on the information in the text, there was no such drop.
# Best Buy had a net decrease of 24 stores between Q2 of FY2023 and FY2024.
# The performance of the Computing and Mobile Phones product category was positive, growing by 7.6%
# 1.73
# 101.9%
# $ 381603.00
# 12645.00
# Commercial Airplanes category represents 38.8% of revenue in 2022.
# Boeing has been involved in legal battles related to the crashes of two planes, Lion Air Flight 610 and Ethiopian Airlines Flight 302.
# No, the gross margin has not shown any consistent improvement over the years. The explanation of this pattern could be that Boeing continues to face issues related to product cost failure.
# 40% of our revenues were earned pursuant to U.S. government contracts
# Yes, Boeing's business is subject to cyclicality.
# Boeing expects the 787 program to increase production to 5 planes per month in 2023, after the production hiatus due to COVID outbreaks. The 777X production is planned to resume in 2023. The company will increase 737 production rates based on demand and supply chain capacity.
# The effective tax rate was (0.6)% in FY 2022, compared to 14.7% in FY 2021.
# 0.03
# FY2021 Margin = 60.002%
# 0.80
# 65.53
# 14.0%
# 92%
# No, Corning had a working capital deficit in 2022, contrary to its working capital surplus in 2021.
# Costco had 59,268 million in total assets as of FY2021 which ended on August 29, 2021.
# 16.32
# Yes. CVS Health seems to be a capital-intensive business based on total revenue that the company generated in FY2022, because less than 2% of the company's revenues are from net investment income.
# The Company is currently involved in multiple litigation proceedings that include usual and customary or the alleged overcharging of drug prices at the company's retail pharmacies, as well as its pricing and rebate practices. A186B34D56_Pursuant to a settlement agreement, the Company agreed to resolve its legal disputes with a leadership group of a number of state Attorneys General and the Plaintiffs’ Executive Committee related to its opioid practices. Under this agreement, the Company is to pay an aggregate amount of approximately $4.925 billion over a 10-year period, starting in 2023 to remediate its opioid claims.
# Yes, CVS Health Corporation announced that it will pay dividends of up to $0.55 per share.
# Yes. Mary N. Dillon, 61, has the previous CEO experience in a similar company to Foot Locker. She was the previous CEO of Ulta Beauty, Inc. (which is a fashion retailer that targets similar audience to Foot....rin, high-net-worth women)
# Yes, Director Richard A. Johnson.
# -28.34
# 0.68
# 3215.80
# 0.63
# It is not doing as well as FY2021 in terms of sales growth. (1.3% vs.13.6%)
# Cost of products sold increased as a percent to sales due to one-time COVID-19 vaccine manufacturing exit related costs, commodity inflation and currency impacts in the pharmaceutical segment, partially offset by supply chain benefits in the Consumer Health segment.
# inventory turnover is almost 8 times, that means they sold their inventory in average 45.63 days; one implication of high inventory turnover ratio is that they might/JnJ might be using just in time inventory or have high power over their suppliers
# Yes, growth in JnJ's adjusted EPS is expected to accelerate in FY2023 by 3.5%.
# Sales in the US were up 3.0% in 2022, while international sales were down (0.6)%
# Johnson & Johnson will treat its Consumer Health segment as a discontinued operation.
# $20 billion
# The cash proceeds addressed in the query were $13.20 billion which was generated by JnJ through the investor offering and equity sale at Kenvue's IPO.
# Yes.
# Corporate's net revenue was -$473 million. It was the lowest among all segments.
# $73.22
# No this number has been fluctuating more than 2% for JPM's gross margins. In fact,  20%+ drop in 2019 compared to the previous year.
# Corporate had the highest net income
# That is correct. The average total VaR decreased by $7 million primarily due to reduced credit portfolio and fixed income VaR
# So, the inventory turnover ratio for FY2019 is 6.42 times
# 1.2871
# $ 582.00
# -4.7%
# 302.578
# 3.2%
# Yes. They've maintained of annual dividend of $0.01 per share throughout 2022.
# Las Vegas Strip Resorts
# 1.7
# MGM China had the worst topline performance by having a net decrease of 44.00% in revenue
# $416,420 in corporate bonds made up 82% of the $509,921 in total short-term investments of MGM Grand in H1 FY2023.
# 32,780
# No, it decreased from $47,032 million to $41,990 million in the year-ending June 30, 2023.
# 4.5%
# Effective from 31st December, 2017, total current liabilities amount to 5,466,312 (in USD millions).
# 56.1%
# In Fiscal Year 2019, Nike reported around $16.525 B in total current assets as per its consolidated balance sheet.
# 3.62
# Cash provided (used) by operations: $5,841 (2023); $5,188 (2022);  $6,657 (2021)
# Yes, Paypal has positive working capital of $12,416 million as of December 31, 2022, which means they are current assets exceed their current liabilities by $12.4 billion.
# 4.6
# PepsiCo operates in more than 200 countries and territories, depending on the report.
# There have been no recent legal battles from FY2022 and FY2021 that would have a material impact on our financial condition.
# 0
# $7742.0
# 15.25%
# No
# $400,000,000.
# “PepsiCo may also, upon the agreement of either the then existing lenders or of additional banks not currently party to the 2023 Five YearCredit Agreement, increase the commitments under the 2023 Five Year Credit Agreement to up to $4,950,000,000 in U.S. Dollars and/or Euros.”
# Pepsico's full year guidance was increased due to strong start to business momentum and  categories and geographies remaining resilient
# 1%
# PPNE grew 8.28% from FY20 to FY21
# In 2019, a gain on completion of Consumer Healthcare JV transaction of $8,107 million substantially increased the net income by Pfizer Inc.
# Array, Trillium and Therachon
# $700 million
# Developed Rest of World (the combination of Japan, Australia, Canada and other) revenues dropped 74%rouw revenues dropped by 74% in Q2-23 compared to Q2-22.
# Based on the above snippet, we can conclude that Pfizer is spinning off Upjohn.
# Common stock, par value $0.01 per share (trading symbol: ULTA) on The NASDAQ Global Select Market
# Acquisitions, net of cash acquired
# - $
# - $
# (
# 1,220
# )
# Due to lower marketing expenses and leverage of incentive compensation due to higher sales.
# $104.2millionINCREMENT EOFY22-EOFY21  Increased by47 stores launched andinventory to support new brands andinventory cost increases.
# 29%
# Decreased to 23.5% compared to 23.9% in fiscal 2021
# Cross currency swaps
# $1,097.00
# 0.48
#    It does not tell the entire story of liquidity.
# No, it's not a capital intensive business.
# In FY 2022, Verizon reported 389,680 MM dollars in total assets and 136,835 MM dollars in operating revenues.
# Decreased by around $3 Billion, No (Disappeared in 2022, ~$3 Billion decrease)... The long-term debt remained essentially flat... at December 31, 2021... Long-term debt decreased $3.4 billion to $140.7 billion at the end of 2022... It was $143.4 billion at the end of 2021
# 73.23
# 0.5%
# 4.3%
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ft:gpt-3.5-turbo-1106:liangzhang::8bZWUpoz
# ft:gpt-3.5-turbo-1106:liangzhang::8bZWUpoz
# ft:gpt-3.5-turbo-1106:liangzhang::8bZWUpoz
# ft:gpt-3.5-turbo-1106:liangzhang::8bZWUpoz
# ft:gpt-3.5-turbo-1106:liangzhang::8bZWUpoz
# ft:gpt-3.5-turbo-1106:liangzhang::8bZWUpoz
# $1,577 Mn
# 0.77
# Yes, 3M is a capital intensive business.
# There has been a significant increase in special item costs due to important litigation infancy stages, of approximately $1.2 billion, impairment costs related to exiting PFAS manufacturing, divestiture-related restructuring charges, and continued investment.
# Consumer
# Based on the 3M's 2023 Q2 10-K report, 3M's quick ratio is 0.8.
# - 1.500% Notes due 2026(MMM26) New York Stock Exchange
# - 1.750% Notes due 2030(MMM30) New York Stock Exchange
# - 1.500% Notes due 2031(MMM31) New York Stock Exchange
# Yes, 3M maintains a stable trend of dividend distribution
# 12.04
# 2.2%
# 0.66
# 65.1%
# 0.83
# No, Adobe has slipped in it's operating margin.
# Yes, Adobe has an improving Free cashflow conversion as of FY2022, it is 35.8%.
# 0
# 2.48 times
# -0.01
# 57.33
# 44.1%
# 11588
# Trade receivables, net are $1615.9 million
# The key agenda of AMCOR's 8k filing dated 1st July 2022 was to file the necessary documentation relating to the substitution of the Substitute Issuer for the Former Issuer and the assumption by the Substitute Issuer of the covenants of the Former Issuer under the Indentures.
# It has Marginally increased as the quick ratio of AMCOR has increased from 0.7 to 0.73
# The major acquisitions done by Amcor are:
#
# On May 31, 2023, a New Zealand based leading manufacturer of state-of-the-art, automated protein
# packaging machines.
#
# On March 17, 2023, a medical device packaging manufacturing site in Shanghai, China.
#
# On August 1, 2022, a Czech Republic company that operates a world-class
# flexible packaging manufacturing plant.
# Amcor primarily operates in the packaging industry
# No, in FY 2023, Amcor's gross profit had slightly decreased compared to the previous year
# The purpose and nature of Amcor's restructuring liability is to retain an amount from the costs of restructuring in order to be paid in future. This can be in form of employee costs, asset, and other related costs.
# $2,018 million
# $239mill
# 4.2%
# No, the quick ratio is not relevant to measure the liquidity given the available cash and cash equivalent and short-term investment
# AMD sells: CPUs, GPUs, data center processors products, semiconductors for PCs, and other product and services.
# Increase in revenue was driven by a 64% increase in Data Center segment revenue primarily due to higher sales of the EPYC™ server processors, a 21% increase in Gaming segment revenue primarily due to higher semi-custom product sales, and a significant increase in Embedded segment revenue from the prior year period.
# The decrease in operating income in 2022 was primarily driven by amortization of intangible assets associated with the Xilinx acquisition
# Investing Activities brought in the most cash after financing activities
# Gaming
# AMD reported that 16% of its net revenue was from one customer from the Gaming segment
# American Express has Common Shares (par value $0.20 per Share) AXP registered for trade on the New York Stock Exchange
# United States, EMEA APAC, and LACC
# No, the company's operating margin is not improving.
# There is not sufficient information to conduct gross margin analysis for this company
# There was a reduction of 3 percentage points in the effective tax rate
# LiabilitiesCustomer deposits $ 110,239 $ 84,382
# yes
# $0.389 billion
# Note: There is no footnote to that question
# No, American Water Works Company, Inc. has  negative working capital of $1,561 million, calculated as (Current assets) - (Current liabilities)
# 3.8%
# 5409.0
# Best Buy’s gross margins have fluctuated by more than 2% in recent fiscal years.
# In fiscal 2022, Best Buy Co., Inc. did two major acquisitions. It acquired Current Health Ltd on November 2, 2021 for net cash consideration of $389 million. On November 4, 2021, the company acquired all of the outstanding shares of Two Peaks, LLC d/b/a Yardbird Furniture for net cash consideration of $79 million.
# In the fiscal year ended January 28, 2023, in what form is Best Buy's balance sheet debt?
# -0.42
# There was no change
# Consumer electronics yielded the best comparable sales results via sales decline in home theater category, and some growth in headphones and portable speakers.
# 1.73
# N-1 - 11.7%
# 381,603
# $12,645
# No, there aren't any product or service categories that represent more than 20% of Boeing's revenue	Copyright notice: The Boeing Company, Copyright Notice (p. 137).
# Yes. A material amount of claims, including those of Lion Air and Ethiopian Airlines, by various customers and other stakeholders are considered factually flawed and legally improper or otherwise not warranted.
# Yes, Boeing saw improved gross margin in 2022, albeit from very low levels.
# Boeing's primary customers are commercial airlines.
# Yes
# A rate of 5 per month from 2023
# Boeing's effective income tax rate was negative (0.6%) in FY2022 and 14.7% in FY2021
# 0.06
# Why don't you try dividing 15357 by 38655?
# 0.8
# 63.66
# 15.1%
# 23% to 20%
# Yes, Corning has positive working capital based on FY2022 data
# $59268
# 1.70
# Based on the FY2022 data, CVS Health has a capital-intensive business.
# Yes, the company agreed to a formal settlement in December 2022 with a leadership group of a number of state Attorneys General and the Plaintiffs’ Executive Committee which would resolve substantially all opioid claims against Company entities by states and political subdivisions, but not private plaintiffs.
# Yes. CVS Health has paid a quarterly cash dividend $0.55 to common shareholders
# Mary N. Dillon resigned as President of McDonald’s after 5 years at the company, during which she was once a notable candidate to replace the current CEO.
# Yes.
# -12.02
# 0.68
# $640.1 million
# 0.76
# No, their revenues are expected to grow upwards of 2-5%
# The following drove the consolidated gross margin change:
#
# * One-time COVID-19 vaccine manufacturing exit costs
# * Currency impacts in the Pharmaceutical segment
# * Commodity inflation in the MedTech and Consumer Health segments
# JnJ sold its inventory around four times in FY2022. The Inventory turnover ratio is 4.17 times.
# No, EPS growth is expected to decelerate
# JnJ's US sales grew by 3% but international sales were up 9% in FY2022
# Johnson&Johnson will present itsConsumer Health business financial results as discontinued operations
# JnJ will have $20 billion worth of gains from the Kenvue separation
# Johnson & Johnson received $13.2 billion in cash proceeds from the Kenvue separation.
# Yes, JnJ's net earnings as a percent of sales did increase in Q2 of FY2023 over Q2 of FY2022.
# The Copperate segment had a net loss of 473 million
# If JPMorgan were to liquidate its assets it would deliver $66.56 to each shareholder
# No, JPM's gross margin has not been consistent, as it has average around 78%-82% in the past 8 years
# Consumer & Community Banking
# Yes
# 4.92
# 0.34
# 5,818
# -3.1%
# 302.6
# 1.2%
# Yes. The dividend amount is not changing, and it remains at $0.01 per share annually.
# Vegas Strip Resorts
# The adjusted EBIT to annual interest expense coverage at December 31, 2022 was 1.80x
# MGM China
# Throughout January 1, 2023 to June 30, 2023, the largest percentage of MGM's short-term investment is through a corporate bond that accounts for 81.7% of MGM's short-term investment standing at $416,420 in fair value, making it the highest investment.
# Meet set Wenger's company_ftqb6 In the fiscal year of 2016, The Cost of Goods Sold(COGS) for Microsoft Corporation was $32,780 million
# No
# The FY2015 unadjusted EBITDA margin for Netflix was 4.6%.
# 5466.312
# Balancing quality of the input data against time spent when calculating a smoothed estimate assuming the data is not seasonally affected
# $16,5251 million
# 3.53
# Cash provided (used) by operations :  5,841
# Yes, Paypal does have positive working capital of $5,416 million
# In 2021, PepsiCo's capital expenditure amount is 4.63 in USD billions
# Pepsico operates in Asia Pacific, Australia, New Zealand, China, Africa, the Middle East, South Asia, Europe, and Latin America for the FY2022
# Pepepsico believes that the final outcome of its current litigations will not materially affect its financial statement
# 0
# $5093
# 20.20%
# The shareholder proposal regarding a congruency report on net-zero emissions policies was defeated:For 19,718,780Against 977,228,788
# $400,000,000
# 4,950,000,000
# Due to strong momentum in their different categories and geographical segments Pepsico has raised guidance for full year organic revenue growth to 8% and core constant currency ESP growth to 9%.
# PepsiCo raised its full-year guidance by one percentage point for core constant currency EPS growth
# Yes, between FY20 and FY21, Pfizer's PPNE increased by $2,431.000, from $33,007 to $35,438
# Gain on completion of Consumer Healthcare JV transaction $ (8,107)mil
# Trillium, Array and Therachon
# Pfizer expects to pay USD  700.0 million
# Pfizer's 'Developed Rest of World' division saw the biggest revenue drop for Q22023printwde over year, with a 74% decline
# Yes, Upjohn
# None
# There are no acquisitions in FY 2023 and FY 2022.
# Flow Through
# The $104.2 million increase was  were the opening of 47 new stores since January 29, 2022, inventory to support new brand launches and brand expansions and inventory cost increases.
# 33%
# SG&A expenses increased 16.2% to $2.4 billion compared to $2.1 billion in fiscal
# 2021. As a percentage of net sales, SG&A expenses decreased to 23.5% compared to
# 23.9% in fiscal 2021
# The notional value of Verizon’s cross currency swaps was $32,502 million in 2021, which was 23.74% higher than its notional value of $26,288 million in 2020
# 1.097 million dollars
# Yes, Verizon has a reasonably healthy liquidity profile based on its Quick Ratio for FY 2022, even if it had a lower quick ratio than the last year.
# Yes, it is a capital-intensive business. 3 categories of assets, other than current assets, account for 93% of Total assets
# No, debt as of 2022 is lower than 2021
# 2018-50.58
# -0.2%
# 2.8%
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ft:gpt-3.5-turbo-1106:liangzhang::8bZffxGh
# ft:gpt-3.5-turbo-1106:liangzhang::8bZffxGh
# ft:gpt-3.5-turbo-1106:liangzhang::8bZffxGh
# ft:gpt-3.5-turbo-1106:liangzhang::8bZffxGh
# ft:gpt-3.5-turbo-1106:liangzhang::8bZffxGh
# ft:gpt-3.5-turbo-1106:liangzhang::8bZffxGh
# $1577.00
# $8.7
# Yes, 3M is a capital-intensive business
# Operating margin for 3M dropped to 18.7%, down from 23.4% in 2021. SG&A increased to 25.2% in 2022 from 21.3% in 2021.
# Consumer
# 3M has a quick ratio of 1.4 during Q2 of FY2023.
# The 1.500% Notes due 2026 MMM26 and 1.750% Notes due 2030 MMM30 are registered for trading on the New York Stock Exchange.
# Yes
# 25.62
# 1.8%
# 0.66
# 65.2%
# 0.83
# No, Adobe's operating profile did not improve.
# Yes, Adobe has improved its Free Cash Flow conversion as of FY 2022.
# 0
# Inventory Turnover Ratio is calculated as = Cost of Goods Sold/ Average Inventory. The average inventory is college as the average of the inventory at the beginning and at the end of the year. The cost of sales for the year ended     December 31, 202 is $10,069 million. Giving you the Inventory Turnover Ratio would require the inventory at the beginning of the year which is not available.
# -0.02
# 102.09
# 30.6%
# $11588.00
# $1616.0
# AS DISCLOSED IN THE PREVIOUSLY FILED FORM 8-K AND AS FURTHER DISCLOSED IN THE AMCOR’s FORM 10-K, FILED WITH THE SECURITIES AND EXCHANGE COMMISSION ON AUGUST 5, 2022, the filing was made as part of the Substitution and Assumption of the Guarantor Covenants in the indentures governing the Existing Notes and the New Notes by the Substitute Issuer
# The quick ratio has improved between FY2023 and FY2022. In the years 2022 and 2023, AMCOR's quick ratio is 0.69 and 0.74 respectively.
# AMCOR carried out 3 major acquisition deals during FY2023. The acquisition includes; Acquisition of a Czech Republic based company (the 'Czech Acquisition') for $59M on August 1, 2022, Acquisition of a medical device packaging manufacturing site in Shanghai, China (the 'Shanghai Acquisition') for $60M on March 17, 2023, Acquisition of a New Zealand protein packaging equipment company (the 'Austeville Acquisition') for $45M on May 31, 2023.
# packaging
# No
# AMCOR's restructuring liabilities primarily pertain to:
# - Employee costs
# $2,018 million
# It was 1% down for Flexibles and 1% down for Rigid Packaging
# 4.2%
# Yes
# AMD sells server microprocessors (CPUs) and graphics processing units (GPUs), data processing units (DPUs), Field Programmable Gate Arrays (FPGAs), and Adaptive System-on-Chip (SoC) products for data centers; CPUs, accelerated processing units (APUs) that integrate CPUs and GPUs, and chipsets for desktop and notebook personal computers; discrete GPUs, and semi-custom SoC products and development services; and embedded CPUs, GPUs, APUs, FPGAs, and Adaptive SoC products
# 64% from Data center, 21% from Gaming, and significant xilinx revenue
# Amortization of intangible assets associated with the Xilinx acquisition
# Cash flows from operating activities brought in the most cash for Advanced Micro Devices, Inc. in FY 22
# In FY22 compared to FY21, sales from the Data Center segment increased the most, by 63%
# Yes, for the year ended December 31, 2022, one customer accounted for 16% of AMD's consolidated net revenue.া Sales to this customer consisted of sales of products from AMD's Gaming segment.
# None
# United States, EMEA, APAC, and LACC
# Operating margin has reduced from 25% in 2020 to 18% in 2021 and then has further reduced to 18% in 2022 for Amex
# Net card fees
# The effective tax rate for American Express changed from 24.6% in FY2021 to 21.6% in FY2022, decreasing by 3%.
# Customer deposits
# Yes
# $ 0.39
# $1832.00
# Yes, based on the data for FY2022, American Water Works does have positive working capital. The company's current assets exceed its current liabilities by $561 million.
# 2.7%
# $5409000000.00
# Yes, BBBY's gross margins are historically consistent at 25-26%
# - Current Health Ltd.,
# - Two Peaks, LLC
# Operating activities
# Yes, there is a drop in Cash & Cash equivalents between FY 2023 and Q2 of FY2024
# Yes. There was a net decrease of 13 stores between Q2 of FY2024 and FY2023.
# Entertainment
# 1.73
# 101.5%
# $381.60
# $12,645.00
# No, there are no product categories / service categories that represent more than 20% of Boeing's revenue
# Yes, such legal actions are material to our financial condition and operating results.
# Yes, Boeing has been experiencing an improving gross margin profile.
# The U.S. government
# Yes
# Boeing is forecasting that its 787 program will gradually grow to 5 aircraft per month, and production of the 777X is paused and is expected to resume in 2023.
# The effective tax rate for Boeing in FY2022 was (0.6)% compared to 14.7% in FY2021.
# 0.03
# 39.7%
# 0.79
# 39.13
# 12.5%
# The effective tax rate has decreased from 20% in 2021 to 23% in 2022
# Yes, Corning had a positive working capital of $2,278 million in 2022.
# $59268.00
# 7.50
# Based on FY2022 financials, CVS Health is a capital-intensive business
# The Company agreed to a formal settlement agreement with a leadership group of a number of state Attorneys General and the Plaintiffs’ Executive Committee (“PEC”), the financial amounts of which were agreed to in principle in October 2022.
# No, CVS Health reportedly did not pay any dividends to common shareholders during this period.
# Yes. Foot Locker's new CEO, Mary N. Dillon, has experience as CEO at Ulta Beauty Inc.
# Yes, that nominee would be Richard A. Johnson
# 22.89
# 0.69
# $317.7
# 0.45
# No, JnJ's FY2022 sales increased by 1.3 % as compared to an increase of 13.6% in FY2021
# Higher pharmaceutical sales and reduced intangible asset amortization lowered the gross margin for JnJ to 77.1% in 2022 from 77.5% as of 2021
# Johnson and Johnson's inventory turnover ratio for FY 2022 is 7.62 turns.
# No, the company guides 2023 adjusted operational sales growth excluding COVID-19 Vaccine of 4.0% and adjusted operational EPS of $10.50, reflecting growth of 3.5%*
# JnJ's international sales growth outperformed US sales growth in FY2022
# The Consumer Health Segment
# The amount of the gain accruing to JnJ as a result of the separation of its Consumer Health business segment, as of August 30, 2023 was $20 billion in the third quarter
# $13.2 billion
# Yes, JnJ's net earnings as a percent of sales increased from 20.0% in Q2 of FY2022 to 20.1% in Q2 of FY2023
# Corporate
# Each share with book value of  $66.56.
# Due to JP Morgan being a bank and financial services firm, there are no "gross margins".
# Corporateexpanded名称expanded JPM在2022年第二季度的其业务部门中有最高净收益，较去年同期上升。
# Yes, JPM faced decreased risk in the second fiscal quarter of 2023 compared to the same period in the prior year
# 6.17
# 1.29
# $5,818.00
# -1.2%
# $302.58
# 5.6%
# Yes, MGM Resorts has paid dividends of 0.01 per share.
# The Las Vegas Strip Resorts had the highest EBITDAR Contribution for MGM Resorts during the FY2022
# 1.70
# MGM China
# The corporate bonds had the largest investment among short term investments of MGM Resorts International in H1 FY2023.
# $32,780,000,000.00
# Yes
# 3.9%
# $5,466.31
# 58.0%
# $16,525.00
# 3.35
# Cash provided (used) by operations: $5,841
# No, PayPal has negative working capital
# $4.63
# PepsiCo primarily operates in the United States, Canada, Latin America, Europe, Africa, the Middle East, South Asia, and the Asia Pacific, Australia, and New Zealand, and China region.
# Pepsico does not have any materially important ongoing legal battles from FY2022 and FY2021
# 0
# $6424.00
# 21%
# The shareholder proposal regarding a congruency report on net-zero emissions policies was defeated.
# Pepsico increased its unsecured five year revolving credit agreement by $400,000,000.
# PepsiCo may borrow up to $4,200,000,000 under its unsecured revolving credit agreements as of May 26, 2023.
# PepsiCo raised its full year guidance for FY2023 due to a strong start of the year
# The full year 2023 core constant currency EPS growth guidance was raised by 1% to 9%.
# No, Pfizer did not grow its PPNE from 2020 to 2021
# Yes, there was a non-recurring event. From 2019, Pfizer recognized a gain on completion of Consumer Healthcare JV transaction(functions are now performed by GlaxoSmithKline plc)
# Trillium, Array, Therachon
# $700 million
# In Q22023, developed rest of the world had the largest year over year decline in revenues down by 74%
# Yes, Pfizer is spinning off UpJohn
# None
# Ulta Beauty has made no acquisitions in FY2023 or FY2022, according to 10-K documents.
# Lower marketing expenses and leverage of incentive compensation due to higher sales
# New store openings, inventory to support new brand launches and brand expansions, and inventory cost increases drove the increase in Ulta Beauty's merchandise inventories balance at the end of FY2023.
# 30.0%
# decreased
# Cross currency swaps
# The benefit payments to retirees in 2024 are expected to be $1959 millions
# No, because they barely meet the 1.0 threshold.
# No, Not capital intensive
# Yes, Total long term debt has decreased by $2,749 million (around 1.9%) between 2022 and 2021 fiscal period.
# 101.58
# -0.6%
# 3.6%
