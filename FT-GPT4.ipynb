# %%
from langchain.document_loaders import UnstructuredPDFLoader, PyPDFDirectoryLoader, PyPDFLoader
from langchain.indexes import VectorstoreIndexCreator
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.chains.question_answering import load_qa_chain
import openai
import pandas as pd
import requests
import json
import datetime
import shutil
import os
from datasets import load_dataset
import time

# %%
dataset = load_dataset("PatronusAI/financebench")

# %%
df = pd.DataFrame(dataset['train'])

# %%
OPENAI_KEY = os.getenv('OPENAI_KEY')
openai.api_key = OPENAI_KEY

# %%
OPENAI_KEY

# %%
df.head(2)
# Out:
#          financebench_id     doc_name  \
# 0  financebench_id_03029  3M_2018_10K
# 1  financebench_id_04672  3M_2018_10K
#
#                                             doc_link  doc_period  \
# 0  https://investors.3m.com/financials/sec-filing...        2018
# 1  https://investors.3m.com/financials/sec-filing...        2018
#
#        question_type                                           question  \
# 0  metrics-generated  What is the FY2018 capital expenditure amount ...
# 1  metrics-generated  Assume that you are a public equities analyst....
#
#      answer                                      evidence_text page_number
# 0  $1577.00  Table of Contents \n3M Company and Subsidiarie...          60
# 1     $8.70  Table of Contents \n3M Company and Subsidiarie...          58

# %%
def text_to_openai_json(data,filename):
    """
    Converts a given dataset into a JSON Lines (JSONL) file suitable for OpenAI's GPT-3.5 turbo model.
    
    Args:
        data (DataFrame or similar data structure): Input data containing text and labels.

    The function processes the input data row by row, constructing conversations for each row with a system message, user message, and an assistant message. It then writes the generated conversation data to a JSONL file.
 
    """
    # Initialize an empty list to store conversation data
    message_list = []

    # Iterate through the rows in the input data
    for _, row in data.iterrows():
        # Create a system message as an initial instruction
        system_message = {
            "role": "system",
            "content":  f"You are a factual chatbot that answers questions about 10-K documents. You only answer with answers you find in the text, no outside information. Here is the question {row['question']}." 
        }

        # Append the system message to the conversation
        message_list.append({"messages": [system_message]})

        # Create a user message based on the 'text' column from the data
        user_message = {
            "role": "user",
            "content": row['evidence_text']
        }

        # Append the user message to the conversation
        message_list[-1]["messages"].append(user_message)

        # Create an assistant message based on the 'coarse_label' column from the data
        assistant_message = {
            "role": 'assistant',
            "content": row['answer']
        }

        # Append the assistant message to the conversation
        message_list[-1]["messages"].append(assistant_message)

    # Write the conversation data to a JSON Lines (JSONL) file
    with open(filename, "w") as json_file:
        for message in message_list:
            # Serialize the conversation data to JSON and write it to the file
            json.dump(message, json_file)
            json_file.write("\n")

# %%
df.head(2)
# Out:
#          financebench_id     doc_name  \
# 0  financebench_id_03029  3M_2018_10K
# 1  financebench_id_04672  3M_2018_10K
#
#                                             doc_link  doc_period  \
# 0  https://investors.3m.com/financials/sec-filing...        2018
# 1  https://investors.3m.com/financials/sec-filing...        2018
#
#        question_type                                           question  \
# 0  metrics-generated  What is the FY2018 capital expenditure amount ...
# 1  metrics-generated  Assume that you are a public equities analyst....
#
#      answer                                      evidence_text page_number
# 0  $1577.00  Table of Contents \n3M Company and Subsidiarie...          60
# 1     $8.70  Table of Contents \n3M Company and Subsidiarie...          58

# %%
def fine_tune_model(model_id,num_label,pandas_df):
    df = pandas_df.iloc[:num_label]
    filename = f'ft_increment_{num_label}.jsonl'
    text_to_openai_json(df, filename)
    loader = openai.File.create(file=open(filename, "rb"), purpose='fine-tune')
    fine_tuning_job = openai.FineTuningJob.create(training_file=loader.id, model="gpt-3.5-turbo-1106")
    return fine_tuning_job.id

# %%
def wait_for_fine_tuning(job_id):
    while True:
        response = openai.FineTuningJob.retrieve(job_id)
        print(response["fine_tuned_model"])
        if response["fine_tuned_model"]:
            print(response["fine_tuned_model"])
            return response["fine_tuned_model"]
        time.sleep(30)

# %%
system_content = "You are a factual chatbot that answers questions about 10-K documents. You only answer with answers you find in the text, no outside information."

# %%
df['question']
# Out:
# 0      What is the FY2018 capital expenditure amount ...
# 1      Assume that you are a public equities analyst....
# 2      Is 3M a capital-intensive business based on FY...
# 3      What drove operating margin change as of FY202...
# 4      If we exclude the impact of M&A, which segment...
#                              ...
# 145    Is Verizon a capital intensive business based ...
# 146    Has Verizon increased its debt on balance shee...
# 147    What is FY2018 days payable outstanding (DPO) ...
# 148    Based on the information provided primarily in...
# 149    What is the FY2018 - FY2020 3 year average una...
# Name: question, Length: 150, dtype: object

# %%
def generate_10K_responses(data,model_id):
    syntheses = []
    system_content = "You are a factual chatbot that answers questions about 10-K documents. You only answer with answers you find in the text, no outside information. Here the question : " 
    for idx, row in data.iterrows():
        completion = openai.ChatCompletion.create(
            model= model_id ,
            messages=[
                {"role": "system", "content": system_content + row['question']},
                {"role": "user", "content": row['evidence_text'] }
            ])
        
        #print(f'text: {row}')
        print(completion.choices[0].message.content)
        syntheses.append(completion.choices[0].message.content)
    syntheses_df = pd.DataFrame({'evidence_text': data['evidence_text'], 'answer' : data['answer'], 'syntheses' : syntheses })
    
    return syntheses_df

# %% [markdown]
# # Cosine_Similarity

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def compare_strings(text1, text2):
    vectorizer = TfidfVectorizer()
    vectors = vectorizer.fit_transform([text1, text2])
    # Calculate the cosine similarity between the vectors
    similarity = cosine_similarity(vectors)
    return similarity[0][1]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
def run_cosine_sim(response_df):
    list_of_cosine_similarity = []

    for index, row in response_df.iterrows():
                
        model_response = row['syntheses']
        answer = row['answer']

        sim = compare_strings(answer, model_response)

        #add the similarity to the list
        list_of_cosine_similarity.append(sim)

    #get the average of the similarities
    return sum(list_of_cosine_similarity) / len(list_of_cosine_similarity)

# %% [markdown]
# # Eucliden Distance

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import euclidean_distances

def euclidean_text_distance(text1, text2,vectorizer):
    vectors = vectorizer.fit_transform([text1, text2])
    return euclidean_distances(vectors)[0][1]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

def euclidean_distance(vector1, vector2):
    return np.linalg.norm(vector1 - vector2)

def run_euclidean_distance(response_df):
    euclidean_text_distance_list = []
    
    # Initialize the vectorizer outside the loop
    vectorizer = TfidfVectorizer()

    for index, row in response_df.iterrows():
        model_response = row['syntheses']
        answer = row['answer']
        
        # Convert the response and answer to a TF-IDF matrix
        tfidf_matrix = vectorizer.fit_transform([answer, model_response]).toarray()

        # Calculate the Euclidean distance between the vectors
        distance = euclidean_distance(tfidf_matrix[0], tfidf_matrix[1])

        euclidean_text_distance_list.append(distance)

    # Calculate the average Euclidean distance
    return sum(euclidean_text_distance_list) / len(euclidean_text_distance_list)

# %%
count = 10
model_ids = [] 
label_count = [] 
total_average_cosine_similarities = [] 
total_average_euclidean_distances = []

# %%
for i in range(2):
    count += 10
    label_count.append(count)
    ft_id = fine_tune_model(model_id = 'gpt-3.5-turbo-1106', num_label=count, pandas_df=df)
    if wait_for_fine_tuning(ft_id) is not None:
        model_ids.append(wait_for_fine_tuning(ft_id))
        syntheses_df = generate_10K_responses(data = df, model_id = wait_for_fine_tuning(ft_id))
        syntheses_df.to_csv(f'syntheses_df{count}.csv',index=False)
        #total_average_cosine_similarities.append(run_cosine_sim(syntheses_df))
        #total_average_euclidean_distances.append(run_euclidean_distance(syntheses_df))
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ft:gpt-3.5-turbo-1106:liangzhang::8avWGfwq
# ft:gpt-3.5-turbo-1106:liangzhang::8avWGfwq
# ft:gpt-3.5-turbo-1106:liangzhang::8avWGfwq
# ft:gpt-3.5-turbo-1106:liangzhang::8avWGfwq
# ft:gpt-3.5-turbo-1106:liangzhang::8avWGfwq
# ft:gpt-3.5-turbo-1106:liangzhang::8avWGfwq
# $1,577
# 8.74
# 3M Company is a Capital-Intensive business
# Increased special item costs and investments in key growth initiatives, partially offset by restructuring benefits, led operating margin decrease.
# Safety and Industrial
# No, the quick ratio of 0.78 is below 1 which is lower than desired and indicates poor liquidity.
# In its Q2 of 2023 10-Q, 3M has disclosed that 1.500% Notes due 2026, 1.750% Notes due 2030 and 1.500% Notes due 2031 are registered to be listed on The New York Stock Exchange under the company's ticker symbol 'MMM'.
# Yes.
# 3.02
# 1.7%
# 0.66
# - The unadjusted operating income of Adobe has increased by 65.0 percent
# 0.83
# In FY2022 Adobe's operating margin increased to 34.6% from 36.8% in FY2021.
# Yes. During 2022, the Company converted 33% of its net income to operating cash flows, compared to 29% in 2021.
# 0
# 14.4 times
# N/A
# 110.66
# 30.8%
# 11588
# Amcor's trade receivables net accounts for $1,616.0 in 2020
# AMCOR's (the "Company") two bases have been combined, allowing debt exchange described in a previous filing
# Initial ratio for 2023=0.8 and for 2022=0.8.done
# Amcor has not made any major acquisitions in FY2023 or FY2022.
# AMCOR primarily operates in the packaging industry
# No, for fiscal year 2023 Amcor's gross margins are down YoY
# The unpaid employee-related costs are primarily for severance.
#
# The unpaid fixed asset-related costs are primarily for remediation-related charges
#
# The unpaid other costs included primarily lease and contract termination costs.
# $2,018 million
# Amcor's sales, after excluding the impact of Forex movement, passthrough cost and one of items changed by 1%
# This is 4.2%
# No, as the current liabilities clearly exceed the current assets
# Some of its major offerings are
# 1. server microprocessors (CPUs) and graphics processing units (GPUs)
# 2. CPUs, accelerated processing units (APUs), and chipsets for desktops/notebooks
# 3. discrete GPUs
# 4. semi-custom SoC products and development services
# 5. embedded CPUs, GPUs, APUs, FPGAs, and Adaptive SoC products
# AMD's net revenue for 2022 increased 44% compared to 2021
# The decrease in operating income was driven by higher operating expenses, including R&D and SG&A. The increase in R&D and SG&A expenses was primarily driven by R&D expense associated with Xilinx and higher R&D and SG&A spending in support of transformative growth initiatives, increased hiring, and base salary increases.
# Operating activities.
# Data Center
# Yes, one customer accounted for 16% of AMD's revenue for the fiscal year 2022.
# As of the filing date of 2022, none of American Express' securities are registered to trade on a national securities exchange in its name
# United States, EMEA, APAC, and LACC
# No. The company's operating margin remained almost flat between 20-21
# Gross Margin Increase by 290 basis points to 69.5%, reflecting the growth-driven expansion in the high margin discount revenue, more than offsetting the associated higher costs
# The effective tax rate has decreased by 3% from 24.6% in FY2021 to 21.6% in FY2022
# The largest liability was the Customer Deposits of $110.2 billion
# Yes, the company retained it's Card Members.
# $389.0
# 2,046.0
# Yes, its working capital as of December 31, 2022 is $ (1,561)
# 3.3%
# $5,409
# No, the company's consolidated gross margins have consistently fluctuated (decreasing or increasing) by 2% or more over the years
# In FY2021, Best Buy did not acquire any company
# Operating activities brought in the most cash flow.
# Yes. Cash and cash equivalents dropped from $1,874 M to $1,093 M between FY2023 and Q2 of FY2024
# Yes, the number of Best Buy stores decreased by 23 or 2.5%
# Entertainment - Gaming category performed the best
# 1.73
# 101.3%
# $382 million
# 12,645
# No
# Yes, legal actions have been filed against Boeing as a result of the above mentioned accidents
# Boeing has shown an improving gross margin profile from 2020 to 2022. In 2022, Boeing had a gross margin of 5.248%, up from 5.859% that it achieved in 2021, and the (12.07%) negative gross margin in 2020.
# Boeing derives a significant portion of its revenues from limited number of commercial airlines and the U.S. government. In 2022, 60% of the revenues were earned from the commercial airlines.
# Yes, Boeing's business is subject to cyclicality
# The 787 program is currently producing at low rates and Boeing expects to gradually increase to 5 per month by 2023.
# Boeing's effective tax rate was negative 0.6% in 2022, compared to 14.7% in 2021.
# 1.29%
# 39.7%
# 80.13%
# 54.87
# 14.5%
# Corning's effective tax rate for the 2022 fiscal year was 23%, an increase of 3 percentage points compared to the previous year
# No, Corning has negative working capital of $1422 million based on FY2022 data	false
# $59,268
# 13.32
# CVS Health Inc. is a capital-intensive business, with net property and equipment of $12,873 million.
# Yes. CVS is involved in multiple ongoing legal battles including some related to drug pricing and opioid abuse.
# Yes,--> CVS Health has paid a cash dividend of $0.55 per share on May 3, 2022.
# Yes, Mary Dillon was the former Executive Chair and Chief Executive Officer of Ulta Beauty.
# Yes. Richard A. Johnson received more votes against him than other nominees by a considerable margin
# Negative 7.17
# 0.68
# 1321
# 39.18
# No. They are not
# They were driven up by one-time COVID vaccine-related manufacturing exit costs and commodity inflation in the MedTech and Consumer health segment, offset partially by Supply chain benefits in the Consumer health segment
# 3.0; They sold its inventory three times in FY 2022
# No. Rather, JnJ expects the adjusted EPS to grow at 4.8% in FY2023
# Despite flat international growth, US sales grew by 3.0% and international sales fell by 0.6% in FY 2022
# Consumer Healthcare
# The gain accruing to Johnson & Johnson from the separation of its Consumer Health business segment will be $20 billion.
# $13.2 billion
# Yes, it increased by 0.1%
# The Asset & Wealth Management business segment had the lowest net revenue番場 of -$473mn in Q1 2021
# JPM's total stockholder equity at the end of Q1 was $280B, so each shareholder will get $71.85
# yes, JPM's gross margins have shown annual fluctuations of less than 2%
# Consumer & Community Banking
# Yes
# 6.33
# 0.87
# $5,818.00
# -3.4%
# 302.6
# 3.0%
# No, MGM Resorts did not declare dividends to its common shareholders in the current fiscal year.
# Las Vegas Strip Resort
# 6.0
# Asia-Pacific
# MGM made the largest investment in Level 2 corporate bonds amongst the short term investments
# $ 32,780
# No, between 2023 and 2022, the long-term debt has decreased by $5038 Million
# -8.87%
# 5,466.3
# 57.8%
# 16525
# 3.76
# Nike's operations contributed $5,841 million in cash flow
# As of 2022, the company has positive working capital of $12.42 billion
# $4.63
# Our Operations are structured around seven reportable segments (also referred to as divisions): Frito-Lay North America (FLNA), Quaker Foods North America (QFNA), PepsiCo Beverages North America (PBNA), Latin America, Europe, AMESA (Africa, Middle East and South Asia), and APAC (Asia Pacific, Australia and New Zealand, and China region)
# No
# 0
# 6730
# 21.4%
# Shareholder proposal 7 - Congressi[ on Climate policy [failed]
# PepsiCo incresed the unsecured five year reolving credit agreement by $400,000,000, after it as terminated
# PepsiCo may borrow up to $4,200,000,000 under its new unsecured revolving credit agreement
# This is margin view
# 1%
# Yes, it increased 15%
# Yes, $8.1B of gain on the completion of a Consumer Healthcare JV transaction and $3.5B of other income primarily associated with the sale of the Company’s rights to antibiotic products in certain geographies and the receipt of additional calendar period tax deductions
# Three main acquisitions mentioned by Pfizer:
# - Trillium
# - Array
# - Therachon
# They expect to incur costs of approximately $700 million
# Revenues in "Developed Rest of World" were down 74%
# Yes, including the transaction costs, which are included in Selling, informational and Administrative (SI&A) expenses
# $500 million principal amount of 4.000% Senior Notes due 2031
# In the fiscal year ended 2023, no acquisitions were reported in the statements.
# Leverage of incentive compensation due to higher sales.reshape and footprint optimization.
# The increase was primarily due to the opening of 47 new stores since January 29, 2022, inventory to support new brand launches and brand expansions, and inventory cost increases.
# Approximately 79.6%
# Yes, SG&A expenses decreased from 23.9% to 23.5% of net sales due to leverage of incentive compensation because of higher sales, and lower marking expenses
# $32,502
# 45.0 million
# No, the Quick Ratio for Verizon is 0.52 for FY 2022, which is less than 1, indicating a lower likelihood of financial distress.
# Yes
# The total debt decreased from $150,868 in 2021 to $150,639 in 2022 primarily due to repayment of commercial paper.
# 59.40
# -0.7%
# 3.8%
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ft:gpt-3.5-turbo-1106:liangzhang::8avfpeeD
# ft:gpt-3.5-turbo-1106:liangzhang::8avfpeeD
# ft:gpt-3.5-turbo-1106:liangzhang::8avfpeeD
# ft:gpt-3.5-turbo-1106:liangzhang::8avfpeeD
# ft:gpt-3.5-turbo-1106:liangzhang::8avfpeeD
# ft:gpt-3.5-turbo-1106:liangzhang::8avfpeeD
# $1577.00
# $8.74
# Yes, based of the FY2022 data, 3M company operates a capital-intensive business.
# See above
# Safety and Industrial
# 3M's quick ratio for Q2 FY2023 was 1.51.
# There are 6 securities that are registered under 3M's name, which are as follows:
# 1. Common Stock, Par Value $.01 Per Share
# 2. 1.500% Notes due 2026
# 3. 1.750% Notes due 2030
# 4. 1.500% Notes due 2031
# 3M increased its dividend for the 65th consecutive year.
# 27.16
# 1.7%
# 0.66
# 65.3%
# 0.83
# No, Adobe has not improved on its operating margin between FY2021 and FY2022. It remained fairly fixed at 34.6% for both years.
# Yes!_Adjusted Free cashflow conversion increased from 61% in FY 2021, to 71% in FY 2022!
# 0
# The company sold items present in inventory 9.5 times for the FY2022
# -0.02
# 97.79
# 19.4%
# $11588.00
# 1,615.90
# On June 30, 2022, Amcor Finance (USA), Inc. (the “Former Issuer”) and Amcor Flexibles North America, Inc. (the “Substitute Issuer”)entered into a (i) Second Supplemental Indenture (the “Second SupplementalIndenture”) with the Trustee (as defined below) with respect to the Indenture, dated as of April 28, 2016 (as amended and/or supplemented todate, the “2016 Indenture” and, together with the Second Supplemental Indenture, the “2016 Indenture”), among the Former Issuer, theguarantors party thereto and Deutsche Bank Trust Company Americas, as trustee (the “Trustee”), governing the Former Issuer’s (a) 3.625%Guaranteed Senior Notes due 2026 (the “2026 Notes”) and (b) 4.500% Guaranteed Senior Notes due 2028 (the “2028 Notes” and, together withthe 2026 Notes, the “Existing Notes”) and (ii) First Supplemental Indenture (the “First Supplemental Indenture” and, together with the SecondSupplemental Indenture, the “Supplemental Indentures”) with the Trustee with respect to the Indenture, dated as of June 13, 2019 (as amendedand/or supplemented to date, the “2019 Indenture” and, together withthe First Supplemental Indenture, the “2019 Indenture” and, together withthe 2016 Indenture, the “Indentures”), among the Former Issuer, the guarantors party thereto and the Trustee, governing the Former Issuer’s(a) 3.625% Guaranteed Senior Notes due 2026 (the “New 2026 Notes”) and (b) 4.500% Guaranteed Senior Notes due 2028 (the “New 2028Notes” and, together with the New 2026 Notes, the “New Notes”), in each case, relating to the substitution of the Substitute Issuer for the FormerIssuer and the assumption by the Substitute Issuer of the covenants of the Former Issuer under the Indentures. As disclosed in the Company’sCurrent Report on Form 8-K, filed with the Securities and Exchange Commission (the “SEC”) on June 17, 2019, the New Notes were issued inJune 2019 following the completion of the Former Issuer’s exchange offer to certain eligible holders of the Existing Notes.
# Amcor's quick ratio improved from 0.56 in FY 2022 to 0.61 in FY 2023.
# - On May 31, 2023, acquiring a New Zealand based leading manufacturer of state-of-the-art, automated protein packaging machines at the purchase of $45 million.
#
# - On March 17, 2023, acquiring 100% equity interest in a medical device packaging manufacturing site in Shanghai, China at the purchase consideration of $60 million (consideration includes contingent consideration of $20 million, to be earned and paid in cash over the three years following the acquisition date, subject to meeting certain performance targets).
#
# - On August 1, 2022, acquiring 100% equity interest in a Czech Republic company that operates a world-class flexible packaging manufacturing plant at the purchase consideration of $59 million.
# Amcor operates predominantly in the Flexible packaging industry
# No, AMCOR's gross margin did not increase in 2023. There are more useful metrics to measure the company's success than following gross margin.
# The total liability for restructuring as of Q2 of FY2023 stood at $93M, which reflects the costs related to employee benefits, reduction in fixed assets et c.
# $2,018 million
# Real change in sales increased by 1%.
# 4.2%
# Yes. The quick ratio for AMD for FY22 is 1.45.
# AMD sells a variety of products, including servers, CPU's, GPU's, semi-custon SoC products, and other embedded products
# 64% increase in Data Center segment revenue primarily due to higher sales of EPYC™ server processors, a 21% increase in Gaming segment revenue primarily due to higher semi-custom product sales, and a significant increase in Embedded segment revenue from the prior year period driven by the inclusion of Xilinx embedded product sales.
# The decrease was primarily driven by amortization of intangible assets associated with the Xilinx acquisition
# The most cash AMD brought in FY22 from cash provided (not necessary amount cash inflow) is 3,565 Million ($) from "Operating" activities
# Data Center.
# Yes. One customer accounted for 16% of our consolidated net revenue for the year ended December 31, 2022
# 3.950% senior notes due
# 2023
# 4.625% senior notes due
# 2027
# 0.125% senior notes due
# 2029
# 2.500% senior notes due
# 2030
# The American geography is the largest of American Express's operations
# Yes, American Express' operating profile has generally trended upward with an operating margin of 18.5% in 2022 compared to 17.8% in 2021. This improvement is underpinned by lower card member rewards expendituresourced, enhanced flexibility in marketingand AXP’s continued moves to streamline its cost structure - coupled with a focus on expanding the digital engagement with consumers.
# The change in American Express gross margin percentage for FY2022 was driven by increase in non-interest revenues which isn't a useful or meaningful metric, and doesn't apply for American Express
# In Fiscal Year 2021, its effective tax rate was 24.6%, which decreased by 3% in FY 2022, at 21.6%.
# Customer deposits
# Yes, in 2022, Card Member retention remained high
# 0.4
# $1832.00
# Yes, estimated FY2022 working capital is around $30.2 million for company.
# 3.0%
# $5409.00
# Gross margins haven't been consistent
# In fiscal 2022, Best Buy acquired all of the outstanding shares of Current Health Ltd. for net cash consideration of $389 million on November 2, 2021, and all of the outstanding shares of Two Peaks, LLC on November 4, 2021, for net cash consideration of $79 million
# Operating activities
# No
# Yes, the number of Best Buy stores decreased from 931 at the beginning of Q2 FY2023 to 907 at the end of Q2 FY2024
# Domestic Best Buy sales for the computing and mobile phone down by 6.4%
# 1.74
# 101.2%
# $381.6 USD million
# $12645.00
# Yes. These segments are individually named Commercial Airplanes, Defense Space and Security, and Global Services
# Yes
# No, Boeing's gross margin has significantly improved over FY2022.
# The U.S. Government and Airlines
# Yes, the airline industry is subject to cyclicality
# A gradual increase to 5 per month
# Boeing has an effective tax benefit of 31% in FY 2022. This is a decrease in comparison to FY 2021, when Boeing had an effective tax benefit of 743%.
# 0.04
# 39.8%
# 79.74%
# 159.02
# 15.9%
# The effective tax rate was 23% during FY 2022 and 20% during FY 2021.
# Yes, Corning had positive working capital of $2,278 million on December 31, 2022.
# $59,268.00
# 24.78
# Yes, CVS Health is a Capital-Intensive business based on FY2022 data
# CVS Health has a number of ongoing materially important legal battles, including those resulting from allegations around usual and customary pricing and drug pricing/rebate arrangements. For instance, the Company had to agree to a formal settlement in December 2022 to resolve substantially all opioid claims against Company entities by states and political subdivisions. The maximum amount payable by the Company under the settlement would be approximately $4.3 billion in opioid remediation and $625 million in attorneys' fees and costs and additional remediation, payable over 10 years, beginning in 2023.
# YesCVS has paid dividends to common shareholders.
# Yes, she previously served as CEO of Ulta Beauty, Inc.
# Yes, Richard A. Johnson
# 12.54
# 0.68
# $ 3188.2
# 55.74%
# No. JnJ's sales growth (sales increase of 1.3%) was not like that of a high growth company
# Areas that caused gross margin to drop for JnJ are :
# • One-time COVID-19 vaccine manufacturing exit related costs
# • Currency impacts in the Pharmaceutical segment
# • Commodity inflation in the MedTech and Consumer Health segments
# 3.02, Inventory Turnover Ratio
# No
# JnJ's international sales grew at a higher rate than JnJ's US sales in FY2022.
# The Consumer Health business
# $20 billion
# Johnson & Johnson (NYSE: JNJ) secured $13.2 billion in cash proceeds from the Kenvue debt offering and initial public offering.
# Largely unchanged
# Corporate
# $ 66.56
# No, gross margins are not a relevant metric for a company like JPM because it is a financial services (multiple) business model.
# Consumer & Community Banking
# Yes, the average total VaR decreased by $7 million for the three months ended June 30, 2023, compared with the same period in the prior year
# 8.91
# 1.3
# $5,818.0
# -2.1%
# $302.58
# 4.5%
# Yes, we paid a dividend of $0.01 per share as part of our common stock dividends promised in FY2022.
# Las Vegas Strip Resorts
# 1.8
# The worst-performing region is "MGM China", showing an 44% topline decline.
# Commercial paper and certificates of deposit
# $32780.00
# No
# 8%
# $5466.31
# 59.2%
# $16525.00
# 3.10
# Operations
# Paypal does not use this metric to evaluate the cash generation capabilities or bankruptcy risk of the company. The company has a history of receiving money from customers before needing to pay charges from merchants. They also mentioned in the past that they have not focused their efforts to use working capital as a tool for liquidity risk management.
# $4.63
# Pepsico serves customers and consumers in more than 200 countries and territories.
# Pepsico does not believe they will face any materially adverse effects from their ongoing legal battles, and does not anticipate obligations as a result of these.
# 0
# $12850.00
# 23.4%
# Proposal defeated with 97.9% votes against
# $400,000,000
# PepsiCo may borrow a total of up to $4200000000 under  its new 364-day revolving credit agreement
# Pepsico increased their full-year 2023 guidance because they are expecting a higher organic revenue and an increase in EPS. The Chairman and CEO believes that due to result of strong performance this increase has occured.
# PepsiCo announced an increase by 1 pct point
# Yes
# Yes. The completion of Pfizer's Consumer Healthcare JV transaction substantially increased net income by $8.1 billion in 2019
# Trillium, Array, Therachon
# $700款million
# Developed Rest of World. There was a 74% year over year revenue fall in the Q22023.
# Yes. Pfizer is separating their Upjohn business segment.
# None
# No acquisitions were made by Ulta Beauty in FY2023 and FY2022.
# Lower marketing expenses and leverage of incentive compensation they due to higher sales
# The increase was primarily due to the opening of 47 new stores since the end of fiscal 2022, inventory to support new brand launches and brand expansions, and inventory cost increases.
# 76.8%
# Decreased
# Cross currency swaps
# $1959mn
# Yes, Verizon Communications Inc. has a reasonably healthy liquidity profile with a quick ratio of 1.17 at December 31, 2022.
# Yes, Verizon operates in a capital intensive business
# No, Verizon's long-term debt has decreased by $2749mm between fiscal year 2021 and 2022.
# 87.99
# 0.2%
# 4.0%
