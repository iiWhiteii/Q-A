# %%
from langchain.document_loaders import UnstructuredPDFLoader, PyPDFDirectoryLoader, PyPDFLoader
from langchain.indexes import VectorstoreIndexCreator
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.chains.question_answering import load_qa_chain
import openai
import pandas as pd
import requests
import json
import datetime
import shutil
import os
from datasets import load_dataset
import time

# %%
dataset = load_dataset("PatronusAI/financebench")

# %%
df = pd.DataFrame(dataset['train'])

# %%
OPENAI_KEY = os.getenv('OPENAI_KEY')
openai.api_key = OPENAI_KEY

# %%
OPENAI_KEY
# Out:
# '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'

# %%
df.head(2)
# Out:
#          financebench_id     doc_name  \
# 0  financebench_id_03029  3M_2018_10K
# 1  financebench_id_04672  3M_2018_10K
#
#                                             doc_link  doc_period  \
# 0  https://investors.3m.com/financials/sec-filing...        2018
# 1  https://investors.3m.com/financials/sec-filing...        2018
#
#        question_type                                           question  \
# 0  metrics-generated  What is the FY2018 capital expenditure amount ...
# 1  metrics-generated  Assume that you are a public equities analyst....
#
#      answer                                      evidence_text page_number
# 0  $1577.00  Table of Contents \n3M Company and Subsidiarie...          60
# 1     $8.70  Table of Contents \n3M Company and Subsidiarie...          58

# %%
def text_to_openai_json(data,filename):
    """
    Converts a given dataset into a JSON Lines (JSONL) file suitable for OpenAI's GPT-3.5 turbo model.
    
    Args:
        data (DataFrame or similar data structure): Input data containing text and labels.

    The function processes the input data row by row, constructing conversations for each row with a system message, user message, and an assistant message. It then writes the generated conversation data to a JSONL file.
 
    """
    # Initialize an empty list to store conversation data
    message_list = []

    # Iterate through the rows in the input data
    for _, row in data.iterrows():
        # Create a system message as an initial instruction
        system_message = {
            "role": "system",
            "content":  f"You are a factual chatbot that answers questions about 10-K documents. You only answer with answers you find in the text, no outside information." 
        }

        # Append the system message to the conversation
        message_list.append({"messages": [system_message]})

        # Create a user message based on the 'text' column from the data
        user_message = {
            "role": "user",
            "content": f"{row['evidence_text']} based on {row['question']}  "
        }

        # Append the user message to the conversation
        message_list[-1]["messages"].append(user_message)

        # Create an assistant message based on the 'coarse_label' column from the data
        assistant_message = {
            "role": 'assistant',
            "content": row['answer']
        }

        # Append the assistant message to the conversation
        message_list[-1]["messages"].append(assistant_message)

    # Write the conversation data to a JSON Lines (JSONL) file
    with open(filename, "w") as json_file:
        for message in message_list:
            # Serialize the conversation data to JSON and write it to the file
            json.dump(message, json_file)
            json_file.write("\n")

# %%
df.head(2)
# Out:
#          financebench_id     doc_name  \
# 0  financebench_id_03029  3M_2018_10K
# 1  financebench_id_04672  3M_2018_10K
#
#                                             doc_link  doc_period  \
# 0  https://investors.3m.com/financials/sec-filing...        2018
# 1  https://investors.3m.com/financials/sec-filing...        2018
#
#        question_type                                           question  \
# 0  metrics-generated  What is the FY2018 capital expenditure amount ...
# 1  metrics-generated  Assume that you are a public equities analyst....
#
#      answer                                      evidence_text page_number
# 0  $1577.00  Table of Contents \n3M Company and Subsidiarie...          60
# 1     $8.70  Table of Contents \n3M Company and Subsidiarie...          58

# %%
def fine_tune_model(model_id,num_label,pandas_df):
    df = pandas_df.iloc[:num_label]
    filename = f'ft_increment_{num_label}.jsonl'
    text_to_openai_json(df, filename)
    loader = openai.File.create(file=open(filename, "rb"), purpose='fine-tune')
    fine_tuning_job = openai.FineTuningJob.create(training_file=loader.id, model="gpt-3.5-turbo-1106")
    return fine_tuning_job.id

# %%
def wait_for_fine_tuning(job_id):
    while True:
        response = openai.FineTuningJob.retrieve(job_id)
        print(response["fine_tuned_model"])
        if response["fine_tuned_model"]:
            print(response["fine_tuned_model"])
            return response["fine_tuned_model"]
        time.sleep(30)

# %%
system_content = "You are a factual chatbot that answers questions about 10-K documents. You only answer with answers you find in the text, no outside information."

# %%
df['question']
# Out:
# 0      What is the FY2018 capital expenditure amount ...
# 1      Assume that you are a public equities analyst....
# 2      Is 3M a capital-intensive business based on FY...
# 3      What drove operating margin change as of FY202...
# 4      If we exclude the impact of M&A, which segment...
#                              ...
# 145    Is Verizon a capital intensive business based ...
# 146    Has Verizon increased its debt on balance shee...
# 147    What is FY2018 days payable outstanding (DPO) ...
# 148    Based on the information provided primarily in...
# 149    What is the FY2018 - FY2020 3 year average una...
# Name: question, Length: 150, dtype: object

# %%
def generate_10K_responses(data,model_id):
    syntheses = []
    system_content = "You are a factual chatbot that answers questions about 10-K documents. You only answer with answers you find in the text, no outside information." 
    for idx, row in data.iterrows():
        completion = openai.ChatCompletion.create(
            model= model_id ,
            messages=[
                {"role": "system", "content": system_content},
                {"role": "user", "content": f"{row['question']} based on {row['evidence_text']}" }
            ])
        
        #print(f'text: {row}')
        print(completion.choices[0].message.content)
        syntheses.append(completion.choices[0].message.content)
    syntheses_df = pd.DataFrame({'evidence_text': data['evidence_text'], 'answer' : data['answer'], 'syntheses' : syntheses })
    
    return syntheses_df

# %%
count = 0
label_count = [] 
total_average_cosine_similarities = [] 
total_average_euclidean_distances = [] 
model_ids = []

# %%
for i in range(5):
    count += 10
    label_count.append(count)
    ft_id = fine_tune_model(model_id = 'gpt-3.5-turbo-1106', num_label=count, pandas_df=df)
    if wait_for_fine_tuning(ft_id) is not None:
        model_ids.append(wait_for_fine_tuning(ft_id))
        syntheses_df = generate_10K_responses(data = df, model_id = wait_for_fine_tuning(ft_id))
        syntheses_df.to_csv(f'syntheses_df{count}.csv',index=False)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ft:gpt-3.5-turbo-1106:liangzhang::8b9gm403
# ft:gpt-3.5-turbo-1106:liangzhang::8b9gm403
# ft:gpt-3.5-turbo-1106:liangzhang::8b9gm403
# ft:gpt-3.5-turbo-1106:liangzhang::8b9gm403
# ft:gpt-3.5-turbo-1106:liangzhang::8b9gm403
# ft:gpt-3.5-turbo-1106:liangzhang::8b9gm403
# $1577
# $8.98
# No. The business is not very capital intensive as indicated by following data:
# 1. Capital Expenditure for 2022 is $ 1,749 million
# 2. Property, Plant, and Equipment: $9,178 million
# Operating margin decline in 2022 was mainly due to a pre-tax charge primarily related to Combat Arms Earplugs litigation, impairment costs related to exiting PFAS manufacturing, costs related to exiting Russia, and divestiture-related restructuring charges.
# The Consumer segment shrunk by 0.9% organically.
# No, the quick ratio is not an appropriate measure of liquidity for 3M as the company's current liabilities include a significant amount of long-term debt that is not due within the next 12 months.
# 1.500% Notes due 2026 (Trading Symbol: MMM26, New York Stock Exchange)
# 1.750% Notes due 2030 (Trading Symbol: MMM30, New York Stock Exchange)
# 1.500% Notes due 2031 (Trading Symbol: MMM31, New York Stock Exchange)
# No
# 24.27
# 1.9%
# 0.66
# 210.4%
# 1.06
# Yes, the company's operating margin has expanded from 2021 to 2022, from 36.8% to 34.6%
# Yes. The Free cashflow conversion of Adobe has improved to 37% in FY2022 from 33% in FY2021.
# $0
# 15.96; No, Conventional inventory management is not meaningful for the company because a significant portion of its revenue comes from services and as a result, it does not need to maintain significant inventory.
# -0.01
# 61.83
# 21.3%
# $11,587
# $1,615.9
# The execution of supplemental indentures for the substitution of the Substitute Issuer for the Former Issuer and the assumption by the Substitute Issuer of the covenants of the Former Issuer under the Indentures
# Yes, it has improved.
# - August 2022: Czech Republic company's equity
# - March 2023: medical device packaging manufacturing site in Shanghai, China
# - May 2023: New Zealand based leading manufacturer of state-of-the-art, automated protein packaging machines
# Packaging
# No, Gross margins have actually contracted from 21.1% in 2022 to 18.5% in 2023
# Restructuring cost liabilities are primarily associated with employee-related costs, including severance and other termination benefits. Other costs include site closure and other related costs.
# $2,117 million
# $435mn
# 4.2%
# No, AMD's quick ratio is 0.98 for FY22, hence it does not meet the ideal threshold of 1, indicating that its liquidity position is not strong enough.
# You are a global semiconductor company known for offering:
# • server microprocessors (CPUs) and graphics processing units (GPUs), data processing units (DPUs), Field Programmable Gate Arrays (FPGAs), and Adaptive System-on-Chip (SoC) products for data centers;
# • CPUs, accelerated processing units (APUs) that integrate CPUs and GPUs, and chipsets for desktop and notebook personal computers;
# • discrete GPUs, and semi-custom SoC products and development services; and
# • embedded CPUs, GPUs, APUs, FPGAs, and Adaptive SoC products.
# Data Center segment revenue primarily due to higher sales of the EPYC™ server processors, a 21% increase in Gaming segment revenue primarily due to higher semi-custom product sales, and a significant increase in Embedded segment revenue from the prior year period driven by the inclusion of Xilinx embedded product sales.
# Operating margin is not a useful metric for AMD as operating income for FY22 was impacted by a significant one-time expense, i.e. amortization of intangible assets associated to Xilinx acquisition
# Operating activities brought in the most cash for AMD.
# The Gaming segment
# Yes
# American Express has the following debt securities registered:
# Title of each class: 1.650% Notes due 2023
#                             1.900% Notes due 2028
#                             4.000% Notes due 2068
#                             3.125% Notes due 2025
#                             3.300% Notes due 2027
#                             2.500% Notes due 2024
# United States, EMEA, APAC, LACC
# Yes, The operating margin of AMEX has improved in 2022 to 19.53% from 17.89% in 2021 and 16.92% in 2020.
# The change in gross margin of American Express is primarily attributable to an increase in card member rewards.
# 21.6%
# Customer deposits, at $110,239 million
# Yes
# $0.389 billions
# $1832
# No, American Water Works Company has negative working capital based on FY2022 data.
# 3.3%
# $5409
# No, they aren't; Gross margins have fluctuated more than 2% recently:
# 2023: 21.4%
# 2022: 22.5%
# 2021: 22.3%
# You seem like you're looking for these acquisitions:
# -Current Health Ltd.
# -Two Peaks, LLC d/b/a Yardbird Furniture
# Operating activities: $1,824 (millions)
# Yes, by $781 between FY 2023 and Q2 of FY2024
# Yes. Between Q2 FY2023 and Q2 FY2024, Best Buy had a net decrease of 13 stores.
# Entertainment
# 1.73
# 99.8%
# $3816.03
# $12,645
# No, None of the product categories / service categories represent more than 20% of Boeing's revenue for FY2022
# Yes, they have reported multiple legal actions resulting from the mentioned accidents.
# No. The gross margin has rather deteriorated from 2021 to 2022. In 2021 it was $3,332 million, while in 2022, it stands at $3,502 million.
# American Airlines, Delta, & Southwest Airlines
# Yes, and this cyclicality in the industry has had significant impact on the financial performance of Boeing
# Boeing is planning to:
# -Gradually increase the 787 production to 5 per month in 2023.
# -Resume the 777X production in 2023.
# The effective tax rate was a benefit of 0.6% in FY2022 compared with an expense of 14.7% in FY2021.
# 0.05
# 39.7%
# 54.96%
# 36.89
# 16.0%
# The effective tax rate of Corning has decreased from 23% to 20%
# No, Corning doesn't have positive working capital; It's working capital is negative 722 million.
# $59,268
# 0.65
# No. The business is not capital intensive.
# The Company and certain current and former directors and officers are named as a defendant in a number of lawsuits that allege that the Company’s retail
# pharmacies overcharged for prescription drugs by not submitting the correct usual and customary price during the claims adjudication process.
#
# In December 2022, the Company agreed to a formal settlement agreement, the financial amounts of which were agreed to in principle in October 2022, with a
# leadership group of a number of state Attorneys General and the Plaintiffs’ Executive Committee (“PEC”). The agreement would resolve substantially all
# opioid claims against Company entities by states and political subdivisions, but not private plaintiffs. The maximum amount payable by the Company under the
# settlement would be approximately $4.3 billion in opioid remediation and $625 million in attorneys’ fees and costs and additional remediation. The amounts
# would be payable over 10 years, beginning in 2023.
# Yes, the date of record for the quarterly dividend of $0.50 per common share was June 22, 2022.
# Yes, she was the CEO of Ulta Beauty, Inc.
# Yes, Richard A. Johnson had substantially more votes against joining than the other nominees
# -35.45
# 0.68
# $3192.1
# 0.29
# No. The growth in 2022 was primarily due to volume. The company's sales declined due to currency in 2022, unlike 2021 when currency had a positive impact
# Change in mix of products sold
# Inventory turnover ratio is 7.6 times.
# No, JnJ's adjusted EPS growth is expected to decelerate in FY2023
# In FY2022, international sales grew by 9.1% on an operational basis, whereas US sales grew by 3.0% on an operational basis.
# Consumer Health Business
# $20 billion
# $13.2 billion
# Yes, by 0.1%
# The Corporate segment
# $99.84
# No, based on the following data, JPM's gross margins have not been consistent and have fluctuated by more than 2%:
# 2022: 53%
# 2021: 54%
# 2020: 54%
# The Corporate segment had the highest net income
# No, it increased by $18 million
# 6.15
# 1.35
# $5,818
# -0.7%
# $302.6
# 1.7%
# Yes, $0.01 per share
# Las Vegas Strip Resorts
# 6.16
# MGM China
# Corporate bonds with fair value level 2 comprises the largest portion of MGM's short term investments, which are categorized as debt investments.
# $17,880
# No, the long-term debt has decreased from $47,032 Million in 2022 to $41,990 Million in 2023.
# 4.5%
# $5,466.3
# 17.5%
# $16,525
# 3.57
# Operating activities brought in $5,841 million cash flow for Nike in FY2023, more than the other 2 activities.
# Yes, PayPal has a positive working capital of $12,416 M at the end of FY2022.
# $4.63
# PepsiCo primarily operates in the following geographies:
# -United States and Canada
# -Latin America
# -Europe
# -Africa, the Middle East, and South Asia
# -Asia Pacific, Australia, New Zealand, and China
# No, PepsiCo has stated that it does not believe any of the ongoing litigation, claims, legal or regulatory proceedings, inquiries and investigations will have a material adverse effect.
# $0.4 billion
# $9234
# 11.7%
# The shareholder proposal regarding a congruency report on net-zero emissions policies was defeated:
# For
# 19,718,780
# Against
# 977,228,788
# Pepsico may increase the commitments under the 2023 Five Year Credit Agreement to up to $4,950,000,000
# $4,200,000,000
# Given their strong start to the year and robust business momentum
# 1%
# Yes, it increased from 35,067 to 59,693
# Yes, the gain on the completion of the Consumer Healthcare JV transaction of $8,107 in 2019 substantially increased the net income for the year.
# - Trillium
# - Array
# - Therachon
# $700
# The developed rest of world region had the biggest drop with a 74% change
# Yes, the company previously announced its plans to spin off its off-patent branded and generic established medicines business, Upjohn, through a proposed combination with Mylan N.V.
# None. Ultamately no debt securities are registered as of FY2023.
# Acquisitions, net of cash acquired:
# $0
# $0
# ($1,220)
# The reduction in marketing expenses and leverage of incentive compensation due to higher sales
# The opening of 47 new stores since January 29, 2022, inventory to support new brand launches and brand expansions, and inventory cost increases.
# 14.9%
# SG&A expenses as a percentage of net sales decreased to 23.5% compared to 23.9% in fiscal 2021
# Cross currency swaps. The notional amount for Cross currency swaps was $32,502 at December 31, 2021.
# $1,959
# No, the quick ratio is not relevant to measure the liquidity of Verizon. In this case, the quick ratio is not relevant to measure the liquidity position as Verizon's primary operating asset, i.e., Wireless licenses, are not included in current assets, which are relatively liquid.
# Yes. The company has investments in unconsolidated businesses, wireless licenses, goodwill, other intangible assets, and operating lease right-of-use assets. Additionally, significant portion of revenue comes from wireless and wireline operations which are generally capital intensive.
# No, it has decreased by $2,749.
# 105.81
# 4.0%
# 7.3%
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ft:gpt-3.5-turbo-1106:liangzhang::8b9nllqh
# ft:gpt-3.5-turbo-1106:liangzhang::8b9nllqh
# ft:gpt-3.5-turbo-1106:liangzhang::8b9nllqh
# ft:gpt-3.5-turbo-1106:liangzhang::8b9nllqh
# ft:gpt-3.5-turbo-1106:liangzhang::8b9nllqh
# ft:gpt-3.5-turbo-1106:liangzhang::8b9nllqh
# $1,577
# $8.7 billions
# Yes, 3M is a capital-intensive business. The company needs to spend a considerable amount on property, plant, and equipment. The company uses the cash from the operations for purchasing the property and plant equipment.
# 3M's Operating Margin decreased from 22.6% in 2021 to 20.3% in 2022. The decline was mainly due to an increase in SG&A costs driven by several one-time adjustment items that were recovered well by restructuring initiatives and cost management.
# Consumer segment dragged down in 2022
# It is not relevant to measure liquidity as it is a measure of solvency and not liquidity based on the US GAAP.
# 1.500% Notes due 2026 MMM26 New York Stock Exchange
# 1.750% Notes due 2030 MMM30 New York Stock Exchange
# 1.500% Notes due 2031 MMM31 New York Stock Exchange
# Yes
# 22.45
# 1.2%
# 0.66
# 65.4%
# 0.83
# No, Adobe's operating margin profile has not improved significantly in FY2022, as the detailed operating margin in 2022, 2021 and 2020 has been 34.6%, 36.8% and 32.9% respectively
# No, Adobe's free cashflow conversion has improved from 80.4% to 100.9%
# 0
# AES Corporation sold its inventory 16.1 times in FY2022.
# Inventory Turnover = Cost of Goods Sold / Average Inventory = $10,069 / (($1,055+$604)/2)=16.1 times
# -0.02
# 77.44
# 30.9%
# 11588
# The net Accounts Receivable as at June 30, 2020 is 1,615.9 million USD
# The key agenda of the 8k filing was to convey the substitution of the Former Issuer by the Substitute Issuer and the assumption by the Substitute Issuer of the covenants of the Former Issuer under the Indentures.
# The quick ratio has improved from 1.15x in FY2022 to 1.19x in FY2023.
# 1. Czech Republic - August 1, 2022 for $59 million
# 2. Shanghai, China - March 17,2023 for $60 million
# 3. New zealand - May 31, 2023 for $45 million
# The industry is packaging products
# No, Gross margin has been deteriorating.6036398467432957% for 2023.6899602194783385% for 2022.6731543143757232% for 2021.
# to restructure the Flexibles and Rigid Plastics operating segments.
# $2,117 million
# $ million -42
# 4.2%
# The quick ratio is a measure not commonly used to evaluate a company's liquidity. Financial analysts usually rely on the current ratio because it is a more inclusive measure of a company's liquidity position.
# AMD sells:
# - server microprocessors (CPUs) and graphics processing units (GPUs), data processing units (DPUs), Field Programmable Gate Arrays (FPGAs), and Adaptive System-on-Chip (SoC) products for data centers;
# - CPUs, accelerated processing units (APUs) that integrate CPUs and GPUs, and chipsets for desktop and notebook personal computers;
# - discrete GPUs, and semi-custom SoC products and development services; and
# - embedded CPUs, GPUs, APUs, FPGAs, and Adaptive SoC products.
# The increase in net revenue was driven by a 64% increase in Data Center segment revenue primarily due to higher sales of our EPYC™ server processors, a 21% increase in Gaming segment revenue primarily due to higher semi-custom product sales, and a significant increase in Embedded segment revenue from the prior year period driven by the inclusion of Xilinx embedded product sales.
# Because of one-time items such as a foreign exchange gain or loss the operating margin is not a meaningful indicator of the company's performance
# Operating activities brought in the most cash for AMD in FY22, contributing to a net increase in cash and cash equivalents of $2,300.
# The proportionately most increasing segment is "Data Center"
# Yes! One customer accounted for 16% of our consolidated net revenue
# None
# United States (US), Europe/Middle East/Africa (EMEA), Asia Pacific (APAC), Latin America/Canada (LACC)
# yes
# Card member rewards expenses increased primarily due to higher Card Member spending and higher associated rewards payouts relative to the prior year. Additionally, salaries and employee benefits increased primarily due to higher salaries and benefit costs. As the revenues, margins and prices in financial institutions depend on interests, fees and their respective pricing; more than one metric should be used to explain their financial performance, rather than providing precedence to gross margin.
# The effective tax rate for American Express was 24.6% in 2021 and 21.6% in 2022.
# Customer deposits $ 110,239
# Yes, it was able to retain card members
# $389.00
# $1,832 million
# No, it is negative by $1,561. The company does not use the working capital metric and considers any short-term debt used to fund long-term investments as base maturing before it is due.
# 3.6%
# $5,409.00
# No, they have been fluctuating each year by roughly within 2%
# In fiscal 2022, Best Buy acquired all of the outstanding shares of Current Health Ltd. and Two Peaks, LLC d/b/a Yardbird Furniture.
# Best Buy gained the most cash from operating activities. Additionally, there was a loss in cash from investing activities but it was less than the cash flow lost in financing activities.
# Net cash flow from operations:
# 2023: $1,824
# 2022: $3,252
# 2021: $4,927
# Net cash flow from investing activities:
# 2023: ($962)
# 2022: ($1,372)
# 2021: ($788)
# Net cash flow from financing activities:
# 2023: ($1,806)
# 2022: ($4,297)
# 2021: ($876)
# Yes, Cash & Cash equivalents Dropped by $781 from FYE2023 to Q2 FY2024
# The total number of Best Buy stores decreased from 931 at the beginning of the second quarter of FY2023 to 907 at the beginning of the second quarter of FY2024
# Entertainment
# 1.73
# 101.1%
# $381,603.
# 12,645
# No, there is no such category
# Yes, we are exposed to ongoing legal and third-party claims related to the 737 MAX grounding, termination of the American Airlines contract and other losses deriving from these issues.
# No, Boeing's gross margin showed some near-term pressures, due to timing of production costs. However, gross margins isn't the best measure for a company like this that engages in the manufacture, rather than sale, of goods, and involves long-term contracts which are substantial outlays of cash initially, with recovery over the life of the contracts.
# American Airlines, Delta, United, Southwest, Ryanair and Lufthansa._PRIMARY_CUSTOMERS_FINANCEBENCH_DELIMITER___DoD, NASA, NSA__, and ___United States government.PRIMARY_CUSTOMERS_FINANCEBENCH_DELIMITER___United States Department of Defense, comprising the U.S. Army, U.S. Navy, U.S. Air Force and ospitality._PLAIN_TEXT_DELIMITER___U.S. government contracting agencies.
# Yes, it is.
# Boeing expects to gradually increase the 787 program to 5 per month, among other changes.
# Boeing's effective tax rate in FY2022 is -0.6% as compared to 14.7% in FY2021
# 0.02
# 39.7%
# 0.80
# 92.56
# 14.5%
# The effective tax rate of Corning has increased from 20% in FY2021 to 23% in FY2022.
# No, the company has negative working capital of $(4,722) for FY2022.
# $59268
# 16.55
# No, the business is not capital-intensive because it's working capital is largely financed by creditors and from its inefficent use of external capital (negative free cash flow )
# The company is able to pay it's short term obligations with its working capital, but it is inefficient in utilising its working capital
# Total liabilities $ 180,879 $ 187,937
# Net Working Capital $ 34,803 $ 29,288
# capex - 4,045
# free cash flow = -1,898
# Yes, CVS Health is involved in the following ongoing legal battles:
#   1. Claims adjudication cases,
#   2. Drug pricing and rebate arrangements lawsuits,
#   3. Opioid claims against Company details
# Yes, CVS Health paid dividends of $0.50 per share in Q2 of FY2022.
# Yes, Mary Dillon was previously the CEO and Executive Chair of Ulta Beauty, Inc.
# Yes, Richard A. Johnson received 16,105,005 votes against joining, representing around 22.8% of the votes.
# -35.44
# 0.68
# $405.4
# 0.63
# No, JnJ's 2022 revenue grew by 1.3% down from a growth of 13.6% in the prior year (2021). Organic volume growth slowed from ~13% in 2021 to 6.9% in 2022, but this was partially offset by pricing decreases. Forex was a –6% headwind in 2022, reversing from being a 1.4% tailwind in 2021.
# Cost of products sold increased by 0.7 percentage points as a percent to sales driven by:
# Inventory turnover = Cost of goods sold / Average Inventory
# No
# US sales showed positive growth in FY2022 while international sales declined.
# Johnson & Johnson’s consumer health business will be treated as a discontinued operation.
# $20 billion
# $13.2 billion
# Yes, by 0.1%
# Corporate had the lowest net revenue in 2021 Q1
# $66.56
# Not a relevant metric; The Firm's gross margins are not very consistent, but this is understandable as the Firm operates in multiple financial sectors like investment banking, financial services, commercial banking, financial transaction processing and asset management, with differing margin profiles.
# Corporate had the highest net income with $8.6 billion.
# Yes, the average total VaR decreased by $7 million for the three months ended June 30, 2023, compared with the same period in the prior year. This was predominantly driven by risk reductions impacting Credit Portfolio VaR as well as fixed income
# 6.19
# 1.32
# $5,818 million
# -3.5%
# $302579000
# 2.9%
# Yes, MGM Resorts has maintained an annual dividend of $0.01 per share throughout 2022.
# Las Vegas Strip Resorts
# 1.8
# MGM China
# Corporate bonds of $416,420
# 32,780
# Long-term debt decreased by $5,042 million, or 11%
# The FY2015 unadjusted EBITDA margin for Netflix is 4.3%, calculated as: Unadjusted EBITDA / Revenue
#
# Unadjusted operating income for Netflix in FY2015 is approximately $305,826,000
# Streaming content amortization and DVD content amortization total approximately $3,484,762,000
#
#  The Sum, (D&A + Unadjusted operating income) is approximately 3,790,588,000, and when it is divided by total revenue, (6,779,511,000), we get the EBITDA margin.
# $5,466.3 million
# 62.9%
# 16,525
# 3.58
# The most is cash come from the operations.
# Nike has produced cash from operations of $5,841
# brought in $564 via investing.
# Whereas, from financial activities, a loss of ($7,447) cash was observed.
# No, PayPal has positive working capital of $12,416 million as of December 31, 2022.
# $4.6B
# PepsiCo operates in more than 200 countries and territories, and organized into the following reportable segments: Frito-Lay North America, Quaker Foods North America, PepsiCo Beverages North America, Latin America, Europe, Africa, Middle East and South Asia and Asia Pacific, Australia and New Zealand and China Region.
# No, the company believes the final outcome will not have a material adverse effect on its results.
# 0
# Unadjusted EBITDA less capex for FY2022 for PepsiCo is $5,115. Answer in USD millions.
# 16.2%
# The shareholder proposal regarding a congruency report on net-zero emissions policies was defeated:
# For
# 19,718,780
# Against
# 977,228,788
# $400,000,000
# $4,200,000,000
# Pepsico raised its guidance for the full year of 2023 based on a solid start to the year and strong performance during the quarter.
# 1%
# Yes, Pfizer did grow its "property, plant and equipment" from $13,745 million to $14,882 million between FY20 and FY21
# The $8.1 billion gain on completion of the Consumer Healthcare JV transaction in 2019 has greatly increased Pfizer's net income in 2019.
# Array, Trillium and Therachon
# $630 million
# Drop in Developed Rest of World was the biggest by 74%
# Yes. Pfizer is spinning off Upjohn.
# None
# Ulta Beauty did not make any major acquisitions in FY2023 and FY2022.
# Reduction in marketing expesenses and incentive compensations led to a decrease in SG&A as a percent of net sales by 0.4%
# The increase in merchandise inventories, primarily due to the opening of 47 new stores since January 29, 2022, inventory to support new brand launches and brand expansions, and inventory cost increases.
# 7.3%
# Decrease
# Cross currency swaps
# Verizon estimated about $1,097M for its retirees in 2024
# No, it has decreased from 0.78 to 0.76
# Yes, Verizon appears to be a capital intensive business. Verizon's capital expenditure in the year 2022 was $18.4 billion, and this was financed through a combination of cash from operations, existing cash on hand, debt issuances and maturities, including commercial paper. Verizon spent 13.5% of all its revenues in FY 2022 in Capex
# __,_EBITDA was 42.2% of revenues in FY 2022__. Verizon also reported capital expenditures of $18.4 billion in FY 2022.
# No, the total debt has decreased from $150,868 in 2021 to $150,639 in 2022
# 123.45
# 0.6%
# 3.3%
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ft:gpt-3.5-turbo-1106:liangzhang::8b9vBcCC
# ft:gpt-3.5-turbo-1106:liangzhang::8b9vBcCC
# ft:gpt-3.5-turbo-1106:liangzhang::8b9vBcCC
# ft:gpt-3.5-turbo-1106:liangzhang::8b9vBcCC
# ft:gpt-3.5-turbo-1106:liangzhang::8b9vBcCC
# ft:gpt-3.5-turbo-1106:liangzhang::8b9vBcCC
# -1577334125676
# The Net PPNE - 12/31/18 is $8738mn
# Yes, it is a capital-intensive business based on the increased asset base with a slighter reduction in top-line.
# Negative impacts. The increase in litigation cost by $1.2 billion in 2nd quarter of 2022, investments in key growth initiatives.
# Consumer has dragged down.
# It is not relevant to measure liquidity. The quick ratio which is a component of the liquidity ratio measures short term ability to settle obligations. iti excludes inventory because it is not easy to convert into cash immediately.
# 1.500% Notes due 2026 MMM26 New York Stock Exchange, 1.750% Notes due 2030 MMM30 New York Stock Exchange, 1.500% Notes due 2031 MMM31 New York Stock Exchange
# Yes.
# 5.73
# The 3 year average capex as a % of net revenue of Activision Blizzard, INC. came out to 3.5%
# Your answer is: 0.66
# The unadjusted operating income of Adobe from FY2015 to FY2016 has been declined by 39.3%.
# 0.83
# "Operating income was $6.1 billion in 2022, as compared to $5.8 billion and $4.2 billion in 2021 and 2020, respectively. The company's operating margin has remained generally stable."
# Yes, there has been an improvement in Free cashflow conversion from Adobe, for FY2022.
# 0
# Conventional inventory management does not seem appropriate in respect of AES Corporation for the fiscal year 2022 because
#
# Inventory Turnover = COGS / Inventory
#                         = 10,069 / 1,055
#                         = 9.5
#
# APPROXIMATE INVENTORY TURNOVER = 9.5 TIMES
#
# Inventory turnover of 9.5 times is pretty high and thus these items are converted to sales fewer times throughout the year. The company however operates in Controlled/Utility sector, where rigorous inventory and open market mechanisms may not be applicable.
# -0.01
# 51417.07
# The year-over-year change in Amazon's net sales from 2016 to 2017 is approximately 30.8%.
# Amazon's FY2019 net Income attributable to Shareholders in USD millions is $ 11,588.
# 0.00
# The amendment relates to the substitution of the Substitute Issuer for the Former Issuer and the assumption by the Substitute Issuer of the covenants of the Former Issuer under the Indentures
# No text found
# The purchase consideration for acquisition of 100% equity interest in a Czech Republic company is $59 million, The company completed the acquisition of 100% equity interest in a medical device packaging manufacturing site in Shanghai, China, The purchase consideration for acquisition of a leading manufacturer of automated protein packaging machines is $45 million
# AMCOR primarily operates in developing, producing, and responsible packaging for food, beverage, pharmaceutical, etc.
# On the contrary, AMCOR continues to maintain a consistent level of the gross profit as a percentage of net sales. The gross profit is a direct result of operational outlays irrespective of any change in the gross margin profile of the company.
# During the fiscal 2023 second quarter and first six months, restructuring charges (credits) and other related activities resulted in net charges to earnings of $2, primarily to partially fund employee-related costs. These charges are primarily related to the closure of manufacturing facilities and restructuring of the global operating model of the Packaging business.  AMCOR's restructuring liabilities encompass Cash payments vista of employee expenses, and such assets' closure's postmortem costs.
# For the twelve months ended June 30, 2022, AMCOR's Adjusted EBITDA was $2,117 Milllion. For the twelve months ended June 30, 2023, AMCOR's Adjusted EBITDA was $2,018 Million.
# 1460
# 3.14%
# No, AMD does have a reasonablyhealthy liquidity profile based on its quick ratio for FY22, which stands at 2.5.
# As of 2022 fiscal year, AMD offers server microprocessors (CPUs), server GPUs, data processing units, and adaptive system-on-chip products for data centers. Additionally, the company provides desktop and notebook CPUs, APUs, and chipsets as well as discrete GPUs, semi-custom SoC products, and development services. The company also supplies embedded CPUs, GPUs, APUs, FPGAs, and adaptive SoC products. From time to time, the company may also sell or license portions of its intellectual property (IP) portfolio.
# AMD's net revenue increased by 44% in FY22 compared to FY21, mainly due to a 64% increase in Data Center segment revenue driven by a higher demand for server processors, as well as a 21% increase in Gaming segment revenue and inclusion of Xilinix embedded products in the Embedded segment.
# Operating margin is not a useful metric for the company like this due to the large amortization expense related with Xlyinz acquisition
# Net cash provided by operating activities $ 3,565
# Embedded segment's sales increase the most among the other segments.
# Yes it did, ‘Sales to this customer consisted of sales of products from our Gaming segment’, mentions customer concentration	effect to the business.
# American Express has registered Common Shares (par value $0.20 per Share) under symbol "AXP" on the New York Stock Exchange
# The geographies that American Express primarily operates in as of 2022 include:
# - United States
# - EMEA (Europe, Middle East, and Africa)
# - APAC (Asia-Pacific)
# - LACC (Latin America and the Caribbean)
# No, AMEX doensn't have a consistently increasing operating margin which could indicate a better profile than 2021.
# A decrease of 270 basis points in Branded Card discount rate.The company has been impacted by these macroeconomic headwinds.
# Yes, the effective tax rate of American Express has decreased from 24.6% to 21.6% in the last year.
# Total liabilities $ 203,643
# Yes. American Express was able to retain card members during 2022.
# We can compute that
# American Water Works Company Inc paid $ 389 (in millions) of dividends to the shareholders for FY2020
# $1831.00
# No, as of December 31, 2022 American Water Works has negative working capital amounting to $(1,561).
#  3.1%
# $5,409
# Gross margins (gross profit/revenue) seem to be constantly fluctuating but not by more than 2% over the past few years
# Current Health ltd.,  Yardbird Furniture
# Operating activities brought in the most (or lost the least) cash flow ($1,824M) for Best Buy in FY2023
# Yes, there was a drop in Cash and cash equivalents from $1,874 (January 28, 2023) to $1093 (July 29, 2023)
# Not right961912958973969
# Topline performer was the Entertainment product category, driven by "gaming". This is further offset by declines in Virtual Reality and Drones.
# 2.68
# 14.5%
# USD 381603 millions
# Boeing’s net property, plant, and equipment (in USD millions) for FY2018 was $12.645
# Yes.  No.
# Yes. They are being sued due to the 2018 and 2019 accidents which happened with their Boeing 737 Max jets.
# No, the gross margin profile of Boeing worsened by 4.9% in FY2022.
# USA, UK, China, India, Botswana
# The airline industry is known to be cyclical, and this affects Boeing's performance.
# Five.
# The effective tax rate increased to (0.6%).% in 2022 from 14.7%. in 2021.
# 2.43%
# 57.5%
# 31.99%
# 103.36
# 0.1%
# 23% from 20%
# Corning's working capital is positive. Its current assets surpass current liabilities by $2,278 million (representing a solid increase from 31-Dec-2021, when it stood at $2,853 million).
# On August 29, 2021, Costco reported assets of $59,268 million which increased by $3,712 million from $55,556 million on August 30, 2020.
# 1.29
# Yes, CVS Health is a capital-intensive business: it has invested $984.6 million in "Property and equipment, net", and $63,627 million in "Long-term investments" during FY 2022, which are very capital-intensive aspects.
# The Company has settled a number of opioid litigation claims, while legal battles around the issue of excessive drug pricing and reabte arrangments with drug manufacturers are ongoping.
# Yes
# Yes, Mary N. Dillon holds Executive CEO experience in Ulta Beauty and also other corporations. (see foot locker_annual_report-10k.txt, pg.89)
# No.
# -6.84
# 1.68
# $2,499.2. But it's actually going to be negative as Capex exceeded cash from operations by the tune of $71 odds in FY2020
# 0.45
# No, JnJ's FY2022 financials do not reflect high growth.
# Consolidated earnings before provision for taxes on income was $21.7 billion and $22.8 billion for the years 2022 and 2021, respectively.
# According to 10-K, JnJ inventory turnover is 1.51.
# Yes, growth in JnJ's adjusted EPS is expected to accelerate in FY2023
# International Sales growth was higher than US sales growth during both Q4 and FY'22
# Kenvue Inc.
# $20,000,000,000
# $13.2 billion
# Yes, net earnings as a percent of sales increased by 1.0% (20.1% vs 19.1%).
# Commercial Banking
# After the first quarter of 2021, the Firm assets experienced a 10% YoY growth, ending at $3.47 trillion. They have 3.797 billion shares, providing $916.059 billion for liquidation.  Based on this, each shareholder will receive approximately $241.65
# JPMorgan Chase Source: 10-K Filing 20223 section 1
# The balance of its businesses, including noninterest revenue
# perspectives of the Firm’s top-line performance during 2022 on a consolidated basis. The Firm’s consolidated net worth increased by 16% year-over-year, driven by good growth in loans and deposits on a year-over-year basis. The Firm’s noninterest revenue advanced as well, by 21.1% year-over-year, outpacing most periods. JPMorgan Chase’s noninterest revenue benefitted from higher investment banking fees, primarily driven by higher advisory and debt underwriting fees. Firmpredominantly in the U.S., and many of the world’s most prominent corporate, institutional, and government.getClientsservices and therefore, it is not necessary.
# 16%
# Yes, the risk decreased
# 0.5775530316754979
# 0.69
# -978 USD
# 7.2%
# 302.6
# 3.8%
# Yes, $0.01 per share
# Las Vegas Strip Resorts
# 13.5x
# MGM China in the current year compared to $1.2 billion in the prior year, a decrease of 44%
# $416,420.00
# 31780
# [[ FALSE ]])
# Netflix's FY2015 EBITDA margin was 7.4%
# 10,643 USD
# 2018:55.6
# 2017:55.4
# 2016:53.7
# 16,525
# Answer: 3.58
# $841 of cash flow was provided in investing activities for Nike in FY2023.
# No, Paypal's working capital is negative based on the FY 2022 balance sheet
# 4.625
# - The United States
# - Canada
# - Latin America
# - Europe
# - Africa
# - Middle East
# - South Asia
# - Asia Pacific
# - Australia
# - New Zealand and China_region
# There have been no legal proceedings that PepsiCo has officially disclosed that are considered as a substantially important ongoing legal battle.
# 0
# $14517 mn.
# PepsiCo's unadjusted EBITDA % margin for FY 2022 is 21.23%.
# On this matter the number of shares voted in favor was
# 19,718,780
# Pepsico increased it by $400 Million
# $4.2 billion
# Pepsico raised full year guidance for FY2023 because the company saw resilient performance and business momentum in the first quarter, and gross margin expansion is expected after a significant 90 basis points expansion during the quarter.
# 1.0% to 9.0%
# Yes
# Pfizer Inc. saw “(Gain) on completion of Consumer Healthcare JV transaction” in 2019.
# Therachon, Array, Trillium.
# Up to $700 million
# Revenue from the developed rest of world has dropped the most in the Q22023 over the same period in 2022, by 74%.
# Pfizer Inc recently completed the global separation of its Upjohn business, and
# formed Viatris Inc. to include off-patent, established medicines business and Outsourced pharmaceutical
# manufacturing (OpM) business.
# None
# Net of cash acquired, Ulta Beauty Inc. made no major acquisitions in FY2023 and FY2022
# SG&A expenses decreased to 23.5% compared to 23.9% in fiscal 2021, primarily due to lower marketing expenses and leverage of incentive compensation due to higher sales, partially offset by deleverage of corporate overhead due to strategic investments and deleverage of store payroll and benefits due to wage investments.
# The increase of $104.2 million in the end-of-year merchandise inventory was due to the opening of 47 new stores, to support new brand launches and expansions, and inventory costs increases.
# 58.8%
# Decrease
# $ 32,502.00
# $ 1,097
# The quick ratio for Verizon is 0.71, indicating a not-so-sound liquidity position.
# Yes, Verizon looks like a capital-intensive business.
# Investments in Wireless licenses reflects capital-intensive operations as Verizon operates network and transmission facilities to provide services to its customers.
# No
# Average Accounts Payable = (46,092 + 41,433)/2
#
# Days Payable Outstanding =( 365 * (45862.5)/ (373396 + (43783-43046)))
#
# = 43.99
# Operating income % margin worsened by 0.9% from 4.1% in 2018 to 3.2% in 2019
# 3.7
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ft:gpt-3.5-turbo-1106:liangzhang::8bA4aUyw
# ft:gpt-3.5-turbo-1106:liangzhang::8bA4aUyw
# ft:gpt-3.5-turbo-1106:liangzhang::8bA4aUyw
# ft:gpt-3.5-turbo-1106:liangzhang::8bA4aUyw
# ft:gpt-3.5-turbo-1106:liangzhang::8bA4aUyw
# ft:gpt-3.5-turbo-1106:liangzhang::8bA4aUyw
# 1577
# 8.7
# The company '3M Company and Subsidiaries' had cash payment for "Purchases of property, plant and equipment (PP&E)" of $1749M. This amount indicates that the business is capital intensive.
# The reported GAAP operating margins are not useful due to the impairment charge related to exiting PFAS manufacturing, including environmental remediation and other related activities. This activity accelerated the timeline of certain planned exits and led to impairment charges related to the sites. Adjustment for these costs was considered for non-GAAP operating margin purposes.
# In 2022, 3M's Consumer segment has dragged down the overall growth by -3.9%
# A higher ratio is generally considered to be better than a lower ratio. In lehmans terms, this ratio tests whether a company is able to meet it’s short-term liabilities with its most liquid assets. The quick ratio is similar to the current ratio but it is considered a more reliable measure of company liquidity. It is more conservative because it excludes items such as inventory and other current assets that may not be easily convertible. The higher this ratio, the better position a company is for liquidity.
# 1.500% Notes due 2026 MMM26 New York Stock Exchange
# 1.750% Notes due 2030 MMM30 New York Stock Exchange
# 1.500% Notes due 2031 MMM31 New York Stock Exchange
# Yes, 3M has maintained a stable trend of dividend distribution, with the company marking its 65th consecutive year of dividend increases.
# 24.31
# Capital expenditures = Capex
# Capex for the year ended December 31, 2017 = $155M
# Capex for the year ended December 31, 2018 = $131M
# Capex for the year ended December 31, 2019 = $116M
# Revenue for the year ended December 31, 2017 = $7,017M
# Revenue for the year ended December 31, 2018 = $7,500M
# Revenue for the year ended December 31, 2019 = $6,489M
# =(155+131+116)/(7017+7500+6489)*100 =1.5%
# 0.66
# 65.3%
# 0.83
# In fiscal 2022, Adobe generated an operating income of $6,098 million while in FY 2021 it recorded $5,802 million operating income, implying a slight increase in its operating margin.
# The free cash flow improved$1.61bn in 2022 from $3.69bn in 2021 and $6mn in 2020.
# 0
# 15 times.387 times
# Inventory turnover may not be meaningful to calculate because the company is primarily in the service business, not trading of goods.
# 0.11
# 37.51
# 8.5%
# $11,588
# $1,615.9
# In the 8-K, it was disclosed that the swap of the Amcor Flexibles North America, Inc. (the “Substitute Issuer”) for Amcor Finance (USA), Inc. (the “Former Issuer”) in the 2016 and 2019 Indenture was undertaken. The process also included the replacement of the Former Issuer’s notes.
# Amcor's quick ratio has declined between FY2023 and FY2022
# The major acquisitions that AMCOR has done are:
# 1. Flexible packaging manufacturing plant in Czech Republic.
# 2. Medical device packaging manufacturing site in Shanghai, China.
# 3. New Zealand based leading manufacturer of state-of-the-art, automated protein packaging machines.
# AMCOR primarily operates in the packaging industry, specifically the responsible packaging for food, beverage, pharmaceutical, medical, home and personal-care, and other products.
# No, Amcor gross margin is declining and has been over the past 3 years
# AMCOR has done some restructuring exercise and they flag them under restructuring costs. The costs have been associated with Employee costs including Separation Benefits, bonus and other employee entitlements,  costs like Asset write-downs, with Asset impairment charges included in them, also costs that  are related to third-party services for completing restructuring costs like legal, consulting and alike.
# $2,117 million
# Flexibles sales volume declined 4%, while Flexibles price/mix was up 2%. In constant currency, flexible sales declined 5%. Rigid sales volume was down 3%,  and price/mix was up 1%. Rigid packaging sales declined 3% in constant currency. The divestiture of the North American operations had a 2% reduction on net sales for FY 2023.
# 4.2%
# No, AMD's quick ratio has steadily declined since 2021, with a decrease in 2022 from 2.02x to roughly 1.35x. A ratio of 1.00x would indicate 1.00 of coverage.
# AMD sells CPUs, GPUs, DPUs, and SoC products for data centers, desktop and notebook personal computers, discrete GPUs, semi-custom SoC products and development services, and embedded CPUs, GPUs, APUs, FPGAs, and Adaptive SoC products.
# The increase in net revenue was driven by a 64% increase in Data Center segment revenue primarily due to higher sales of our EPYC™ server processors, a 21% increase in Gaming segment revenue primarily due to higher semi-custom product sales, and a significant increase in Embedded segment revenue from the prior year period driven by the inclusion of Xilinx embedded product sales.
# The decrease in operating income was primarily driven by amortization of intangible assets associated with the Xilinx acquisition.
# Cash flows from Operating activities provided the greatest Cash Flow for AMD in FY22 to the tune of $3,565 million.
# The sales have proportionally increased the most at 63% in the embedded segment
# Yes, a single customer accounted for 16% of consolidated net revenue
# Common Shares (par value $0.20 per Share) AXP New York Stock Exchange
# United States, EMEA, APAC, and LACC
# No, the operating margin is deteriorating
# The composition of its total revenues from the sale of discount is decreasing. Within the non-interest revenue composition, the percentage of non-discount discount revenue declining with a decline of 30% in its share in total non-interest revenues.
# In FY2021, Amex's effective tax rate was 24.6 % and in FY2022, it dropped to 21.6%. This represents a 3.0% drop year on year
# $110,239 million
# Yes, Card Member retention remained high
# $389.00
# 1632
# No. The company has a working capital of -$1,561 M.
# 3%
# 5,409
# No, Best Buy's gross margins are not historically consistent. Gross margin decreased from 22.4% in 2022 to 21.3% in 2023
# In fiscal 2022, Best Buy acquired Current Health Ltd., a care-at-home technology platform and Two Peaks, LLC d/b/a Yardbird Furniture, a direct-to-consumer outdoor furniture company
# Investing activities brought in the most cash flow for Best Buy in FY2023 with a -962 in millions cash outflow
# 69% dro in cash and cash equivalents from July 29, 2023 ($ 1,874) to January 28, 2024 ($ 1,093)
# Yes, there was a change by -13
# Entertainment grew by 9%, driven by gaming.
# 1.73
# An increase in total revenue was 101.3% from 2019 to 2020
# 381.603
# $12,645
# - No
# No, as of February 28, 2022, legal action have been filed as a result of the Lion Air Flight 610 and Ethiopian Airlines Flight 302 accidents.
# This seems to be a short answer.
# Boeing’s primary customers are a small number of commercial airlines and the U.S. government
# Yes, it is.
# 5 per month for the 787 program
# Boeing Capstone's effective tax rate has decreased to 0.6% in FY2022 from a 14.7% in FY2021.
# 0.02
# 39.7%
# 0.79
# 50.86
# 14.2%
# The effective tax rate was 23% in 2022, a 3% increase compared to 2021
# Yes, Corning had positive working capital based on FY 2022 data
# Costco had $59,268M in total assets by the end of FY2021
# 0.02
# 1. CVS is a capital intensive business considering the large investments in property/equipment and other long-term assets. 2. The company's revenues of over $300,000 millions are offset by substantial operating costs to leave an operating income of under $10,000_. 3. Due to non-operating overhead costs, the company reported a lower net income in 2022, compared to 2021 based on the Consolidated Statements of operations.
# CVS Health has been reported with 3 class actions:
# 1. Overcharging by not submitting correct usual customary prices during adjudication process
# 2. Regarding drug pricing and its rebate arrangements with pharmaceutical companies causing inflated prices
# 3. Settlement for opioid claims with maximum of $4.3B for remediation, 625M in attorney fee, payable over 10 years
# Yes, CVS Health has paid dividends to common shareholders in Q2 FY2022
# No. The former CEO of Ulta Beauty, Inc. will be new CEO.
# Yes, with respect to the proposal to elect ten nominees to the Board of Directors, Richard A. Johnson received substantially more votes against joining the board than the other nominees
# 3.67
# 0.68
# $3051.4 Million
# The retention ratio for FY2022 is 0.24
# No
# The change in gross margins was driven by higher cost of products sold driven by one-time COVID-19 vaccine manufacturing exit-related costs, currency impacts in the Pharmaceutical segment, and commodity inflation in the MedTech and Consumer Health segments.
# 0.7Inventory of 12.5 billion turnover 0.7 times in FY2022
# No, growth in JnJ's adjusted EPS is expected to slightly decelerate in FY2023
# JnJ's US sales grew at a faster pace compared to international sales in 2022.
# JnJ's Consumer Health business
# Approximately $20 billion
# Johnson and Johnson received $13.2 billion in cash proceeds from the separation of Kenvue and maintains 9.5% equity stake in Kenvue.
# Yes.
# The Corporate segment had the lowest net revenue in 2021 Q1
# $81.3 million
# No, JPM's gross margin fluctuates by more than 2% each year.
# Consumer & Community Banking
# Yes, the V. a. R did decrease by $7 million
# Kraft Heinz recorded 6.86 in FY2019.
# 0.74
# 5,818
# -3.4%
# The year-end amount of accounts payable for MGM Resorts in fiscal 2018 is $302.6 million USD
# 1.1%
# Yes. As of 3/2/2023, MGM has paid dividends per share of $0.01.
# 50Las Vegas Strip Resorts
# There were 6.6x and 6.5x interest coverage ratios at the end of Q4 2022 and Q4 2021 respectively
# MGM China
# MGM had $416,420 of corporate bonds which received the largest investment among the short term investments for MGM in H1 FY2023
# Microsoft's FY2016 COGS is $32800 millions
# No. The company has decreased its long-term debt obligation from 47,032M to 41,990M.
# Fiscal year 2015 EBITDA % margin for Netflix is 7.2%.
# 5,466
# Note : XF Currency is USD.
# 23.2%
# 16,525illions
# 4.06
# Implicitly, the cash obtained from investing activities was $564 million in FY2023.
# Paypal has positive working capital of 12,416 which can found by subtracting the current assets(57,517) from current liablities(45,101)
# PepsiCo reported approximately $4.63 billion in capital expenditure (Capex) for FY2021
# PepsiCo primarily operates in more than 200 countries and territories. Their global footprint includes business operations in the United States, Canada, Latin America, Europe, Africa, the Middle East and South Asia, and the Asia Pacific, Australia, New Zealand, and China region.
# We and our subsidiaries are party to a variety of litigation, claims, legal or regulatory proceedings, inquiries and investigations. While the results of such litigation, claims, legal or regulatory proceedings, inquiries and investigations cannot be predicted with certainty, management believes that the final outcome of the foregoing will not have a material adverse effect on our financial condition, results of operations or cash flows. See also “Item 1. Business – Regulatory Matters” and “Item 1A. Risk Factors.”
# 0.00
# $6,525 million
# 19.2%
# 19,718,780 shares or 1.97% of the votes were in favor, 977,228,788 shares or 98.03% of the votes were against. The proposal was therefore defeated.
# PepsiCo increased its unsecured five year revolving credit agreement by $ 400,000,000
# PepsiCo may also, upon the agreement of either the then existing lenders or of additional banks not currently party to the 2023 Five YearCredit Agreement, increase the commitments under the 2023 Five Year Credit Agreement to up to $4,950,000,000 in U.S. Dollars and/or Euros.
# Given our strong start to the year, we
# now expect our full-year 2023 organic revenue to increase 8 percent (previously 6 percent) and
# core constant currency EPS to increase 9 percent (previously 8 percent),
# PepsiCo raised its full-year guidance by 1 percentage point
# Yes, the company grew its PPNE, from 13,745 in 2020 to 14,882 in 2021
# No.
# Trillium, Array and Therachon
# Pfizer expects to pay around $700 million to spin off Upjohn in the future. 90% of the estimated costs have been incurred by 2023.
# Although all regions had a significant drop in revenues year over year, the largest was the our of the "Developed Rest of the World" which decreased by 74% from $5,034 million to $1,305 million
# Yes, Pfizer is seperating the Upjohn segment
# ULTA
# Ulta Beauty, Inc. did not make any acquisitions in FY 2022 and FY 2023.
# Lower marketing expenses and leverage of incentive compensation due to higher sales
# The increase in merchandise inventories was primarily due to the opening of 47 new stores since January 29, 2022, inventory to support new brand launches and brand expansions, and inventory cost increases.
# 31.8%
# It decreased by 0.4%.
# Cross currency swaps
# $194,734,000
# lack of clarity
# In terms of current ratio, the firm had a below average, current ratio of less than 1 at 0.9 with current assets of $37.9 bn and current liabilities of $43.6 bn.
# Yes, Verizon decreased its long-term debt by $2,749mil between 2021 and 2022 period
# 91.86
# 1.1%
# 5.3ह.abppercent
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ft:gpt-3.5-turbo-1106:liangzhang::8bAJ249z
# ft:gpt-3.5-turbo-1106:liangzhang::8bAJ249z
# ft:gpt-3.5-turbo-1106:liangzhang::8bAJ249z
# ft:gpt-3.5-turbo-1106:liangzhang::8bAJ249z
# ft:gpt-3.5-turbo-1106:liangzhang::8bAJ249z
# ft:gpt-3.5-turbo-1106:liangzhang::8bAJ249z
# $ 1578.00
# $6.4
# 3M is a capital-intensive business based on FY2022 data.
# SG&A expenses as a percentage of sales increased in 2022 compared to the same period last year. The increases were driven by pre-tax special item costs of approximately $1.2 billion for significant litigation, certain impairment costs, divestiture-related restructuring charges, and continued investment in key growth initiatives. These increases were partially offset by restructuring benefits and general cost management.
# Consumer
# 3M had a current ratio of 1.44 for Q2 of FY2023, which remained improved from 1.55 observed at the end of 2022.
# The 1.500% Notes due 2026, 1.750% Notes due 2030, and the 1.500% Notes due 2031 are the debt securities registered to trade on a national securities exchange under 3M's name.
# Yes, 3M has maintained a stable trend of dividend distribution by increasing for 65 years consecutively
# $50.86
# 2.4%
# 0.66
#
# 60.9
# 0.83
# Operating margins have remained relatively stable over the years and they did not expand in 2022 as well
# Yes. Adobe's free cash flow was approximately 41% of adjusted net income for the year, as measured on a non-GAAP (Generally Accepted Accounting Principles) basis.
# 0
# 1.6 Times
# 56.49%
# 71.28
# 57.4%
# 11588 by Tabular Calc
# $50 million
# The approval of a new agreement regarding the substitution of the Former Issuer by the Substitute Issuer.
# Quick ratios are not usually calculated for companies like AMCOR, as they are generally more relevant for companies with significant short-term cash flow risks.
# AMCOR made three acquisitions in FY2023 as per 10-K. Acquisitions: 1. Czech Republic  $59 million equity interest. 2. Shanghai, China-based $60 million, with performance-based contingent consideration 3 $45 million for New Zealand based maker of protein packaging machines
# AMCOR primarily operates in the packaging industry.
# Gross margin for Amcor is 18.5% as of FY2023, which makes it one of the lowest in the Packaging and Containers industry
# Amcor's restructuring liability decreased during the first half of FY2023, and subsequent adjustments were incorporated towards the end of the year.
# $ 2,117.00
# $7m
# 1.2%, 3.7%, and 4.5%
# Yes, AMD has a healthy liquidity profile with a quick ratio of 4.8x and 4.8x of their total current liabilities covered by current assets
# AMD sells server microprocessors (CPUs) and graphics processing units (GPUs), data processing units (DPUs), Field Programmable Gate Arrays (FPGAs), and Adaptive System-on-Chip (SoC) products for data centers; CPUs, accelerated processing units (APUs) that integrate CPUs and GPUs, and chipsets for desktop and notebook personal computers; discrete GPUs, and semi-custom SoC products and development services; and embedded CPUs, GPUs, APUs, FPGAs, and Adaptive SoC products.
# An increase in net revenue was driven by a 64% increase in Data Center segment revenue, a 21% increase in Gaming segment revenue, and a significant increase in Embedded segment revenue.
# The decrease in operating income was primarily driven by the amortization of intangible assets associated with the Xilinx acquisition
# Cash flows from financing activities
# Data Center
# Yes. One customer accounted for 16% of AMD's consolidated net revenue for the year ended December 31, 2022.
# American Express has only registered their common shares for trading on the New York Stock Exchange. There are no other debt securities registered for trading.
# United States, Europe, Middle East & Africa (EMEA), Asia Pacific (APAC), and Latin America & Caribbean (LACC)
# No, American Express has a deteriorating operating margin profile
# Not applicable
# The effective tax rate for American Express decreased from 24.6% to 21.6% between FY2021 and FY2022.
# $110,239 million of liabilities comprised Customer deposits.
# American Express was able to retain card members during 2022 because Card Member retention remained high
# $389.00
# $1832.00
# Yes. The working capital for American Water Works would be a positive number of  eternity $-1563316396875250$ due to the calcualtion being such-\$ 53096717516208600\$.
# 2.9%
# $5409.00
# No
# Current Health Ltd. in FY 2022
# There was $952M less cash flow from operating activities in Best Buy's FY2023 period than in FY2022.
# Yes, there was a drop
# Yes. The number of Best Buy stores decreased by 23 stores (from 951 to 928)
# Entertainment.
# 1.73
# 45.5%
# $381,603.00
# 5,182
# No
# Yes, Boeing has reported materially important ongoing legal battles.
# Yes. Boeing improved their gross margin profile from (5,685) in 2020 to 3,017 in 2021 and 3,502 in 2022.
# Boeing's primary customers are Commercial airlines, as well as the U.S. government
# Yes
# For the 787 program, they expect to increase from current low rates to 5 per month in 2023. For the 777X program expect production to resume in 2023. The 737 program is producing 31 per month requiring stabilization.
# Boeing's effective tax rate in FY2022 was (0.6)%. In FY2021, it was 14.8%
# 5.70
# 39.7%
# 0.80
# 80.67
# 14.2%
# The effective tax rate of Corning has increased from 20% in FY2021 to 23% in FY2022.
# Yes
# $59268.0
# 0.45
# Yes, CVS Health is a capital-intensive business based on the information provided in their FY2022 Financial Statements, due to the heavy investments in goodwill and intangible assets.
# Yes.
# Yes
# Yes, Mary Dillon has a vast experience as CEO of Ulta Beauty.
# Yes, as none of the nominees had substantially more votes against joining the Board than the other nominees.
# 15.30
# 0.68
# $2908.9
# 0.70
# No, the growth rate in sales decreased significantly in 2022, compared to the previous year.
# We saw an increase in advertising, promotion, and selling expenses as a percentage of sales. This increase is primarily due to:
# •
# Decrease in the estimated fair value of certain intangible assets, partially offset by
# •
# Decline in litigation expenses
# 3 times
# No
# Johnson & Johnson's international sales declined by 0.6% for the full year 2022, while this figure increased 3.0% in the U.S. For Q4 2022, U.S. sales increased by 2.9% while international sales decreased 11.5%.
# vaccines
# Approximately $20 billion
# $ 13.2 billion
# On a Percentage basis, JnJ's net earnings increased 20.1% from 20.0% in Q2 of FY2022 to 20.1% in Q2 of FY2023.
# Corporate
# $66.56
# Gross margins vary by line of business and are not a relevant metric.
# Commercial Banking
# Yes, the risk faced by JPM decreased
# 0.6
# 0.96
# $5,818.0
# -2.3%
# $302.6 Million
# 3.4%
# Yes, MGM Resorts paid dividends to common shareholders in FY2022.
# Las Vegas Strip Resorts
# 1.84x
# MGM had negative topline growth in Las Vegas Strip Resorts for FY 2022.
# Corporate bonds
# $17,880.00
# No, the company has reduced its debt over FY23 period
# Netflix's FY2015 unadjusted EBITDA margin is 3605.85%
# $5,466.31
# 15.8%
# $16,525.00
# The inventory turnover ratio is 3.61
# Cash from investing activities
# Yes, Paypal has positive working capital based on FY2022 data.
# $4.63
# PepsiCo primarily operates in the following geographies:
# 1. Frito-Lay North America (FLNA)
# 2. Quaker Foods North America (QFNA)
# 3. PepsiCo Beverages North America (PBNA)
# 4. Latin America (LatAm)
# 5. Europe
# 6. Africa, Middle East, and South Asia (AMESA)
# 7. Asia Pacific, Australia, and New Zealand, and China Region (APAC)
# No, Pepsico hasn't reported any material legal ongoing legal proceedings from FY 2021 and FY 2022 that would affect their financial position and operations.
# None
# 2606
# 8.3%
# The shareholder proposal regarding a congruency report on net-zero emissions policies was defeated:
# For: 19,718,780
# Against: 977,228,788
# Yes, by $400,000,000
# $4,200,000,000
# It raised the FY2023 guidance based on its strong performance in the first quarter of the year
# Pepsico raised its full-year guidance by 1% for core constant currency EPS growth
# Yes, Pfizer more than doubled its PPNE during FY21, by $1,137 million.
# Yes. The Consumer Healthcare JV transaction of 2019 resulted in $8.1 billion addition to income
# Pfizer has acquired Trillium, Array, and Therachon
# Pfizer expects to pay around $700 million in USD to spin off Upjohn in the future
# Developed Rest of World
# Yes, Pfizer is spinning off Upjohn
# None
# Ulta beauty has not made any acquisitions during FY 2023 and FY 2022.
# Lower marketing expenses and leverage of incentive compensation due to higher sales
# The $104.2 million increase in merchandise inventories was due to the opening of 47 new stores, inventory to support new brand launches and brand expansions, and inventory cost increases.
# 14.91%
# SG&A expenses decreased as a percentage of net sales to 23.5% in FY2023, from 23.9% in FY2022
# The cross currency swaps had the highest notional value for FY 2021 with $32,502 million
# $1.096 billion
# The quick ratio is not relevant to measure the company's liquidity profile
# Based on the assets, Verizon can be considered capital intensive. The Company has a total of $379,680 million in assets relative to its total revenues of $136,835 million
# No, Verizon has reduced its long term debt by $2,749 million between 2022 and 2021.Further on average debt remained constant from 2022 to 2021. Verizon decreased the total debt by $229 during that period.
# 17.85
# 0.2%
# 4.3%
