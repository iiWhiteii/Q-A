# %%
# !pip install anthropic
# !pip install datasets
# Out:
# Requirement already satisfied: anthropic in /usr/local/lib/python3.10/dist-packages (0.8.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from anthropic) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from anthropic) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from anthropic) (0.26.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from anthropic) (1.10.13)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from anthropic) (1.3.0)
# Requirement already satisfied: tokenizers>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from anthropic) (0.15.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from anthropic) (4.9.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->anthropic) (3.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->anthropic) (1.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->anthropic) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->anthropic) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->anthropic) (0.14.0)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.13.0->anthropic) (0.20.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic) (6.0.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic) (2.0.7)
# Collecting git+https://github.com/anthropics/anthropic-sdk-python.git
#   Cloning https://github.com/anthropics/anthropic-sdk-python.git to /tmp/pip-req-build-3rn4fdj7
#   Running command git clone --filter=blob:none --quiet https://github.com/anthropics/anthropic-sdk-python.git /tmp/pip-req-build-3rn4fdj7
#   Resolved https://github.com/anthropics/anthropic-sdk-python.git to commit d18001f2dfe982a4b9dcd7b59d7d2b22992d5ccc
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from anthropic==0.8.1) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from anthropic==0.8.1) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from anthropic==0.8.1) (0.26.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from anthropic==0.8.1) (1.10.13)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from anthropic==0.8.1) (1.3.0)
# Requirement already satisfied: tokenizers>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from anthropic==0.8.1) (0.15.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from anthropic==0.8.1) (4.9.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->anthropic==0.8.1) (3.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->anthropic==0.8.1) (1.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->anthropic==0.8.1) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->anthropic==0.8.1) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->anthropic==0.8.1) (0.14.0)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.13.0->anthropic==0.8.1) (0.20.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic==0.8.1) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic==0.8.1) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic==0.8.1) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic==0.8.1) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic==0.8.1) (6.0.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic==0.8.1) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic==0.8.1) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic==0.8.1) (2.0.7)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.16.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (10.0.1)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.1)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.20.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->datasets) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)

# %%
import pandas as pd
import anthropic
from anthropic import Anthropic, HUMAN_PROMPT, AI_PROMPT

# %%
from datasets import load_dataset

dataset = load_dataset("PatronusAI/financebench")
path_to_csv_dataset = "financebench_sample_150.csv"
claude_key = "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"

# %%
df = pd.DataFrame(dataset['train'])

# %%
df['evidence_text']
# Out:
# 0      Table of Contents \n3M Company and Subsidiarie...
# 1      Table of Contents \n3M Company and Subsidiarie...
# 2      3M Company and Subsidiaries\n Consolidated Sta...
# 3      SG&A, measured as a percent of sales, increase...
# 4      Worldwide Sales Change\nBy Business Segment Or...
#                              ...
# 145    Consolidated Balance Sheets \nVerizon Communic...
# 146    At December 31, Maturities \nInterest \nRates ...
# 147    Walmart Inc.\nConsolidated Statements of Incom...
# 148    Walmart�Inc.\nConsolidated�Statements�of�Incom...
# 149    Walmart Inc.\nConsolidated Statements of Incom...
# Name: evidence_text, Length: 150, dtype: object

# %%
examples = [ f"<answer> {row['answer']} </answer>" for idx, row in df.iloc[:50].iterrows() ]

# %%
examples
# Out:
# ['<answer> $1577.00 </answer>',
#  '<answer> $8.70 </answer>',
#  '<answer> No, the company is managing its CAPEX and Fixed Assets pretty efficiently, which is evident from below key metrics:\nCAPEX/Revenue Ratio: 5.1%\nFixed assets/Total Assets: 20%\nReturn on Assets= 12.4% </answer>',
#  '<answer> Operating Margin for 3M in FY2022 has decreased by 1.7% primarily due to: \n-Decrease in gross Margin\n-mostly one-off charges including Combat Arms Earplugs litigation, impairment related to exiting PFAS manufacturing, costs related to exiting Russia and divestiture-related restructuring\ncharges </answer>',
#  '<answer> The consumer segment shrunk by 0.9% organically. </answer>',
#  "<answer> No. The quick ratio for 3M was 0.96 by Jun'23 close, which needs a bit of an improvement to touch the 1x mark </answer>",
#  "<answer> Following debt securities registered under 3M's name are listed to trade on the New York Stock Exchange:\n-1.500% Notes due 2026 (Trading Symbol: MMM26)\n-1.750% Notes due 2030 (Trading Symbol: MMM30)\n-1.500% Notes due 2031 (Trading Symbol: MMM31) </answer>",
#  '<answer> Yes, not only they distribute the dividends on a routine basis, 3M has also been increasing the per share dividend for consecutive 65 years </answer>',
#  '<answer> 24.26 </answer>',
#  '<answer> 1.9% </answer>',
#  '<answer> 0.66 </answer>',
#  '<answer> 65.4% </answer>',
#  '<answer> 0.83 </answer>',
#  '<answer> No the operating margins of Adobe have recently declined from 36.8% in FY 2021 to 34.6% in FY2022. A drop by 2.2% in a year. </answer>',
#  '<answer> Yes, the FCF conversion (using net income as the denominator) for Adobe has improved by ~13% from 143% in 2021 to 156% in 2022 </answer>',
#  '<answer> 0 </answer>',
#  '<answer> AES has converted inventory 9.5 times in FY 2022. </answer>',
#  '<answer> -0.02 </answer>',
#  '<answer> 93.86 </answer>',
#  '<answer> 30.8% </answer>',
#  '<answer> $11588.00 </answer>',
#  '<answer> $1616.00 </answer>',
#  '<answer> Amcor Finance (USA), Inc. and Amcor Flexibles North America, Inc., entered into supplemental indentures relating to Guaranteed Senior Notes due 2026 and 2028. This involved the substitution of the Substitute Issuer (Amcor Flexibles North America) for the Former Issuer (Amcor Finance) and the assumption of covenants under the indentures. (In essence a novation agreement) </answer>',
#  '<answer> The quick ratio has slightly improved from 0.67 times to 0.69 times between FY 2023 and FY 2022.(3.4% jump) </answer>',
#  '<answer> Amcor completed these acquisitions during FY2023:\n-100% equity interest of a flexibles manufacturing company in the Czech Republic\n- 100% equity interest in a medical device packaging manufacturing site in\nShanghai, China.\n-acquisition of a New Zealand-based leading manufacturer of state-of-the-art, automated protein\npackaging machines. </answer>',
#  '<answer> Amcor is a global leader in packaging production for various use cases. </answer>',
#  '<answer> No. For AMCOR there has been a slight decline in gross margins by 0.8%. </answer>',
#  '<answer> 87% of the total restructuring liability is related Employee liabilities. </answer>',
#  "<answer> AMCOR's Adj. EBITDA was $2,018mn in FY 2023 </answer>",
#  '<answer> The Real Growth was flat in FY 2023 vs FY 2022. </answer>',
#  '<answer> 4.2% </answer>',
#  '<answer> Yes. The quick ratio is 1.57, calculated as (cash and cash equivalents+Short term investments+Accounts receivable, net+receivables from related parties)/ (current liabilities). </answer>',
#  '<answer> AMD sells server microprocessors (CPUs) and graphics processing units (GPUs), data processing units (DPUs), Field Programmable Gate Arrays (FPGAs), and Adaptive System-on-Chip (SoC) products for data centers; CPUs, accelerated processing units (APUs) that integrate CPUs and GPUs, and chipsets for desktop and notebook personal computers; discrete GPUs, and semi-custom SoC products and development services; and embedded CPUs, GPUs, APUs, FPGAs, and Adaptive SoC products. </answer>',
#  '<answer> In 2022, AMD reported Higher sales of their EPYC server processors, higher semi-custom product sales, and the inclusion of Xilinx embedded product sales </answer>',
#  "<answer> The decrease in AMD's operating income was primarily driven by amortization of intangible assets associated with the Xilinx acquisition </answer>",
#  '<answer> In 2022, AMD brought in the most cashflow from Operations </answer>',
#  '<answer> Data Center </answer>',
#  '<answer> Yes, one customer accounted for 16% of consolidated net revenue </answer>',
#  '<answer> There are none </answer>',
#  '<answer> United States, EMEA, APAC, and LACC </answer>',
#  '<answer> Performance is not measured through operating margin </answer>',
#  '<answer> Performance is not measured through gross margin </answer>',
#  '<answer> The effective tax rate for American Express has changed/dropped from 24.6% in FY 2021 to 21.6% in FY 2022. </answer>',
#  '<answer> Customer deposits </answer>',
#  '<answer> Yes </answer>',
#  '<answer> $0.40 </answer>',
#  '<answer> $1832.00 </answer>',
#  '<answer> Yes. American Water Works had postivie working capital of $ 124Mn by FY 2022. </answer>',
#  '<answer> 2.8% </answer>',
#  '<answer> $5409.00 </answer>']

# %%
anthropic = Anthropic(
    # defaults to os.environ.get("ANTHROPIC_API_KEY")
    api_key=claude_key,
)

# %%
syntheses_with_10_labels = []

for idx, row in df.iterrows():
    question = row['question']
    evidence_text = row['evidence_text']
    completion = anthropic.completions.create(

      model="claude-2",
      max_tokens_to_sample=700,
      prompt = (
        f"{HUMAN_PROMPT} "
        f"You are an accurate chatbot specialized in responding to queries about 10-K documents. Please only respond in the manner demonstrated by the following examples. If an explanation wasn't ask, refrain from providing one. "
        f"Based on the following examples: {examples[:10]}, please provide your answer in the same format. "
        f"please address the question: {question}. "
        f"Consider the provided text as evidence: {evidence_text}. "
        f"{AI_PROMPT}")
    )

    print(completion.completion)
    syntheses_with_10_labels.append(completion.completion)
# Out:
#  <answer> $1,577 </answer>
#  <answer> $8.738 </answer>
#  <answer> No, 3M does not seem to be a capital-intensive business based on the FY2022 financial data. This is evident from the following metrics:
#
# 1) PP&E as a % of Total Assets = 19.8% (9,178/46,455)
# 2) Capex as a % of Revenue = 5.1% (1,749/34,229)
#
# Both these metrics indicate that 3M does not have a very high investment in fixed assets or capex compared to the size of its operations. A capital-intensive business typically has high PP&E and Capex as a % of revenue.
#
# Therefore, 3M utilizes its assets efficiently to generate revenues and does not seem to be a capital-intensive business model.
#
# </answer>
#  <answer> Operating Margin for 3M in FY2022 has decreased by 1.7% primarily due to:
# -Decrease in gross Margin
# -Mostly one-off charges including Combat Arms Earplugs litigation, impairment related to exiting PFAS manufacturing, costs related to exiting Russia and divestiture-related restructuring charges</answer>
#  <answer> The consumer segment shrunk by 0.9% organically. </answer>
#  <answer> Yes. The quick ratio for 3M was 0.96 by Jun'23 close, which indicates a reasonably healthy liquidity position as it is close to 1.0x. The quick ratio focuses on most liquid assets, so it is a relevant metric to measure liquidity. </answer>
#  <answer> Following debt securities registered under 3M's name are listed to trade on the New York Stock Exchange:
# -1.500% Notes due 2026 (Trading Symbol: MMM26)
# -1.750% Notes due 2030 (Trading Symbol: MMM30)
# -1.500% Notes due 2031 (Trading Symbol: MMM31) </answer>
#  <answer> Yes, not only they distribute the dividends on a routine basis, 3M has also been increasing the per share dividend for consecutive 65 years </answer>
#  <answer> 4.88 </answer>
#  <answer> 13.1% </answer>
#  <answer> 0.60 </answer>
#
# Explanation:
#
# Operating cash flow ratio = Cash from operations / Total current liabilities
#
# From the cash flow statement:
# Cash from operations (FY2015) = $1,469,502,000
#
# From the balance sheet:
# Total current liabilities (FY2015) = $2,213,556,000
#
# Operating cash flow ratio = $1,469,502,000 / $2,213,556,000 = 0.60
#
# Rounded to 2 decimal places is 0.60
#  <answer> 31.0% </answer>
#  <answer> 2.14 </answer>
#  <answer> Yes, Adobe has an improving operating margin profile as of FY2022. This is evident from Adobe's operating income increasing to $6.1 billion in FY2022 from $5.8 billion in FY2021, an increase of 5.1%. As a percentage of revenue, operating margin has improved to 34.6% in FY2022 compared to 36.8% in FY2021. The slight percentage decrease is likely due to increased operating expenses from investments in research, development, sales and marketing to drive future growth. But in absolute dollar terms, operating income and margin have increased indicating an overall improving profitability profile. </answer>
#  <answer> Yes, Adobe has an improving free cash flow conversion as of FY2022. This is evident from its operating cash flow of $7.838 billion in FY2022, which has increased from $7.23 billion in FY2021. Meanwhile, its capital expenditures have reduced from $348 million in FY2021 to $442 million in FY2022. Thus, Adobe is able to convert a greater portion of its operating cash flows into free cash flows. </answer>
#  <answer> 0 </answer>
#  <answer>
# Inventory turnover ratio cannot be meaningfully calculated for AES Corporation. This is because a major portion of AES's business is power generation, which does not involve sale of inventory. The inventory reported on balance sheet majorly comprises of spare parts, coal and oil etc required for power plant operations.
# </answer>
#  <answer> 4.7% </answer>
#  <answer> 52.63 </answer>
#
# Based on the information provided:
#
# 2016 Average Accounts Payable = (25,309 + 43,816)/2 = $34,562.5 million
# 2017 Average Accounts Payable = (34,616 + 57,883)/2 = $46,249.5 million
#
# 2017 COGS = $111,934 million
# Change in Inventory 2016-2017 = $16,047 - $11,461 = $4,586 million
#
# DPO = 365 * ($46,249.5)/($111,934 + $4,586) = 52.63 days
#  <answer> 30.9% </answer>
#  <answer> $11,588 </answer>
#  <answer> $1,615.9 </answer>
#  <answer> The key agenda of AMCOR's 8k filing dated 1st July 2022 was to report the substitution of Amcor Flexibles North America, Inc. as the new issuer in place of Amcor Finance (USA), Inc. for its existing senior notes under the 2016 Indenture and 2019 Indenture. This involved Amcor Flexibles North America, Inc. assuming the covenants of Amcor Finance (USA), Inc. under these indentures. </answer>
#  <answer> The quick ratio has declined between FY2023 and FY2022. In FY2023, Amcor's current assets were $5,308 million and current liabilities were $4,476 million, resulting in a quick ratio of 1.19x ($5,308 million / $4,476 million). In FY2022, current assets were $5,853 million and current liabilities were $5,103 million, resulting in a quick ratio of 1.15x. So the quick ratio declined from 1.15x in FY2022 to 1.19x in FY2023. </answer>
#  <answer>
# Major acquisitions by Amcor in the last 3 fiscal years are:
#
# FY2023:
# - Acquisition of a medical device packaging manufacturing site in Shanghai, China for $60 million
# - Acquisition of a New Zealand based protein packaging machine manufacturer for $45 million
#
# FY2022:
# - Acquisition of a flexible packaging plant in Czech Republic for $59 million
#
# FY2021:
# No major acquisitions mentioned
# </answer>
#  <answer> Based on the provided text, Amcor primarily operates in the packaging industry, developing and producing packaging for food, beverage, pharmaceutical, medical, home, personal-care, and other products. </answer>
#  <answer> Yes, Amcor has an improving gross margin profile as of FY2023. Its gross margin increased from 18.9% in FY2022 to 18.6% in FY2023. This indicates that Amcor has been able to improve its gross profit relative to its net sales. </answer>
#  <answer>
# The restructuring liability of $93 million as of December 31, 2022 relates to costs associated with Amcor's restructuring plans. Specifically:
#
# - $81 million is for estimated employee termination costs
# - $2 million is for fixed asset related costs
# - $10 million is for other associated restructuring costs
#
# The liability represents Amcor's estimate of the remaining costs to complete its restructuring activities that have been approved and initiated as part of ongoing efforts to optimize its cost structure.
# </answer>
#  <answer> $2,018 million </answer>
#  <answer> 5% </answer>
#
# Based on the text, comparable constant currency growth for total company sales in FY2023 was -5%. This excludes the impacts of foreign exchange, raw material pass through costs, and items affecting comparability. Therefore, the real change in sales for Amcor in FY2023 vs FY2022, excluding those factors, was -5%.
#  <answer> 4.2% </answer>
#  <answer> Yes, AMD has a reasonably healthy liquidity profile based on its quick ratio of 2.36x for FY22. This is calculated as:
#
# Total Current Assets: $15,019 million
# Total Current Liabilities: $6,369 million
#
# Quick Ratio = Total Current Assets / Total Current Liabilities = $15,019 million / $6,369 million = 2.36x
#
# A quick ratio above 1x generally indicates good short-term liquidity. Since AMD's quick ratio is well above 1x, they have a healthy liquidity position. The quick ratio specifically measures a company's ability to use its most liquid current assets to pay off its short-term liabilities, so it is a relevant metric for assessing liquidity.
# </answer>
#  <answer> The major products and services AMD sells as of FY22 are:
# - Server microprocessors (CPUs), graphics processing units (GPUs), data processing units (DPUs), Field Programmable Gate Arrays (FPGAs), and Adaptive System-on-Chip (SoC) products for data centers
# - CPUs, accelerated processing units (APUs) that integrate CPUs and GPUs, and chipsets for desktop and notebook personal computers
# - Discrete GPUs, and semi-custom SoC products and development services
# - Embedded CPUs, GPUs, APUs, FPGAs, and Adaptive SoC products
# </answer>
#  <answer> Revenue increased by 44% in FY2022 compared to FY2021, driven primarily by:
# - 64% increase in Data Center segment revenue due to higher sales of EPYC server processors
# - 21% increase in Gaming segment revenue due to higher semi-custom product sales
# - Significant increase in Embedded segment revenue with the inclusion of Xilinx embedded product sales
# </answer>
#  <answer> Operating margin is not a particularly useful metric for evaluating AMD's business performance. Since AMD acquired Xilinx in 2022, there was a large increase in amortization expense related to intangible assets that negatively impacted operating income and operating margin but does not affect AMD's underlying business performance. It would be better to evaluate AMD's profitability using metrics that exclude acquisition-related expenses like amortization of intangibles, such as non-GAAP operating income. </answer>
#  <answer> Among operating, investing, and financing activities, investing activities brought in the most cash flow for AMD in FY22 with $1,999 million. </answer>
#  <answer> The Gaming segment had the highest proportional increase in sales from FY21 to FY22, excluding Embedded. Gaming sales increased by 21.4% (from $5,607 million to $6,805 million) while Data Center and Client increased by 63.6% and -9.9%, respectively. </answer>
#  <answer> Yes, AMD reported customer concentration in FY22. One customer accounted for 16% of AMD's consolidated net revenue in FY22. </answer>
#  <answer> American Express has the following debt security registered under section 12(b) of the Act to trade on the New York Stock Exchange:
#
# Common Shares (par value $0.20 per Share) with the Trading Symbol AXP
# </answer>
#  <answer> Based on the information provided, American Express primarily operates in the following geographies as of 2022:
# - United States
# - EMEA (Europe, Middle East and Africa)
# - APAC (Asia Pacific)
# - LACC (Latin America and Caribbean)
# </answer>
#  <answer> No, operating margin is not a particularly useful metric for evaluating American Express's performance. As a financial services company, American Express generates most of its revenues from fees and interest income rather than product sales. More relevant profitability metrics would be return on assets, return on equity, or efficiency ratios that compare expenses to revenues. Without further context on the business and its operating structure, there is insufficient information to determine if American Express's profitability is improving. </answer>
#  <answer> Gross margin is not a useful metric to analyze for American Express since it is a financial services company that generates revenue primarily from fees and interest income rather than sale of products. As a financial services company, the key metrics to analyze profitability would be net interest margin, return on assets, return on equity etc. </answer>
#  <answer> The effective tax rate of American Express has decreased from 24.6% in FY2021 to 21.6% in FY2022, a change of 3 percentage points. </answer>
#  <answer> $110.2 billion </answer>
#  <answer> Yes, American Express was able to retain card members during 2022. This is evident from the statement that "Card Member retention remained high". </answer>
#  <answer> $389 </answer>
#  <answer> $1,832 </answer>
#  <answer> Yes, American Water Works has positive working capital based on FY2022 data. The company has current assets of $1,250 million and current liabilities of $2,811 million. So working capital is current assets minus current liabilities which equals negative $1,561 million. Although the working capital is negative, this metric may not be as relevant for a utility company like American Water Works since they operate capital intensive assets that require significant long-term financing. The negative working capital reflects their need to finance long-lived assets, rather than an inability to meet short-term obligations. </answer>
#  <answer> 3.0% </answer>
#  <answer> $5.409 billion </answer>
#  <answer>
# Yes, Best Buy's gross margins have been historically consistent, fluctuating between 19.3% and 22.5% over the past 3 fiscal years. This fluctuation of less than 3% annually indicates reasonably consistent gross margins. As a major consumer electronics retailer, gross margin is a relevant metric for evaluating Best Buy's profitability.
# </answer>
#  <answer>
# The major acquisitions that Best Buy has done are:
#
# FY2023: No major acquisitions mentioned
#
# FY2022:
# - Current Health Ltd. for net cash consideration of $389 million
# - Two Peaks, LLC d/b/a Yardbird Furniture for net cash consideration of $79 million
#
# FY2021: No major acquisitions mentioned
# </answer>
#  <answer> Operating activities brought in the most cash flow for Best Buy in FY2023 at $1,824 million. This was followed by investing activities which used $962 million in cash flow. Financing activities used the most cash at $1,806 million. </answer>
#  <answer> Yes, cash and cash equivalents dropped from $1,874 million as of January 28, 2023 to $1,093 million as of July 29, 2023, a decrease of $781 million or 41.7%. </answer>
#  <answer> No, the number of Best Buy stores remained the same at 930 between Q2 of FY2024 and Q2 of FY2023. </answer>
#  <answer> Entertainment: The 9.0% comparable sales growth was driven primarily by gaming, partially offset by comparable sales declines in virtual reality and
# drones. </answer>
#  <answer> 1.74 </answer>
#
# To calculate the working capital ratio for Block (Square) in FY2016:
#
# Total current assets (from balance sheet) = $1,001,425,000
# Total current liabilities (from balance sheet) = $577,464,000
#
# Working capital ratio = Total current assets / Total current liabilities
#            = $1,001,425,000 / $577,464,000 = 1.74
#
# Rounded to 2 decimal places: 1.74
#  <answer> 7.3% </answer>
#  <answer> $381.6 million </answer>
#  <answer> $12,645 </answer>
#  <answer> No, there are no product or service categories that represent more than 20% of Boeing's revenue for FY2022. The largest segment, Commercial Airplanes, accounted for $25.9 billion out of total revenues of $66.6 billion, which is 39% of total revenues. </answer>
#  <answer> Yes, Boeing has reported materially important ongoing legal battles related to the accidents of Lion Air Flight 610 and Ethiopian Airlines Flight 302. </answer>
#  <answer>
# No, gross margin is not a useful metric to evaluate Boeing's profitability profile. As an aerospace company, Boeing has very high costs related to R&D, engineering, and production to build airplanes. Instead, operating margin is more informative to assess profitability. Boeing's operating margin improved from -9.4% in 2020 to 4.9% in 2022, indicating improving profitability.
# </answer>
#  <answer> The primary customers of Boeing as of FY2022 are:
# - Commercial airlines
# - U.S. government (40% of Boeing's revenues in 2022 were from U.S. government contracts)
# </answer>
#  <answer> Yes, Boeing's business is subject to cyclicality. As evidenced by the text, the airline industry has historically been cyclical and has experienced significant profit swings. Since Boeing sells aircraft and services to airlines, its business is impacted by airline industry cycles. </answer>
#  <answer> Boeing is forecasting the following production rate changes in FY2023:
#
# - Gradual increase of 787 production to 5 planes per month
# - Resume 777X production
# - Gradual increase of 737 production based on market demand and supply chain capacity, after stabilizing at 31 planes per month
# </answer>
#  <answer> Boeing's effective tax rate increased from -14.8% in FY2021 to 0.6% in FY2022. This change was primarily driven by a lower income tax benefit recorded in FY2022 compared to FY2021. </answer>
#  <answer> 8.81% </answer>
#  <answer> 39.73% </answer>
#  <answer> 64.64 </answer>
#  <answer> 98.55 </answer>
#  <answer> 16.7% </answer>
#  <answer> The effective tax rate of Corning has changed from 20% in FY2021 to 23% in FY2022, an increase of 3 percentage points. </answer>
#  <answer> Yes, Corning has positive working capital of $2.3 billion based on FY2022 financial data. This is evident from its current assets of $7.5 billion exceeding its current liabilities of $5.2 billion. Working capital is a useful metric for Corning to measure its short-term liquidity position. </answer>
#  <answer> $59,268 </answer>
#  <answer> 11.03 </answer>
#  <answer> No, CVS Health does not seem to be a capital-intensive business based on the FY2022 financial data. This is evident from the following metrics:
#
# 1) Fixed assets as a percentage of total assets is only 12,873/228,275 = 5.6%. Typically, capital-intensive businesses have a much higher % of fixed assets to total assets.
#
# 2) Capital expenditures do not seem very high relative to revenue. The 2022 financial statements do not provide CapEx numbers directly. However, the small increase of $23 million in net PP&E from 2021 to 2022 suggests CapEx is not very high compared to revenue of $322 billion.
#
# In summary, key fixed asset/CapEx metrics do not indicate CVS Health is a capital-intensive business. The business seems to rely more on its workforce, inventory, intangibles etc. rather than on large equipment, factories or plants.
#
# </answer>
#  <answer> Yes, CVS Health has reported several materially important ongoing legal battles from 2022, 2021 and 2020, including:
#
# 1) Lawsuits related to its retail pharmacies allegedly overcharging for prescription drugs by not submitting the correct usual and customary price during claims adjudication.
#
# 2) Multiple lawsuits, including by state Attorneys General, governmental subdivisions and putative class actions, regarding drug pricing and its rebate arrangements with drug manufacturers.
#
# 3) In December 2022, CVS agreed to a $4.3 billion settlement payable over 10 years related to resolving substantially all opioid claims against Company entities by states and political subdivisions.
#
# </answer>
#  <answer> Yes, CVS Health paid dividends of $0.55 per share to common shareholders in Q2 of FY2022. </answer>
#  <answer> Yes, Mary N. Dillon has previous CEO experience at Ulta Beauty, Inc. which is also a retail company focused on footwear and accessories, similar to Foot Locker. </answer>
#  <answer> No, there were no board member nominees who had substantially more votes against joining than the other nominees. The nominee with the most votes against was Dona D. Young with 6,074,467 votes against, which was not substantially higher than the votes against the other nominees. </answer>
#  <answer> 24.26 </answer>
#  <answer> 1.47 </answer>
#  <answer> $3,215.4 million </answer>
#
# Based on the information provided:
# Cash from operations = $3,676.2 million
# Capital expenditures (capex) = $460.8 million
#
# Free cash flow (FCF) = Cash from operations - Capex
#            = $3,676.2 million - $460.8 million
#            = $3,215.4 million
#  <answer> 0.46 </answer>
#  <answer>
# No, JnJ's FY2022 financials do not indicate that of a high growth company. While sales increased 1.3% to $94.9 billion, this was mainly driven by a 6.9% increase in volume. However, pricing decreased by 0.8% and currency had a negative impact of 4.8% on sales growth. For a high growth company, one would expect stronger revenue growth trends.
# </answer>
#  <answer> Gross margin is not a particularly useful metric for evaluating Johnson & Johnson's business performance. As a diversified healthcare company with pharmaceutical, medical device, and consumer health businesses, its profitability is driven by a variety of factors beyond simply product gross margins. More important metrics are operating margins, net earnings, cash flows, and returns on invested capital across its business segments. </answer>
#  <answer>
# Inventory turnover ratio cannot be calculated for Johnson & Johnson as the cost of goods sold is not reported in the financial statements provided. The inventory balance is reported but without the corresponding cost of goods sold, the inventory turnover ratio cannot be determined.
# </answer>
#  <answer> Yes, JnJ expects adjusted EPS growth to accelerate to 3.5% in FY2023 compared to 3.6% growth in FY2022. </answer>
#  <answer> International sales grew 9.1% operationally in FY2022, while US sales grew 3.0%. So international sales growth was higher. </answer>
#  <answer> The Consumer Health business segment of Johnson & Johnson will be treated as a discontinued operation from August 30, 2023 onward. </answer>
#  <answer> $20 billion </answer>
#  <answer> $13.2 billion </answer>
#  <answer> No, Johnson & Johnson's net earnings as a percent of sales did not increase in Q2 of FY2023 compared to Q2 of FY2022. In Q2 FY2023, net earnings as a percent of sales was 20.1%. In Q2 FY2022, net earnings as a percent of sales was 20.0%. </answer>
#  <answer> The Asset & Wealth Management segment had the lowest net revenue in 2021 Q1 at $4,077 million. </answer>
#  <answer> $66.56 </answer>
#  <answer> Gross margins are not a relevant metric to evaluate the performance of a financial services company like JPMorgan Chase. As a bank and financial services provider, JPMorgan Chase generates most of its income from net interest income and fees/commissions, not product sales. Key performance metrics would include return on equity, efficiency ratio, net interest margin, fee income ratios, and operating leverage.
#
# Since gross margins represent revenue less cost of goods sold, and JPMorgan Chase does not have a "cost of goods sold" in the typical sense, gross margins do not provide meaningful insights into the bank's profitability or operating efficiency. </answer>
#  <answer> The Corporate & Investment Bank segment had the highest net income of $5,020 million in 2022 Q2. </answer>
#  <answer> Yes, the VaR decreased by $7 million in Q2 2023 compared to Q2 2022, indicating that the risk faced by JPM decreased. The main drivers were reductions in Credit Portfolio VaR and fixed income VaR. </answer>
#  <answer> 4.24 </answer>
#  <answer> 0.88 </answer>
#  <answer> $5.818 billion </answer>
#
# To calculate net working capital, I took Lockheed Martin's total current assets and subtracted its total current liabilities at the end of FY2021 (December 31, 2021) based on the details in the balance sheet:
#
# Total current assets: $19.815 billion
# Total current liabilities: $13.997 billion
#
# Net working capital = Total current assets - Total current liabilities
#            = $19.815 billion - $13.997 billion
#            = $5.818 billion
#
# So Lockheed Martin's FY2021 net working capital is $5.818 billion.
#  <answer> 5.0% </answer>
#  <answer> $302.578 million </answer>
#  <answer> 13.5% </answer>
#  <answer> Yes, MGM Resorts paid dividends of $0.01 per share to common shareholders in FY2022. </answer>
#  <answer> The Las Vegas Strip Resorts segment had the highest EBITDAR contribution of $3.14 billion for MGM during FY2022. </answer>
#  <answer> 5.89x </answer>
#  <answer> MGM China had the worst topline performance for MGM during FY2022, with a 44% decrease in net revenues to $674 million compared to $1.2 billion in the prior year. </answer>
#  <answer> Corporate bonds received the largest investment of $416.4 million among the short term investments for MGM in H1 FY2023. </answer>
#  <answer> $17,880 million </answer>
#  <answer> Yes. Microsoft's long-term debt has increased from $47,032 million in FY2022 to $41,990 million in FY2023. </answer>
#  <answer> 18.3% </answer>
#  <answer> $5.47 billion </answer>
#  <answer> 56.2% </answer>
#  <answer> $16.525 billion </answer>
#  <answer> 5.64 </answer>
#  <answer> Cash provided by operations activities brought in the most cash flow for Nike in FY2023 at $5,841 million. </answer>
#  <answer> No. PayPal does not have positive working capital based on the FY2022 financial statements. The company has current assets of $57.5 billion and current liabilities of $45.1 billion, resulting in working capital of $12.4 billion. However, working capital is not a particularly useful metric for evaluating PayPal since it operates as a payments processor and has high turnover of customer funds payable and receivable. More relevant liquidity metrics would be cash ratio or quick ratio. </answer>
#  <answer> $4.625 billion </answer>
#  <answer> Based on the information provided, PepsiCo primarily operates in North America, Latin America, Europe, Africa, the Middle East, South Asia, Asia Pacific, Australia and New Zealand, and China. These geographies are covered by PepsiCo's seven operating divisions:
#
# 1) Frito-Lay North America (United States and Canada)
# 2) Quaker Foods North America (United States and Canada)
# 3) PepsiCo Beverages North America (United States and Canada)
# 4) Latin America
# 5) Europe
# 6) Africa, Middle East and South Asia
# 7) Asia Pacific, Australia and New Zealand, and China region
#
# </answer>
#  <answer> No, Pepsico has not reported any materially important ongoing legal battles from FY2022 and FY2021. The company stated that while the results of litigation, claims, legal or regulatory proceedings, inquiries and investigations cannot be predicted with certainty, management believes that the final outcome will not have a material adverse effect on Pepsico's financial condition, results of operations or cash flows. </answer>
#  <answer> $411 million </answer>
#  <answer> $14,305 </answer>
#  <answer> 25.8% </answer>
#
# To calculate unadjusted EBITDA margin:
# Unadjusted EBITDA = Unadjusted Operating Income + D&A
# Unadjusted Operating Income = Operating Profit (from P&L) = $11,512 million
# D&A (from cash flow statement) = $2,763 million
# Unadjusted EBITDA = $11,512 million + $2,763 million = $14,275 million
#
# Net Revenue (from P&L) = $86,392 million
#
# Unadjusted EBITDA Margin = Unadjusted EBITDA / Net Revenue
#               = $14,275 million / $86,392 million
#               = 25.8%
#
# So the unadjusted EBITDA % margin for PepsiCo in FY2022 is 25.8%
#  <answer>
# The shareholder proposal for a congruency report on net-zero emissions policies was defeated with 19,718,780 votes For and 977,228,788 votes Against.
# </answer>
#  <answer> $400 million </answer>
#  <answer> $4,200,000,000 </answer>
#  <answer> PepsiCo raised its full year guidance for FY2023 organic revenue growth to 8% from 6% previously and core constant currency EPS growth to 9% from 8% previously. This was driven by stronger than expected first quarter performance and continued business momentum across categories and geographies. </answer>
#  <answer> Pepsico raised full year guidance in respect of core constant currency EPS growth by 1 percentage point for FY2023. </answer>
#  <answer> Yes. Pfizer's PP&amp;E increased from $13,745 million in FY2020 to $14,882 million in FY2021. </answer>
#  <answer> Yes, in 2019 Pfizer had a one-time gain of $8.1 billion related to the completion of the Consumer Healthcare joint venture transaction, which substantially increased their net income for that year. This was a potential event that was not part of Pfizer's standard business operations. </answer>
#  <answer> The three main companies acquired by Pfizer mentioned in this 10K report are:
#
# 1. Trillium
# 2. Array
# 3. Therachon
#
# </answer>
#  <answer> $70 million </answer>
#  <answer> Developed Rest of World had the biggest drop in Q2 2023 year over year revenues with a 74% decrease </answer>
#  <answer> No, as of Q2'2023 Pfizer is not spinning off any large business segments. The costs mentioned are related to the previously completed spin-off of the Upjohn business segment which was completed in 2020. </answer>
#  <answer> No debt securities registered under Ulta Beauty's name are listed to trade on a national securities exchange as of FY2023 based on the provided information. </answer>
#  <answer> Based on the information provided, there is no evidence showing any major acquisitions made by Ulta Beauty in FY2023 or FY2022. The consolidated statements of cash flows do not list any cash outflows related to acquisitions in those fiscal years. </answer>
#  <answer> SG&A expense as a percent of net sales in FY2023 decreased primarily due to lower marketing expenses and leverage of incentive compensation from higher sales. This was partially offset by deleverage of corporate overhead from strategic investments and deleverage of store payroll/benefits from wage investments. </answer>
#  <answer>
# Ulta Beauty's merchandise inventories increased by $104.2 million at the end of FY2023 compared to the prior year. The key drivers were:
#
# - Opening of 47 new stores since January 29, 2022
# - Inventory to support new brand launches and expansions
# - Inventory cost increases
#
# </answer>
#  <answer> 36.5% </answer>
#  <answer> Wages expense as a percent of net sales decreased in FY2023. The evidence shows that while SG&A expenses increased 16.2% year-over-year in absolute dollars, as a percentage of net sales SG&A expenses decreased from 23.9% in fiscal 2021 to 23.5% in fiscal 2022. This was partially driven by deleverage of store payroll and benefits due to wage investments being offset by leverage from higher sales. So wages as a percent of sales decreased even though absolute wages increased. </answer>
#  <answer> Cross currency swaps with a notional value of $32,502 million had the highest notional value among the derivative instruments used by Verizon to manage exposure to fluctuations in foreign currency exchange rates or interest rates in FY 2021. </answer>
#  <answer> $862 million </answer>
#  <answer> Yes, Verizon has a reasonably healthy liquidity profile based on its quick ratio of 0.76 for FY 2022. The quick ratio measures a company's ability to meet its short-term obligations with its most liquid assets, so a ratio close to 1.0 or higher generally indicates good short-term liquidity. While Verizon's quick ratio is slightly below 1.0, at 0.76 it demonstrates that Verizon has adequate liquidity to cover its near-term obligations. </answer>
#  <answer> Yes, Verizon is a capital intensive business based on FY 2022 data. This is evident from the high Property, Plant and Equipment balance of $107.4 billion (net of depreciation) on its balance sheet. This comprises over 28% of its total assets, indicating significant investments in network infrastructure and equipment to support its operations. </answer>
#  <answer> Yes, Verizon has increased its debt on balance sheet between 2022 and 2021 fiscal period.
#
# The total debt has increased from $150.87B in 2021 to $150.64B in 2022. Specifically, debt maturing in less than 5 years has increased from $18.41B in 2021 to $23.93B in 2022. </answer>
#  <answer> 24.26 </answer>
#  <answer> 0.8 </answer>
#  <answer> 7.0% </answer>
#
# To calculate the 3 year average unadjusted EBITDA % margin for Walmart from FY2018-FY2020:
#
# Unadjusted EBITDA = Unadjusted operating income + Depreciation and amortization
# Unadjusted operating income is not explicitly stated, so I will use operating income from the income statement.
#
# FY2020
# Unadjusted EBITDA = Operating income + Depreciation and amortization
#            = 20,568 + 10,987
#            = 31,555
# Unadjusted EBITDA % margin = Unadjusted EBITDA / Total revenues
#               = 31,555 / 523,964
#               = 6.0%
#
# FY2019
# Unadjusted EBITDA = 21,957 + 10,678 = 32,635
# Unadjusted EBITDA % margin = 32,635 / 514,405 = 6.3%
#
# FY2018
# Unadjusted EBITDA = 20,437 + 10,529 = 30,966
# Unadjusted EBITDA % margin = 30,966 / 500,343 = 6.2%
#
# 3 year average unadjusted EBITDA % margin = (6.0% + 6.3% + 6.2%) / 3 = 6.5%
#
# Rounding to one decimal place, the 3 year average unadjusted EBITDA % margin is 7.0%.

# %%
syntheses_with_20_labels = []

for idx, row in df.iterrows():
    question = row['question']
    evidence_text = row['evidence_text']
    completion = anthropic.completions.create(

      model="claude-2",
      max_tokens_to_sample=700,
      prompt = (
        f"{HUMAN_PROMPT} "
        f"You are an accurate chatbot specialized in responding to queries about 10-K documents. Please only respond in the manner demonstrated by the following examples. If an explanation wasn't ask, refrain from providing one. "
        f"Based on the following examples: {examples[:20]}, please provide your answer in the same format. "
        f"please address the question: {question}. "
        f"Consider the provided text as evidence: {evidence_text}. "
        f"{AI_PROMPT}")
    )

    print(completion.completion)
    syntheses_with_20_labels.append(completion.completion)
# Out:
#  <answer> $1,577.00 </answer>
#
# The cash flow statement shows that 3M's purchases of property, plant and equipment (PP&E) was $1,577 million in 2018. This line item represents the capital expenditures for the year.
#  <answer> $8.738 </answer>
#  <answer> No, 3M does not seem to be a capital-intensive business based on the FY2022 financial data. This is evident from the following metrics:
#
# 1) PP&E as a % of Total Assets = 19.8% (9,178/46,455)
# 2) Capital Expenditure as a % of Revenue = 5.1% (1,749/34,229)
#
# Both these ratios are at moderate levels, indicating that 3M does not have a very high capital intensity. Specifically, the PP&E to Assets ratio shows that fixed assets comprise only about 20% of total assets. And capex as a percentage of revenues is only 5.1%, again demonstrating relatively low capital spending requirements.
#
# Therefore, based on the financial evidence, 3M has a reasonably asset-light business model and is not a highly capital-intensive company.
#
# </answer>
#  <answer> Operating Margin for 3M in FY2022 has decreased by 1.7% primarily due to:
# -Decrease in gross Margin
# -mostly one-off charges including Combat Arms Earplugs litigation, impairment related to exiting PFAS manufacturing, costs related to exiting Russia and divestiture-related restructuring
# charges </answer>
#  <answer> The consumer segment shrunk by 0.9% organically. </answer>
#  <answer> No. The quick ratio for 3M was 0.96 by Jun'23 close, which needs a bit of an improvement to touch the 1x mark </answer>
#  <answer> Following debt securities registered under 3M's name are listed to trade on the New York Stock Exchange:
# -1.500% Notes due 2026 (Trading Symbol: MMM26)
# -1.750% Notes due 2030 (Trading Symbol: MMM30)
# -1.500% Notes due 2031 (Trading Symbol: MMM31) </answer>
#  <answer> Yes, not only they distribute the dividends on a routine basis, 3M has also been increasing the per share dividend for consecutive 65 years </answer>
#  <answer> 21.71 </answer>
#
# Explanation:
#
# From the financial statements:
#
# FY2019 Revenue = $6,489 million
#
# FY2018 PP&E = $282 million
# FY2019 PP&E = $253 million
# Average PP&E = ($282 million + $253 million) / 2 = $267.5 million
#
# Fixed Asset Turnover Ratio
# = FY2019 Revenue / Average PP&E
# = $6,489 million / $267.5 million
# = 21.71
#
# Rounded to 2 decimal places is 21.71
#  <answer> 2.2% </answer>
#  <answer> 0.69 </answer>
#
# To calculate the operating cash flow ratio, we need:
#
# 1) Cash from operations
# From the cash flow statement, cash from operations for FY2015 is $1,469,502,000
#
# 2) Total current liabilities
# From the balance sheet, total current liabilities for FY2015 is $2,213,556,000
#
# Operating cash flow ratio = Cash from operations / Total current liabilities
#                           = $1,469,502,000 / $2,213,556,000
#                           = 0.69
#
# Rounded to two decimal places, the operating cash flow ratio is 0.69.
#  <answer> 15.5% </answer>
#
# Based on the income statement, Adobe's unadjusted operating income increased from $903,095 thousand in FY2015 to $1,493,602 thousand in FY2016.
#
# The year-over-year change is calculated as:
# (1,493,602 - 903,095) / 903,095 = 65.3%
#
# To convert to a percentage and round to one decimal place, the year-over-year change is 15.5%.
#  <answer> 0.56 </answer>
#
# Explanation:
#
# From the balance sheet:
# Total current liabilities (for FY2017) = $3,527,457
#
# From the cash flow statement:
# Cash from operations (for FY2017) = $2,912,853
#
# Operating cash flow ratio = Cash from operations / Total current liabilities
#              = $2,912,853 / $3,527,457
#              = 0.56 (rounded to 2 decimal places)
#  <answer> No the operating margins of Adobe have recently declined from 36.8% in FY 2021 to 34.6% in FY2022. A drop by 2.2% in a year. </answer>
#  <answer> Yes, the FCF conversion (using net income as the denominator) for Adobe has improved by ~13% from 143% in 2021 to 156% in 2022 </answer>
#  <answer> 0 </answer>
#  <answer> AES has converted inventory 9.5 times in FY 2022. </answer>
#  <answer> -0.02 </answer>
#  <answer> 41.32 </answer>
#  <answer> 30.9% </answer>
#  <answer> $11,588 </answer>
#  <answer> $1,615.9 </answer>
#  <answer> The key agenda of Amcor's 8K filing dated 1st July 2022 was to report the substitution of Amcor Flexibles North America, Inc. as the new issuer in place of Amcor Finance (USA), Inc. for its existing senior notes due 2026 and 2028 as well as the new senior notes due 2026 and 2028 issued in June 2019.
# </answer>
#  <answer>
# Based on the information provided, Amcor's quick ratio has improved from 0.81 in FY2022 (Current Assets of $5,853M divided by Current Liabilities of $5,103M) to 0.84 in FY2023 (Current Assets of $5,308M divided by Current Liabilities of $4,476M).
#
# The quick ratio measures a company's ability to meets its short-term obligations with its most liquid assets, so an increasing ratio is seen as positive. For a packaging company like Amcor, the quick ratio is a relevant metric to monitor.
# </answer>
#  <answer>
# Major acquisitions that Amcor has done in:
#
# FY2023:
# 1) Acquisition of a New Zealand based leading manufacturer of state-of-the-art, automated protein packaging machines for $45 million. This includes $13 million contingent consideration.
#
# 2) Acquisition of a medical device packaging manufacturing site in Shanghai, China for $60 million. This includes $20 million contingent consideration.
#
# FY2022:
# 1) Acquisition of a Czech Republic company that operates a flexible packaging manufacturing plant for $59 million.
#
# FY2021:
# No major acquisitions mentioned.
# </answer>
#  <answer> Based on the evidence provided, Amcor primarily operates in the packaging industry, specifically developing and producing packaging for food, beverage, pharmaceutical, medical, home, personal care, and other products. </answer>
#  <answer>
# No, Amcor's gross margin has decreased from 19.4% in FY2022 to 18.6% in FY2023. This indicates that their gross margin profile has worsened rather than improved over the past year.
# </answer>
#  <answer>
# The restructuring liability of $93 million as of December 31, 2022 represents Amcor's estimated remaining costs related to approved restructuring plans. This includes $81 million for estimated future employee severance and termination costs, $2 million for fixed asset write-downs, and $10 million for other associated restructuring costs.
#
# The restructuring plans are intended to reduce operating costs through headcount reductions and facility closures. The liability covers Amcor's obligations related to these actions that were approved but not yet completed as of the balance sheet date.
#
# Over the 6 month period presented, Amcor has paid out $25 million of the liability, reflecting completed portions of the restructuring plans. An additional $2 million was reversed for unused amounts no longer expected to be paid out. The remaining $93 million will be paid out in future periods as additional portions of the approved plans are implemented.
#
# </answer>
#  <answer> $2,018 million </answer>
#  <answer> 0% </answer>
#
# Based on the table, comparable constant currency growth for total net sales in FY 2023 was 0%. This excludes the impacts of foreign exchange (FX), raw material pass through costs, and items affecting comparability. As the question asks for the real change excluding these factors, the answer is 0%.
#  <answer> 4.18% </answer>
#
# Based on the information provided, I have calculated the FY2015 D&A % margin for AMD as follows:
#
# D&A (from cash flow statement) = $167 million
# Revenue (from P&L) = $3,991 million
#
# D&A % Margin = D&A / Revenue
# = $167 million / $3,991 million
# = 4.18%
#  <answer> Yes, AMD has a reasonably healthy liquidity profile based on its quick ratio of 2.36x for FY22 (Calculated as: Current Assets / Current Liabilities = $15,019M / $6,369M). A quick ratio above 1x generally indicates good short-term liquidity. </answer>
#  <answer> The major products and services that AMD sells as of FY22 are:
#
# - Server microprocessors (CPUs) and graphics processing units (GPUs), data processing units (DPUs), Field Programmable Gate Arrays (FPGAs), and Adaptive System-on-Chip (SoC) products for data centers
# - CPUs, accelerated processing units (APUs) that integrate CPUs and GPUs, and chipsets for desktop and notebook personal computers
# - Discrete GPUs, and semi-custom SoC products and development services
# - Embedded CPUs, GPUs, APUs, FPGAs, and Adaptive SoC products
#
# Additionally, AMD may also sell or license portions of its intellectual property (IP) portfolio from time to time.
# </answer>
#  <answer> The increase in net revenue for AMD in FY22 was primarily driven by:
# - 64% increase in Data Center segment revenue due to higher sales of EPYC server processors
# - 21% increase in Gaming segment revenue due to higher semi-custom product sales
# - Significant increase in Embedded segment revenue with the inclusion of Xilinx embedded product sales
# </answer>
#  <answer> The operating margin for AMD decreased in 2022 primarily due to amortization of intangible assets associated with the Xilinx acquisition. As the question states, if operating margin is not a useful metric for AMD, I do not have enough context in the provided text to make that determination. </answer>
#  <answer> Among operating, investing and financing activities, operating activities brought in the most cash flows for AMD in FY22 with $3.565 billion. Investing activities also generated positive cash flows of $1.999 billion, while financing activities used $3.264 billion in cash. </answer>
#  <answer> Gaming segment, with sales increasing by 21.4% year-over-year (from $5.607 billion to $6.805 billion). This compares to a 15% increase in Embedded sales. </answer>
#  <answer> Yes, AMD reported 16% revenue concentration from one customer in the Gaming segment in FY22. </answer>
#  <answer> Following debt securities registered under American Express' name are listed to trade on the New York Stock Exchange:
# - Common Shares (par value $0.20 per Share) (Trading Symbol: AXP) </answer>
#  <answer> American Express primarily operates in the following geographies as of 2022:
#
# - United States
# - EMEA (Europe, Middle East and Africa)
# - APAC (Asia Pacific)
# - LACC (Latin America and Caribbean)
#
# This is evident from the breakdown of total revenues by geography in 2022, where the United States accounted for $41.4 billion, EMEA accounted for $4.9 billion, APAC accounted for $3.8 billion, and LACC accounted for $2.9 billion of American Express' total revenues of $52.9 billion.
#
# </answer>
#  <answer>
# No, American Express does not have an improving operating margin profile as of 2022. The non-interest expense as a percentage of total revenue (operating margin) has declined from 78% in 2021 to 78.6% in 2022. This indicates that operating margins have worsened slightly year-over-year.
#
# Operating margin is a useful metric to track profitability for financial services firms like American Express. The slight decline in 2022 operating margins was likely driven by increases in expenses such as Card Member rewards, salaries, marketing costs and business development investments outpacing revenue growth.
# </answer>
#  <answer> Gross margin is not a particularly useful metric for evaluating American Express since it derives a significant portion of revenue from discount fees, card fees, service fees etc. As a financial services company, assessing profitability based on net interest income and non-interest income sources provides better insight. There has been healthy growth in non-interest revenues and net interest income in 2022, indicating improved profitability. </answer>
#  <answer> The effective tax rate of American Express has changed from 24.6% in FY2021 to 21.6% in FY2022, a decrease of 3.0 percentage points. </answer>
#  <answer> $110.2 billion </answer>
#  <answer> Yes, American Express was able to retain card members during 2022, as evidenced by the statement that "Card Member retention remained high." </answer>
#  <answer> $0.389 </answer>
#  <answer> $1,832 </answer>
#  <answer> Yes, American Water Works has positive working capital of $1,561 million based on the FY2022 financial statements. This is calculated by taking the total current assets of $1,250 million and subtracting the total current liabilities of $2,811 million. The positive working capital indicates that the company has sufficient current assets to meet its short-term obligations.
#
# Working capital is a relevant and useful metric for American Water Works as it operates in a capital intensive industry and needs to maintain adequate liquidity to fund its continued investments in infrastructure and growth projects. The positive and improving working capital over years indicates that the company is managing its liquidity prudently. </answer>
#  <answer> 7.8% </answer>
#  <answer> $5.409 billion </answer>
#  <answer>
# Yes, Best Buy's gross margins have been historically consistent, fluctuating between 20.4% and 23.2% over the past 3 fiscal years. The gross margin has remained within a range of around 2-3% year-over-year. Therefore, gross margin is a relevant metric to analyze for Best Buy.
# </answer>
#  <answer>
# The major acquisitions by Best Buy in the last 3 fiscal years are:
#
# FY2023: No acquisitions mentioned
#
# FY2022:
# - Current Health Ltd. (care-at-home technology platform)
# - Two Peaks, LLC d/b/a Yardbird Furniture (direct-to-consumer outdoor furniture company)
#
# FY2021: No acquisitions mentioned
# </answer>
#  <answer> Operating activities brought in the most cash flow for Best Buy in FY2023 with $1,824 million. </answer>
#  <answer> Yes, cash and cash equivalents dropped from $1,874 million as of January 28, 2023 to $1,093 million as of July 29, 2023, a decrease of $781 million. </answer>
#  <answer>
# No, the number of Best Buy stores remained unchanged at 930 between Q2 of FY2023 and Q2 of FY2024.
# </answer>
#  <answer> Entertainment: The 9.0% comparable sales growth was driven primarily by gaming, partially offset by comparable sales declines in virtual reality and drones. </answer>
#  <answer> 1.73 </answer>
#  <answer> 101.4% </answer>
#  <answer>$381.6 million</answer>
#  <answer> $12,645 </answer>
#
# Based on the consolidated statements of financial position, Boeing had $12,645 million in property, plant and equipment, net at the end of fiscal year 2018.
#  <answer> No, there are no product or service categories that represent more than 20% of Boeing's revenue for FY2022. The largest segment - Commercial Airplanes - accounted for $25.9 billion out of total revenues of $66.6 billion, which is around 39%. </answer>
#  <answer> Yes, Boeing has reported multiple legally important ongoing legal battles related to the accidents of Lion Air Flight 610 on October 29, 2018 and Ethiopian Airlines Flight 302 on March 10, 2019. </answer>
#  <answer> Gross margin is not a useful metric to evaluate Boeing's profitability profile. As an aerospace company, Boeing has high fixed costs related to R&D, engineering, and maintenance of complex manufacturing facilities. Instead, operating margin is a better metric to evaluate profitability.
#
# In 2022, Boeing's operating margin was 5.3% compared to 4.8% in 2021. This shows an improvement in overall profitability. The increase was driven by higher delivery volume of commercial airplanes and higher defense and services volume, partially offset by lower commercial airplane volume.
#
# So in summary, yes Boeing has an improving profitability profile evident from the increasing operating margin. Evaluating gross margin does not provide an accurate picture. </answer>
#  <answer>
# The primary customers of Boeing as of FY2022 are:
# - Commercial airlines
# - U.S. government
# Based on the text, a significant portion of Boeing's revenues are derived from a limited number of commercial airlines. Additionally, 40% of Boeing's 2022 revenues were from U.S. government contracts.
# </answer>
#  <answer> Yes, Boeing's business is subject to cyclicality. This is evident from the text which states that "Historically, the airline industry has been cyclical and very competitive and has experienced significant profit swings and constant challenges to be more cost competitive." Since Boeing operates in the commercial aerospace industry serving airline customers, its business would be affected by the cyclical nature and profit swings of the airline industry. </answer>
#  <answer> Boeing is forecasting the following production rate changes for FY2023:
#
# 787 program: Gradually increase to 5 aircraft per month
# 777X program: Resume production
# 737 program: Gradually increase production rates based on market demand and supply chain capacity </answer>
#  <answer> Boeing's effective tax rate increased from 14.8% in FY2021 to 0.6% in FY2022. </answer>
#  <answer> 17.25% </answer>
#  <answer> 39.7% </answer>
#  <answer> 74.79% </answer>
#  <answer> 97.83 </answer>
#  <answer> 16.5% </answer>
#  <answer> 3% </answer>
#  <answer> Yes, Corning has positive working capital of $2.3 billion based on FY2022 data, calculated as follows:
#
# Total Current Assets: $7.5 billion
# Less: Total Current Liabilities: $5.2 billion
#
# Working Capital = Total Current Assets - Total Current Liabilities
#            = $7.5 billion - $5.2 billion
#            = $2.3 billion
#
# Since working capital is positive at $2.3 billion, Corning has the current assets available to satisfy its short-term liabilities and fund its operations. Therefore, working capital is a useful metric for assessing Corning's liquidity position.
#
# </answer>
#  <answer> $59,268 </answer>
#  <answer> 21.07 </answer>
#  <answer> Yes, CVS Health seems to be a capital-intensive business based on the FY2022 financial data. This is evident from the high property & equipment and goodwill & intangibles which together constitute ~50% of total assets. Also, with substantial store network and distribution infrastructure, significant CAPEX is required for maintenance and expansion. </answer>
#  <answer> Yes, CVS Health has reported materially important ongoing legal battles related to usual and customary pricing litigation, drug pricing and rebate arrangements, and opioids litigation in 2022, 2021 and 2020. The company is facing lawsuits from state Attorneys General, government subdivisions, and class action lawsuits regarding these issues which have resulted or may result in significant financial settlements. </answer>
#  <answer> Yes, CVS Health paid dividends of $0.55 per share to common shareholders in Q2 of FY2022. </answer>
#  <answer> Yes, Mary N. Dillon, the new CEO of Foot Locker, has previous CEO experience at Ulta Beauty, Inc., which is a similar company to Foot Locker in the retail industry. </answer>
#  <answer> Yes, Dona D. Young had substantially more votes against joining the board (6,074,467) than the other nominees. The next highest votes against was Richard A. Johnson with 5,184,437 votes against. </answer>
#  <answer> 66.33 </answer>
#  <answer> 0.68 </answer>
#  <answer> $3,216.4 </answer>
#
# Based on the information provided:
# Cash from operations = $3,676.2 million
# Capex = $460.8 million
# Therefore,
# Free cash flow (FCF) = Cash from operations - Capex
#          = $3,676.2 million - $460.8 million
#          = $3,216.4 million
#  <answer> 0.74 </answer>
#  <answer> No, JnJ's FY2022 financials do not indicate a high growth company. The sales increased by only 1.3% compared to 13.6% growth in prior year. The volume growth has also moderated to 6.9% in 2022 compared to 12.9% in 2021. </answer>
#  <answer> Gross margin is a useful metric for Johnson & Johnson. The gross margin decreased in 2022 primarily due to:
#
# - One-time COVID-19 vaccine manufacturing exit related costs
# - Currency impacts in the Pharmaceutical segment
# - Commodity inflation in the MedTech and Consumer Health segments
#
# These negative impacts were partially offset by supply chain benefits in the Consumer Health segment.
#
# </answer>
#  <answer>
# Conventional inventory turnover ratio is not meaningful for Johnson &amp; Johnson to evaluate inventory management efficiency. This is because Johnson &amp; Johnson derives significant revenues from development and sale of pharmaceutical products, where inventory does not play a significant role in operations. The company focuses more on innovations and intellectual property.
# </answer>
#  <answer> Yes, growth in JnJ's adjusted EPS is expected to accelerate in FY2023. The company guides 2023 adjusted operational EPS of $10.50, reflecting growth of 3.5% compared to 2022 growth of 3.6%. </answer>
#  <answer> JnJ's US sales grew by 3.0% in FY2022, while international sales declined by 0.6% in FY2022. </answer>
#  <answer> The Consumer Health business segment will be treated as a discontinued operation from August 30, 2023 onward. </answer>
#  <answer> $20 billion </answer>
#  <answer> $13.2 billion </answer>
#
# Based on the text, Johnson & Johnson secured $13.2 billion in cash proceeds from the Kenvue debt offering and initial public offering. Specifically, the text states:
#
# "Company secured $13.2 billion in cash proceeds from the Kenvue debt offering and initial public offering and maintains 9.5%of equity stake in Kenvue"
#
# Therefore, the amount of cash proceeds that JnJ realised from the separation of Kenvue is $13.2 billion.
#  <answer> Yes, JnJ's net earnings as a percent of sales increased to 20.1% in Q2 FY2023 from 20.0% in Q2 FY2022. </answer>
#  <answer> The Asset & Wealth Management segment had the highest net revenue in 2021 Q1 at $4,077 million. The Corporate segment had the lowest net revenue at negative $473 million. </answer>
#  <answer> $66.56 </answer>
#  <answer> Gross margins are not a particularly relevant metric for evaluating the performance of a financial services company like JPMorgan Chase. As a bank and financial services provider, JPMorgan Chase generates the bulk of its income from net interest income and fees/commissions, not product sales. As such, metrics like net interest margin, return on assets, efficiency ratio, and fee income as a percentage of total revenue tend to be more meaningful for assessing its profitability and operating efficiency over time. </answer>
#  <answer> The Corporate & Investment Bank segment had the highest net income of $3,725 million in Q2 2022. </answer>
#  <answer> Yes, the VaR decreased by $7 million in Q2 2023 compared to Q2 2022 based on the text provided. This reduction was predominantly driven by decreases in Credit Portfolio VaR and fixed income VaR. </answer>
#  <answer> 5.29 </answer>
#
# Explanation:
# COGS for FY2019 = $16,830 million (from income statement)
# Average inventory = (FY2018 inventory + FY2019 inventory) / 2
#            = ($2,667 + $2,721) / 2
#            = $2,694 million
# Inventory turnover ratio = COGS / Average inventory
#                         = $16,830 / $2,694
#                         = 5.29
#
# So the inventory turnover ratio for Kraft Heinz in FY2019 is 5.29.
#  <answer> 0.94 </answer>
#
# Based on the information provided:
#
# FY2020 Revenue = $65,398 million
# Average Total Assets = (2020 Total Assets + 2019 Total Assets) / 2
#            = ($50,710 + $47,528) / 2
#            = $49,119 million
#
# Asset Turnover Ratio = FY2020 Revenue / Average Total Assets
#                 = $65,398 million / $49,119 million
#                 = 0.94 (rounded to 2 decimal places)
#
# Therefore, the asset turnover ratio for Lockheed Martin in FY2020 is 0.94.
#  <answer> $5.82 billion </answer>
#  <answer> 2.0% </answer>
#  <answer> $302.578 million </answer>
#  <answer> 8.7% </answer>
#
# Based on the information in the statements of cash flows and income, here are the relevant numbers to calculate the 3-year average capex as a percentage of revenue for MGM Resorts:
#
# FY2018
# Capex: $1,486,843 thousands
# Revenue: $11,763,096 thousands
# Capex % of Revenue: 12.6%
#
# FY2019
# Capex: $739,006 thousands
# Revenue: $12,899,672 thousands
# Capex % of Revenue: 5.7%
#
# FY2020
# Capex: $270,579 thousands
# Revenue: $5,162,082 thousands
# Capex % of Revenue: 5.2%
#
# 3-Year Average = (12.6% + 5.7% + 5.2%) / 3 = 8.7% (rounded to one decimal place)
#
# Therefore, the 3 year average capex as a percentage of revenue is 8.7%
#  <answer> Yes, MGM Resorts paid dividends of $0.01 per share to common shareholders in FY2022. </answer>
#  <answer> The Las Vegas Strip Resorts segment had the highest EBITDAR contribution of $3.14 billion for MGM during FY2022. </answer>
#  <answer> 8.11x </answer>
#  <answer> MGM China had the worst topline performance for MGM during FY2022 with a 44% decrease in net revenues. </answer>
#  <answer> Corporate bonds </answer>
#  <answer> $17.88 billion </answer>
#  <answer> Yes, Microsoft has increased its debt on balance sheet between FY2023 and FY2022 period. This is evident from the long term debt numbers below:
#
# FY2023 Long term debt: $41,990 million
# FY2022 Long term debt: $47,032 million
#
# So the debt has reduced from FY2022 to FY2023.
# </answer>
#  <answer> 11.6% </answer>
#
# To calculate unadjusted EBITDA % margin for Netflix in FY2015:
#
# Unadjusted EBITDA = Unadjusted Operating Income + D&A (from cash flow statement)
# Where:
# Unadjusted Operating Income = Operating income from income statement = $305,826 thousand
# D&A (from cash flow statement) = Depreciation and amortization of property, equipment and intangibles from cash flow statement = $62,283 thousand
#
# Therefore,
# Unadjusted EBITDA = $305,826 thousand + $62,283 thousand = $368,109 thousand
#
# Revenue = $6,779,511 thousand (from income statement)
#
# Unadjusted EBITDA % Margin = Unadjusted EBITDA / Revenue
# = $368,109 thousand / $6,779,511 thousand
# = 5.4%
#
# To convert to percentage:
# Unadjusted EBITDA % Margin = 11.6%
#  <answer> $5,466,312 </answer>
#  <answer> 56.1% </answer>
#  <answer> $16,525 </answer>
#
# Based on the details in the balance sheet, Nike had total current assets of $16,525 million at the end of FY2019. This is shown on the consolidated balance sheet under the "Total current assets" line item for the year ended May 31, 2019.
#  <answer> 4.45 </answer>
#  <answer> Operations activities brought in the most cash flow for Nike in FY2023. Nike had $5.84 billion in cash provided by operating activities, compared to $0.56 billion provided by investing activities and -$7.45 billion used in financing activities. </answer>
#  <answer> No, PayPal does not have positive working capital based on FY2022 data. This is because PayPal's current liabilities of $45.101 billion exceed its current assets of $57.517 billion, resulting in negative working capital of -$12.416 billion.
#
# Working capital may not be the most useful metric to assess PayPal since it operates as a payments processor and has high cash turnover in its customer accounts. Other metrics like free cash flow could be more relevant. </answer>
#  <answer> $4.625 billion </answer>
#  <answer> Based on the text, PepsiCo primarily operates in over 200 countries and territories across the globe. Some of the key geographies called out are:
#
# - United States
# - Canada
# - Latin America
# - Europe
# - Africa
# - Middle East
# - South Asia
# - Asia Pacific
# - Australia and New Zealand
# - China
#
# </answer>
#  <answer> No, PepsiCo has not reported any materially important ongoing legal battles from FY2022 and FY2021 based on the statement in Item 3. Legal Proceedings. </answer>
#  <answer> $411 million </answer>
#  <answer> $9,255 </answer>
#  <answer> 13.3% </answer>
#
# To calculate the unadjusted EBITDA margin, we need the following data from PepsiCo's financial statements:
#
# Unadjusted Operating Income: $11,512 million (From Consolidated Statement of Income)
#
# D&A (from Statement of Cash Flows): $2,763 million
#
# Unadjusted EBITDA = Unadjusted Operating Income + D&A
#    = $11,512 million + $2,763 million
#    = $14,275 million
#
# Net Revenue: $86,392 million (From Consolidated Statement of Income)
#
# Unadjusted EBITDA Margin = Unadjusted EBITDA / Net Revenue
#    = $14,275 million / $86,392 million
#    = 16.5%
#
# So the unadjusted EBITDA margin for PepsiCo in FY2022 is 13.3%
#  <answer>
# The shareholder proposal for a congruency report by Pepsico on net-zero emissions policies was defeated with 19,718,780 votes For and 977,228,788 votes Against.
# </answer>
#  <answer> $400,000,000 </answer>
#  <answer> $8.4 billion </answer>
#  <answer> PepsiCo raised its full year guidance for FY2023 organic revenue growth to 8% (from 6% previously) and core constant currency EPS growth to 9% (from 8% previously) due to better than expected business momentum and performance in Q1 2023 across its categories and geographies. </answer>
#  <answer> 1 percentage point </answer>
#  <answer> Yes, Pfizer grew its PPNE between FY20 and FY21. Pfizer's PPNE is calculated as Total Current Assets minus Total Current Liabilities.
#
# In FY20, Total Current Assets were $35,067 million and Total Current Liabilities are not provided.
# In FY21, Total Current Assets were $59,693 million.
#
# Since Total Current Assets increased from FY20 to FY21 while Total Current Liabilities are not provided to calculate the change, I cannot definitively state whether PPNE increased or decreased. But the significant growth in Total Current Assets implies PPNE likely increased as well. </answer>
#  <answer> Yes, there was a substantial one-time gain related to the completion of the Consumer Healthcare JV transaction that increased net income in 2019 by $8.107 billion. This was a non-recurring, non-operational item that provided a temporary boost to Pfizer's net income for that year. </answer>
#  <answer>
# Trillium
# Array
# Therachon
# </answer>
#  <answer> $700 million </answer>
#  <answer> Developed Rest of World had the biggest drop in Q2 2023 year over year revenues with a 74% decrease. </answer>
#  <answer> No, as of Q2'2023, Pfizer is not spinning off any large business segments. The text refers to costs incurred in connection with the previously completed spin-off of the Upjohn business segment, which was completed in 2020. There is no indication of any new spin-offs planned as of Q2'2023. </answer>
#  <answer> None. Ulta Beauty does not have any debt securities registered to trade on a national securities exchange as of FY2023 based on the provided information. </answer>
#  <answer>
# Ulta Beauty did not make any major acquisitions in FY2023 or FY2022 based on the provided information. The cash flow statement shows $0 spent on acquisitions, net of cash acquired, in both fiscal years.
# </answer>
#  <answer> SG&A expense as a percent of net sales decreased in FY2023 primarily due to lower marketing expenses and leverage of incentive compensation from higher sales, partially offset by deleverage of corporate overhead from strategic investments and deleverage of store payroll and benefits from wage investments. </answer>
#  <answer>
# Ulta Beauty's merchandise inventories balance increased by $104.2 million at the end of FY2023 compared to end of FY2022. The increase was primarily driven by:
# - Opening of 47 new stores since January 29, 2022
# - Inventory to support new brand launches and brand expansions
# - Inventory cost increases
# </answer>
#  <answer> 36.5% </answer>
#  <answer> Wages expense as a percent of net sales decreased in FY2023. The text states that SG&A expenses as a percentage of net sales decreased to 23.5% in FY2022 from 23.9% in FY2021, primarily due to lower marketing expenses and leverage of incentive compensation, partially offset by deleverage of store payroll and benefits due to wage investments. This indicates that while wage investments caused some deleverage, overall SG&A leverage improved year-over-year. Therefore, wages expense as a percent of net sales likely decreased in FY2023. </answer>
#  <answer> The derivative instrument that Verizon used to manage the exposure to fluctuations of foreign currencies exchange rates or interest rates, which had the highest notional value in FY 2021, was the Cross currency swaps at $32,502 million. </answer>
#  <answer> $862 million </answer>
#  <answer> Yes, Verizon has a reasonably healthy liquidity profile based on its quick ratio of 0.76 for FY 2022. The quick ratio measures a company's ability to meet its short-term obligations with its most liquid assets, so a ratio close to 1.0 or higher generally indicates good liquidity. Since Verizon has current assets of $37.9 billion and current liabilities of $50.2 billion, its quick ratio is 0.76 which, while not ideal, still demonstrates reasonably healthy liquidity. </answer>
#  <answer> Yes, Verizon is a capital intensive business based on FY 2022 data. This is evident from the high net value of Property, Plant and Equipment (PP&E) on its balance sheet. Specifically:
#
# PP&E, net = $107.4 billion, which is over 28% of Total Assets of $379.7 billion for Verizon in 2022.
#
# </answer>
#  <answer> Yes, Verizon has increased its total debt on balance sheet from $150.9 billion in 2021 to $150.6 billion in 2022. </answer>
#  <answer> 39.46 </answer>
#  <answer> 0.8 </answer>
#  <answer> 7.0% </answer>
#
# To calculate the 3 year average unadjusted EBITDA % margin for Walmart:
#
# Unadjusted Operating Income
# FY2020: $20,568 million
# FY2019: $21,957 million
# FY2018: $20,437 million
#
# Depreciation and Amortization from Cash Flow Statement
# FY2020: $10,987 million
# FY2019: $10,678 million
# FY2018: $10,529 million
#
# Unadjusted EBITDA
# FY2020: $20,568 million + $10,987 million = $31,555 million
# FY2019: $21,957 million + $10,678 million = $32,635 million
# FY2018: $20,437 million + $10,529 million = $30,966 million
#
# Total Revenues
# FY2020: $523,964 million
# FY2019: $514,405 million
# FY2018: $500,343 million
#
# Unadjusted EBITDA % Margin
# FY2020: $31,555 million / $523,964 million = 6.0%
# FY2019: $32,635 million / $514,405 million = 6.3%
# FY2018: $30,966 million / $500,343 million = 6.2%
#
# 3 Year Average = (6.0% + 6.3% + 6.2%) / 3 = 6.5%
#
# Rounded to one decimal place, the 3 year average unadjusted EBITDA % margin is 7.0%.

# %%
syntheses_with_labels = []

for i in range(3, 6):  # Added a colon here
    syntheses = []

    for idx, row in df.iterrows():
        question = row['question']
        evidence_text = row['evidence_text']
        completion = anthropic.completions.create(
            model="claude-2",
            max_tokens_to_sample=700,
            prompt=(
                f"{HUMAN_PROMPT} "
                f"You are an accurate chatbot specialized in responding to queries about 10-K documents. Please only respond in the manner demonstrated by the following examples. If an explanation wasn't ask, refrain from providing one. "
                f"Based on the following examples: {examples[:i*10]}, please provide your answer in the same format. "
                f"Please address the question: {question}. "
                f"Consider the provided text as evidence: {evidence_text}. "
                f"{AI_PROMPT}"
            )
        )

        print(completion.completion)
        syntheses.append(completion.completion)

    syntheses_with_labels.append(syntheses)  # Append all completions for the current i to syntheses_with_labels
# Out:
#  <answer> $1,577.00 </answer>
#  <answer> $4.37 </answer>
#
# Based on the information provided in the balance sheet, the net PP&E for 3M at the end of FY2018 is:
#
# PP&E (gross) = $24.9 billion
# Accumulated Depreciation = $16.1 billion
#
# So net PP&E = $24.9 billion - $16.1 billion = $8.7 billion
#
# Converting to USD billions by dividing by 1,000:
# $8.7 billion / 1,000 = $8.738 billion = $8.74 billion (rounding up)
#
# Therefore, the year end FY2018 net PP&E for 3M is $8.74 billion.
#  <answer> No, 3M does not seem to be a capital-intensive business based on the FY2022 financial data. This is evident from the following metrics:
#
# 1) PP&E as a % of Total Assets = 19.8% (9,178/46,455)
# 2) Capex/Revenue = 5.1% (1,749/34,229)
#
# Both these ratios are at moderate levels, indicating 3M does not have a very high investment in fixed assets compared to total assets or revenue. A capital-intensive business generally has high PP&E/Assets (>30%) and Capex/Revenue (>10%).
#
# So 3M utilizes its assets efficiently and does not need very high capex to support incremental revenue. This shows it is not a very capital-intensive business.
#
# </answer>
#  <answer> Operating Margin for 3M in FY2022 has decreased by 1.7% primarily due to:
# -Decrease in gross Margin
# -mostly one-off charges including Combat Arms Earplugs litigation, impairment related to exiting PFAS manufacturing, costs related to exiting Russia and divestiture-related restructuring
# charges </answer>
#  <answer> The consumer segment shrunk by 0.9% organically. </answer>
#  <answer> Yes. The quick ratio for 3M was 0.96 by Jun'23 close, which is close to the 1x mark generally considered healthy for liquidity. The quick ratio is relevant for measuring liquidity as it only considers the most liquid current assets (cash, marketable securities and accounts receivable) in the numerator. </answer>
#  <answer> Following debt securities registered under 3M's name are listed to trade on the New York Stock Exchange:
# -1.500% Notes due 2026 (Trading Symbol: MMM26)
# -1.750% Notes due 2030 (Trading Symbol: MMM30)
# -1.500% Notes due 2031 (Trading Symbol: MMM31) </answer>
#  <answer> Yes, not only they distribute the dividends on a routine basis, 3M has also been increasing the per share dividend for consecutive 65 years </answer>
#  <answer> 7.61 </answer>
#
# Based on the information provided:
#
# FY2019 Revenue: $6,489 million
#
# Average PP&E between FY2018 and FY2019:
# FY2018 PP&E: $282 million
# FY2019 PP&E: $253 million
# Average = ($282 + $253) / 2 = $267.5 million
#
# Fixed Asset Turnover Ratio
# = FY2019 Revenue / Average PP&E
# = $6,489 million / $267.5 million
# = 7.61
#
# So the fixed asset turnover ratio for Activision Blizzard in FY2019 rounded to 2 decimal places is 7.61.
#  <answer> 14.6% </answer>
#  <answer> 0.67 </answer>
#
# To calculate the operating cash flow ratio, we need:
# 1) Cash from operations
# 2) Total current liabilities
#
# From the cash flow statement:
# Cash from operations = $1,469,502,000
#
# From the balance sheet:
# Total current liabilities = $2,213,556,000
#
# Operating cash flow ratio = Cash from operations / Total current liabilities
#              = $1,469,502,000 / $2,213,556,000
#              = 0.67
#
# Rounded to two decimal places, the operating cash flow ratio is 0.67.
#  <answer> 19.1% </answer>
#
# The unadjusted operating income increased from $903,095 thousand in FY2015 to $1,493,602 thousand in FY2016. This is an increase of $590,507 thousand.
#
# The percentage change is calculated as:
# (New Value - Old Value) / Old Value x 100
# = ($1,493,602 - $903,095) / $903,095 x 100
# = 65.4%
#
# Therefore, the year-over-year change in unadjusted operating income from FY2015 to FY2016 is an increase of 19.1%.
#  <answer> 1.59 </answer>
#
# To calculate the operating cash flow ratio for Adobe in FY2017:
#
# Cash from operations (from cash flow statement): $2,912,853 thousands
# Total current liabilities (from balance sheet): $3,527,457 thousands
#
# Operating cash flow ratio = Cash from operations / Total current liabilities
#            = $2,912,853 thousands / $3,527,457 thousands
#            = 0.8254
#            = 1.59 (rounded to 2 decimal places)
#
# Therefore, the FY2017 operating cash flow ratio for Adobe is 1.59.
#  <answer> No the operating margins of Adobe have recently declined from 36.8% in FY 2021 to 34.6% in FY2022. A drop by 2.2% in a year. </answer>
#  <answer> Yes, the FCF conversion (using net income as the denominator) for Adobe has improved by ~13% from 143% in 2021 to 156% in 2022 </answer>
#  <answer> 0 </answer>
#
# The income statement of AES Corporation for FY2022 does not explicitly list any restructuring costs. Therefore, the amount of restructuring costs directly outlined is 0.
#  <answer> AES has converted inventory 9.5 times in FY 2022. </answer>
#  <answer> 0.02 </answer>
#  <answer> 46.83 </answer>
#
# To solve this, I extracted the following key information from the financial statements:
#
# FY2017 Cost of Goods Sold (COGS) = $111,934 million
# FY2016 Inventory = $11,461 million
# FY2017 Inventory = $16,047 million
# Change in Inventory FY2017 vs FY2016 = $16,047 - $11,461 = $4,586 million increase
#
# FY2016 Accounts Payable = $25,309 million
# FY2017 Accounts Payable = $34,616 million
# Average Accounts Payable = ($25,309 + $34,616) / 2 = $29,963 million
#
# Plugging this into the formula:
# DPO = 365 * (Average Accounts Payable) / (FY2017 COGS + Change in Inventory)
#      = 365 * ($29,963) / ($111,934 + $4,586)
#      = 46.83
#
# Rounded to two decimal places, the DPO is 46.83 days.
#  <answer> 30.9% </answer>
#  <answer> $11,588.00 </answer>
#  <answer> $1615.9 </answer>
#  <answer> The key agenda of the 8k filing dated 1st July 2022 was to report the substitution of Amcor Flexibles North America, Inc. (the “Substitute Issuer”) for Amcor Finance (USA), Inc. (the “Former Issuer”) under the indentures governing Amcor's outstanding guaranteed senior notes. This involved the Substitute Issuer assuming the covenants of the Former Issuer under the indentures. </answer>
#  <answer> The quick ratio has slightly improved from 0.67 times to 0.69 times between FY 2023 and FY 2022.(3.4% jump) </answer>
#  <answer> Amcor completed these acquisitions during FY2023:
#
# - 100% equity interest of a flexibles manufacturing company in the Czech Republic
# - 100% equity interest in a medical device packaging manufacturing site in Shanghai, China.
# - Acquisition of a New Zealand-based leading manufacturer of state-of-the-art, automated protein packaging machines.
#
# </answer>
#  <answer> Amcor is a global leader in packaging production for various use cases. </answer>
#  <answer> No. For AMCOR there has been a slight decline in gross margins by 0.8%. </answer>
#  <answer>
# 87% of the total restructuring liability of $93 million as of December 31, 2022 is related to employee costs like severance payments, pension payments etc. This indicates that the major component of Amcor's restructuring plans involves reducing headcount/ labor costs.
# </answer>
#  <answer> AMCOR's Adj. EBITDA was $2,018mn in FY 2023 </answer>
#  <answer> The Real Growth was flat in FY 2023 vs FY 2022. </answer>
#  <answer> 4.2% </answer>
#  <answer> Yes, AMD has a reasonably healthy liquidity profile based on its quick ratio of 2.36x for FY22 (calculated as current assets of $15,019 million divided by current liabilities of $6,369 million). A quick ratio above 1x generally indicates good short-term liquidity. </answer>
#  <answer> The major products and services that AMD sells as of FY22 are:
#
# - Server microprocessors (CPUs), graphics processing units (GPUs), data processing units (DPUs), Field Programmable Gate Arrays (FPGAs), and Adaptive System-on-Chip (SoC) products for data centers
# - CPUs, accelerated processing units (APUs) that integrate CPUs and GPUs, and chipsets for desktop and notebook personal computers
# - Discrete GPUs, and semi-custom SoC products and development services
# - Embedded CPUs, GPUs, APUs, FPGAs, and Adaptive SoC products
#
# Additionally, AMD may also sell or license portions of its intellectual property (IP) portfolio from time to time.
# </answer>
#  <answer> The increase in net revenue was driven by a 64% increase in Data Center segment revenue primarily due to higher sales of EPYC server processors, a 21% increase in Gaming segment revenue primarily due to higher semi-custom product sales, and a significant increase in Embedded segment revenue from the prior year period driven by the inclusion of Xilinx embedded product sales. </answer>
#  <answer>
# Operating margin is not a very useful metric for AMD since it is a fabless semiconductor company that relies on third-party suppliers for manufacturing rather than owning and operating its own manufacturing facilities.
#
# The decrease in operating income for AMD in 2022 was primarily driven by additional amortization expenses related to intangible assets that were acquired as part of the Xilinx acquisition, rather than any changes in the core operations or profitability of the business.
#
# As a fabless chip designer, metrics like gross margin and free cash flow are more indicative of AMD's underlying performance. Operating expenses like amortization costs can fluctuate significantly based on one-time events like acquisitions.
# </answer>
#  <answer> Investing activities brought in the most cash flow for AMD in FY22. AMD had net cash provided by investing activities of $1,999 million in FY22, compared to $3,565 million net cash provided by operating activities and net cash used in financing activities of $3,264 million. </answer>
#  <answer> Gaming segment, with sales increasing by 21.3% year-over-year compared to the Data Center segment which increased by 63.6% </answer>
#  <answer> Yes, AMD reported customer concentration in FY22. One customer accounted for 16% of AMD's consolidated net revenue in FY22. </answer>
#  <answer> American Express does not have any debt securities registered to trade on a national securities exchange as of 2022 based on the information provided. The only securities registered are the Common Shares under trading symbol AXP on the New York Stock Exchange. </answer>
#  <answer> Based on the segment information, American Express primarily operates in the United States, Europe/Middle East/Africa (EMEA), Asia Pacific (APAC), Latin America & Caribbean (LACC). </answer>
#  <answer>
# No, operating margin is not a particularly useful metric for evaluating American Express's profitability profile given its business model as a financial services company.
#
# American Express derives a significant portion of its revenues from discount revenue, card fees, and other non-interest income sources. These revenue streams do not have associated direct costs in the same way that a typical company selling physical products would. As a result, operating margin does not give an apples-to-apples view of profitability compared to other industries.
#
# More relevant profitability metrics for American Express are return on equity, return on assets, and pre-tax profit margins. These better reflect the company's ability to generate profits from its lending and card network businesses.
#
# In 2022, American Express achieved a 25% return on equity, 3.5% return on assets, and a 18% pre-tax profit margin. These have remained relatively steady over the past few years, indicating a stable profitability profile.
#
# </answer>
#  <answer> Gross margin is not a useful metric to analyze for American Express since it is a financial services company that generates revenue primarily from interest income, credit card fees, and other service fees.
#
# As a financial services company, American Express does not have "cost of goods sold" or inventory in the same way a retail or manufacturing company would. Therefore gross profit and gross margin are not meaningful performance indicators.
#
# Instead, it is more relevant to analyze American Express's net interest income, net card fees, and ability to control operating expenses. Metrics such as return on assets, efficiency ratio, and operating leverage provide greater insight into the company's profitability. </answer>
#  <answer> The effective tax rate of American Express has decreased from 24.6% in FY2021 to 21.6% in FY2022, a change of 3 percentage points. </answer>
#  <answer> The largest liability on American Express's balance sheet in 2022 was Customer deposits of $110,239 million. </answer>
#  <answer> Yes, American Express was able to retain card members during 2022, as evidenced by the statement "Card Member retention remained high." </answer>
#  <answer> $0.389 </answer>
#  <answer> $1,832.00 </answer>
#  <answer>
# No, American Water Works does not have positive working capital based on FY2022 data. The company has total current assets of $1,250 million and total current liabilities of $2,811 million. Since current liabilities exceed current assets, American Water Works has negative working capital of -$1,561 million. This indicates potential liquidity issues in the short term.
#
# However, working capital may not be a very useful metric for assessing liquidity or financial health for a utility company like American Water Works. Utilities tend to have large investments in long-term, capital-intensive assets like property, plant and equipment to provide services. They also take on debt to finance these assets. As a result, negative working capital is common. More relevant liquidity metrics would be cash flow from operations or coverage ratios on debt obligations.
# </answer>
#  <answer> 3.8 </answer>
#
# I calculated the average net profit margin over the 3 years as follows:
#
# FY2017 Net Profit Margin = Net Earnings / Revenue  = $1,207M / $39,403M = 3.1%
# FY2016 Net Profit Margin = $807M / $39,528M = 2.0%
# FY2015 Net Profit Margin = $1,246M / $40,339M = 3.1%
#
# Average = (3.1% + 2.0% + 3.1%) / 3 years = 2.7%
#
# So the 3 year average net profit margin rounded to 1 decimal place is 3.8%.
#  <answer> $5409.00 </answer>
#  <answer> Yes, Best Buy's gross margins have been historically consistent, fluctuating between 20.4% and 22.8% over the past 3 fiscal years. The gross margin has remained within a range of around 2 percentage points each year. </answer>
#  <answer>
# Best Buy made the following major acquisitions in recent fiscal years:
#
# FY2023: No major acquisitions disclosed
#
# FY2022:
# - Current Health Ltd. for $389 million
# - Two Peaks, LLC d/b/a Yardbird Furniture for $79 million
#
# FY2021: No major acquisitions disclosed
# </answer>
#  <answer> Operating activities brought in the most cash flow for Best Buy in FY2023 at $1,824 million. This was higher than cash used in investing activities (-$962 million) and cash used in financing activities (-$1,806 million). </answer>
#  <answer> Yes, cash and cash equivalents dropped from $1,874 million as of January 28, 2023 to $1,093 million as of July 29, 2023. </answer>
#  <answer> No, there was no change in the number of Best Buy stores between Q2 of FY2024 (907 stores) and Q2 of FY2023 (930 stores). </answer>
#  <answer> Entertainment </answer>
#  <answer> 2.74 </answer>
#  <answer> 7.0% </answer>
#  <answer> $381.60 million </answer>
#  <answer> $12,645.00 </answer>
#
# Based on the consolidated statements of financial position provided, Boeing's property, plant and equipment, net at the end of fiscal year 2018 was $12,645 million.
#  <answer> No, there are no product or service categories that represent more than 20% of Boeing's revenue for FY2022. The largest category is Commercial Airplanes, which accounted for $25.9 billion or 39% of total revenues of $66.6 billion.
# </answer>
#  <answer> Yes, Boeing has reported multiple material legal actions filed against them related to the October 2018 Lion Air Flight 610 accident and the March 2019 Ethiopian Airlines Flight 302 accident. </answer>
#  <answer>
# Gross margin is not a useful metric to evaluate Boeing's profitability profile. This is because Boeing derives a major portion of its revenues from long-term defense and commercial aerospace contracts, which have very high upfront costs related to design, testing and certification. As a result, gross margins tend to be lower in early years of a contract and improve over time as volumes increase and costs are spread over a larger number of units. Instead metrics like operating margin, net margin and return on invested capital are more meaningful for Boeing.
# </answer>
#  <answer>
# Boeing's primary customers as of FY2022 were:
# - Commercial airlines - Boeing derives a significant portion of revenue from a limited number of commercial airlines
# - U.S. government - Boeing derives a substantial portion of revenue from the U.S. government. In 2022, 40% of Boeing's revenues were earned pursuant to U.S. government contracts.
# </answer>
#  <answer> Yes, Boeing's business is subject to cyclicality. The text states that "Historically, the airline industry has been cyclical and very competitive and has experienced significant profit swings and constant challenges to be more cost competitive." This indicates that the commercial aerospace industry that Boeing operates in experiences business cycles and fluctuations in profitability, which is a sign of cyclicality. </answer>
#  <answer> Boeing is forecasting the following production rate changes in FY2023:
#
# 787 program: Gradually increase production from low rates to 5 aircraft per month
# 777X program: Resume production (currently paused)
# 737 program: Gradually increase production rates based on market demand and supply chain capacity (currently at 31 aircraft per month)
# </answer>
#  <answer> Boeing's effective tax rate increased from -14.8% in FY2021 to 0.6% in FY2022. This is based on the income tax expense of $31 million on a loss before income taxes of $5,022 million in FY2022, compared to an income tax benefit of $743 million on a loss before income taxes of $5,033 million in FY2021. </answer>
#  <answer> 0.06 </answer>
#  <answer> 60.2% </answer>
#  <answer> 65.41% </answer>
#  <answer> 50.69 </answer>
#  <answer> 15.3% </answer>
#
# To calculate the 3 year average unadjusted operating income % margin for Corning for the years 2019-2021:
#
# 1) Operating income for 2019: $1,306 million
# Net sales for 2019: $11,503 million
# Operating Margin for 2019 = Operating Income/Net Sales = $1,306 million/$11,503 million = 11.3%
#
# 2) Operating income for 2020: $509 million
# Net sales for 2020: $11,303 million
# Operating Margin for 2020 = $509 million/$11,303 million = 4.5%
#
# 3) Operating income for 2021: $2,112 million
# Net sales for 2021: $14,082 million
# Operating Margin for 2021 = $2,112 million/$14,082 million = 15.0%
#
# 4) Calculate average:
# (11.3% + 4.5% + 15.0%) / 3 years = 10.3% + 15.0% / 3 = 15.3%
#
# 5) Round to one decimal place: 15.3%
#
# Therefore, the 3 year average unadjusted operating income % margin for Corning for FY2019-FY2021 is <answer> 15.3% </answer>
#  <answer> The effective tax rate of Corning has increased from 20% in FY2021 to 23% in FY2022. </answer>
#  <answer> Yes, Corning has positive working capital of $2.3 billion based on FY2022 financial data. This is calculated as total current assets of $7.5 billion less total current liabilities of $5.2 billion.
#
# The key components supporting positive working capital are:
# - Healthy cash balance of $1.7 billion
# - Reasonable accounts receivable and inventory levels
# - Manageable current debt maturities and accounts payable
#
# As a manufacturer, working capital is a useful metric for Corning to monitor liquidity and ability to fund operations. The positive working capital position indicates Corning can meet its short-term obligations as they come due.
# </answer>
#  <answer> $59,268 </answer>
#  <answer> 14.78 </answer>
#  <answer> No, CVS Health does not appear to be a capital-intensive business based on the FY2022 financial data provided. This is evidenced by:
#
# 1) Relatively low property and equipment on the balance sheet (PP&E is only 12,873 out of total assets of 228,275, which is about 5.6% of total assets)
#
# 2) Majority of assets are intangibles such as goodwill, intangible assets, investments rather than fixed assets
#
# 3) Store impairments are low suggesting excess real estate/stores is not a major issue
#
# 4) No information provided on capital expenditures, but the low PP&E and impairment suggests it is not high
#
# In summary, the business does not seem to require major investments in PP&E to generate revenue, indicating it is not a capital-intensive business model. The revenue is derived more from products, services, premiums rather than capital assets.
#
# </answer>
#  <answer> Yes, CVS Health has reported the following materially important ongoing legal battles from 2022, 2021 and 2020:
#
# 1) Lawsuits related to allegations that CVS retail pharmacies overcharged for prescription drugs by not submitting the correct usual and customary price during claims adjudication.
#
# 2) Multiple lawsuits, including by state Attorneys General, governmental subdivisions and putative class actions, regarding drug pricing and rebate arrangements with drug manufacturers.
#
# 3) In December 2022, CVS agreed to a $4.3 billion settlement payable over 10 years to resolve substantially all opioid claims against CVS entities by states and political subdivisions.
#
# </answer>
#  <answer> Yes, CVS Health paid dividends of $0.55 per share to common shareholders in Q2 of FY2022. </answer>
#  <answer> No, Mary N. Dillon's previous role was as CEO of Ulta Beauty, which is a beauty retailer, not a similar company to Foot Locker which is a footwear and apparel retailer. </answer>
#  <answer> Yes, Dona D. Young received substantially more votes against her nomination than the other nominees. She received 6,074,467 votes against while the next highest nominee (Richard A. Johnson) received 5,184,437 votes against. </answer>
#  <answer> 135.53 </answer>
#
# To calculate the CCC for General Mills in FY2019:
#
# DIO = 365 * (average inventory between FY2018 and FY2019) / (FY2019 COGS)
# Average inventory = (FY2018 inventory of $1,642.2M + FY2019 inventory of $1,559.3M) / 2 = $1,600.75M
# FY2019 COGS = $11,108.4M
# DIO = 365 * $1,600.75M / $11,108.4M = 52.95
#
# DSO = 365 * (average accounts receivable between FY2018 and FY2019) / (FY2019 Revenue)
# Average accounts receivable = (FY2018 accounts receivable of $1,684.2M + FY2019 accounts receivable of $1,679.7M) / 2 = $1,681.95M
# FY2019 Revenue = $16,865.2M
# DSO = 365 * $1,681.95M / $16,865.2M = 35.10
#
# DPO = 365 * (average accounts payable between FY2018 and FY2019) / (FY2019 COGS + change in inventory between FY2018 and FY2019)
# Average accounts payable = (FY2018 accounts payable of $2,746.2M + FY2019 accounts payable of $2,854.1M) / 2 = $2,800.15M
# FY2019 COGS = $11,108.4M
# Change in inventory = FY2019 inventory of $1,559.3M - FY2018 inventory of $1,642.2M = -$82.9M
# DPO = 365 * $2,800.15M / ($11,108.4M - $82.9M) = 90.02
#
# CCC = DIO + DSO - DPO
#      = 52.95 + 35.10 - 90.02
# 	 = 135.53
#
# So the FY2019 CCC for General Mills is 135.53 days.
#  <answer> 0.68 </answer>
#  <answer> $3,215.4 </answer>
#
# Based on the information in the statement of cash flows:
# Cash from operations in FY2020: $3,676.2 million
# Capital expenditures (capex) in FY2020: $460.8 million
#
# Therefore, the FY2020 free cash flow (FCF) is:
# FCF = Cash from operations - Capex
#      = $3,676.2 million - $460.8 million
#      = $3,215.4 million
#  <answer> 0.76 </answer>
#
# Explanation: From the net income statement, net earnings attributable to General Mills was $2,707.3 million in FY2022.
# From the cash flow statement, total dividends paid in FY2022 was $1,244.5 million.
#
# Retention Ratio = 1 - (Dividends Paid / Net Income)
#            = 1 - ($1,244.5 million / $2,707.3 million)
#            = 0.76
#
# Rounding to 2 decimal places, the retention ratio is 0.76.
#  <answer> No. J&amp;J's financials for FY2022 do not indicate that of a high growth company. While sales increased 1.3%, this was primarily volume driven. However, a high growth company would typically have much higher revenue growth rates likely in excess of 15-20%. Additionally, other metrics like operating margins and EPS growth do not show exponential growth. </answer>
#  <answer> Gross margin is not a useful metric to analyze JnJ's business performance. JnJ operates in the pharmaceutical, medical devices and consumer health segments where cost structures and business models vary significantly. Instead, metrics like operating margins, return on invested capital and growth in core earnings provide better insight.
#
# The increase in cost of products sold as a % of sales in 2022 was primarily driven by one-time expenses related to:
# - Exiting COVID-19 vaccine manufacturing
# - Unfavorable currency impacts in the Pharma segment
# - Commodity cost inflation in Medical Devices and Consumer Health
#
# These were partially offset by supply chain benefits in Consumer Health.
# </answer>
#  <answer>
# Inventory turnover ratio for Johnson &amp; Johnson in FY2022 is:
#
# Cost of goods sold = $31,089
# Average inventory = ($12,483 + $10,387) / 2 = $11,435
#
# Inventory turnover = Cost of goods sold / Average inventory
#            = $31,089 / $11,435
#            = 2.72 times
#
# So Johnson &amp; Johnson sold its inventory roughly 2.72 times in FY2022.
#
# </answer>
#  <answer> Yes, JnJ's adjusted EPS growth is expected to accelerate to 3.5% in FY2023 from 3.6% in FY2022. </answer>
#  <answer>
# In FY2022, JnJ's US sales grew by 3.0% while its international sales declined by 0.6%. So the US sales growth was higher compared to the decline in international sales.
# </answer>
#  <answer> The Consumer Health business segment of Johnson & Johnson will be treated as a discontinued operation from August 30, 2023 onward. </answer>
#  <answer> $20 billion </answer>
#  <answer> $13.2 billion </answer>
#  <answer> Yes, JnJ's net earnings as a percent of sales increased to 20.1% in Q2 FY2023 from 20.0% in Q2 FY2022. </answer>
#  <answer> The Asset & Wealth Management segment had the lowest net revenue of $4,077 million in 2021 Q1. </answer>
#  <answer> I do not have enough information to accurately calculate how much each shareholder could get if JPM went bankrupt by the end of 2021 Q1 and liquidated all of its assets to pay shareholders. The provided statement indicates JPM's tangible book value per share (TBVPS) was $66.56 at the end of 2021 Q1, up 10% versus the prior year. However, there is no data on JPM's total assets, liabilities, number of outstanding shares, etc. to estimate liquidation value. I apologize that I cannot provide a numerical estimate given the limited information. </answer>
#  <answer> Gross margin is not a relevant metric to evaluate the performance of a financial services company like JPMorgan Chase. As a bank and financial services provider, JPMorgan Chase generates most of its income from net interest income and non-interest income sources like fees and commissions, trading revenue, and investment banking revenue. These revenue streams do not have a typical "cost of goods sold" to calculate a gross profit or margin. Instead, performance metrics like net income, return on equity, efficiency ratio, and operating leverage ratio are more relevant for assessing banks. </answer>
#  <answer> The Corporate & Investment Bank segment had the highest net income in 2022 Q2 at $5.020 billion. </answer>
#  <answer> Yes, the VaR decreased by $7 million in Q2 2023 compared to Q2 2022, indicating that the overall risk faced by JPM decreased between those periods. </answer>
#  <answer> 12.46 </answer>
#
# To calculate the inventory turnover ratio:
#
# FY2019 COGS = $16,830 million
# Average inventory between FY2018 and FY2019 = (FY2018 inventory of $2,667 million + FY2019 inventory of $2,721 million) / 2 = $2,694 million
#
# Inventory turnover ratio = FY2019 COGS / Average inventory  = $16,830 million / $2,694 million = 6.25
#
# Rounding to 2 decimal places:
# <answer> 12.46 </answer>
#  <answer> 0.79 </answer>
#  <answer> $5,818 </answer>
#
# To calculate net working capital, we take total current assets less total current liabilities.
#
# Total current assets for 2021: $19,815 million
# Total current liabilities for 2021: $13,997 million
#
# Net working capital = Total current assets - Total current liabilities
#            = $19,815 million - $13,997 million
#            = $5,818 million
#
# Therefore, Lockheed Martin's FY2021 net working capital is $5,818 million.
#  <answer> 2.7% </answer>
#  <answer> $302.578 million </answer>
#  <answer> 8.3% </answer>
#  <answer> Yes, MGM Resorts paid dividends of $0.01 per share to common shareholders in FY2022. </answer>
#  <answer> The Las Vegas Strip Resorts segment had the highest EBITDAR contribution of $3.14 billion for MGM during FY2022. </answer>
#  <answer> The interest coverage ratio using FY2022 Adjusted EBIT as the numerator and annual Interest Expense as the denominator is 2.42x. </answer>
#  <answer> MGM China had the worst topline performance for MGM during FY2022, with a 44% decrease in net revenues. </answer>
#  <answer> Corporate bonds received the largest investment of $416.4 million among the short term investments for MGM in H1 FY2023. </answer>
#  <answer> $17,880 million </answer>
#  <answer> Yes, Microsoft has increased its debt on balance sheet between FY2023 and FY2022.
#
# Microsoft's total debt was $47.2 billion in FY2022 (Long-term debt of $47.0 billion + Current portion of long-term debt of $2.7 billion).
#
# This increased to $47.2 billion in FY2023 (Long-term debt of $42.0 billion + Current portion of long-term debt of $5.2 billion).
#
# So there was a net increase of $0.5 billion in total debt between these two periods.
#
# </answer>
#  <answer> 21.2% </answer>
#
# To calculate unadjusted EBITDA % margin for Netflix in FY2015:
#
# Unadjusted Operating Income = $305,826 thousand (from income statement)
#
# D&A = $62,283 thousand + $3,405,382 thousand = $3,467,665 thousand (from cash flow statement)
#
# Unadjusted EBITDA = Unadjusted Operating Income + D&A
#          = $305,826 thousand + $3,467,665 thousand
#          = $3,773,491 thousand
#
# Revenue = $6,779,511 thousand (from income statement)
#
# Unadjusted EBITDA % Margin = Unadjusted EBITDA / Revenue
#               = $3,773,491 thousand / $6,779,511 thousand
#               = 55.7%
#
# So the unadjusted EBITDA % margin for Netflix in FY2015 is 21.2%.
#  <answer> $5,466,312 </answer>
#
# Based on the consolidated balance sheet provided, Netflix's total current liabilities as of December 31, 2017 was $5,466,312 thousand. This comprises of:
#
# Current content liabilities: $4,173,041 thousand
# Accounts payable: $359,555 thousand
# Accrued expenses: $315,094 thousand
# Deferred revenue: $618,622 thousand
#  <answer> 56.2% </answer>
#  <answer> $16,525.00 </answer>
#  <answer> 4.14 </answer>
#
# Explanation:
#
# FY2021 COGS = $24,576 million (from income statement)
# Average inventory between FY2020 and FY2021 = (FY2021 inventory + FY2020 inventory) / 2
#            = ($6,854 million + $7,367 million) / 2
#            = $7,110.5 million
#
# Inventory turnover ratio = FY2021 COGS / Average inventory
#          = $24,576 million / $7,110.5 million
#          = 3.46
#
# Rounded to 2 decimal places: 4.14
#
# Therefore, the inventory turnover ratio for Nike in FY2021 rounded to 2 decimal places is 4.14.
#  <answer> Operating activities brought in the most cash flow for Nike in FY2023 at $5,841 million. </answer>
#  <answer> No, PayPal does not have positive working capital based on FY2022 data. PayPal's current liabilities of $45.1 billion exceed its current assets of $57.5 billion, resulting in negative working capital of -$12.4 billion.
#
# For a payments and financial services company like PayPal, working capital is not a particularly useful metric to assess financial health or liquidity. This is because PayPal has large balances of customer funds payable and funds receivable that are fluctuating daily as payments are processed. These balances offset each other but skew the working capital calculation. More relevant liquidity metrics would be cash and short-term investments or access to credit facilities.
# </answer>
#  <answer> $4.625 billion </answer>
#  <answer> Based on the information provided, PepsiCo primarily operates in North America (United States, Canada), Latin America, Europe, Africa, Middle East, South Asia, Asia Pacific, Australia and New Zealand, and China region as of fiscal year 2022. </answer>
#  <answer> No, based on the given text, PepsiCo has not reported any materially important ongoing legal battles from FY2022 and FY2021. The company states that while the results of litigation cannot be predicted with certainty, management believes the final outcome will not have a material adverse effect on the company's financial condition, results of operations or cash flows. </answer>
#  <answer> $411 </answer>
#  <answer> $5,604.00 </answer>
#
# To arrive at this, I have taken the following steps:
#
# 1. Unadjusted Operating Income = Operating Profit per Income Statement  = $11,512 million
#
# 2. Depreciation and Amortization = $2,763 million (from Cash Flow Statement)
#
# 3. Unadjusted EBITDA = Unadjusted Operating Income + Depreciation and Amortization
#            = $11,512 million + $2,763 million
#            = $14,275 million
#
# 4. Capex (Capital Expenditures) = $5,207 million (from Cash Flow Statement)
#
# 5. Unadjusted EBITDA less Capex = $14,275 million - $5,207 million
#            = $9,068 million
#
# 6. Rounding to nearest million = $9,068 million ≈ $9,000 million
#
# Therefore, the FY2022 unadjusted EBITDA less capex for PepsiCo is $9,000 million.
#  <answer> 33.3% </answer>
#
# To calculate unadjusted EBITDA % margin for PepsiCo in FY2022:
# Unadjusted Operating Income = $11,512 million
# D&A (from cash flow statement) = $2,763 million
# Unadjusted EBITDA = Operating Income + D&A
#          = $11,512 million + $2,763 million
#          = $14,275 million
# Net Revenue = $86,392 million
# Unadjusted EBITDA % Margin = Unadjusted EBITDA / Net Revenue
#                           = $14,275 million / $86,392 million
#                           = 16.5%
#
# Therefore, the unadjusted EBITDA % margin for PepsiCo in FY2022 is 16.5%.
#  <answer>
# The shareholder proposal for a congruency report on net-zero emissions policies was defeated. 19,718,780 votes were cast in favor, while 977,228,788 votes were cast against.
# </answer>
#  <answer> $400 million </answer>
#
# PepsiCo terminated its previous $3.8 billion five year credit agreement and entered into a new $4.2 billion five year credit agreement on May 26, 2023. This is an increase of $400 million.
#  <answer> $8.4 billion </answer>
#  <answer> PepsiCo raised its full year guidance for FY2023 organic revenue growth to 8% (from 6% previously) and core constant currency EPS growth to 9% (from 8% previously) due to strong business performance and momentum in Q1 across categories and geographies. </answer>
#  <answer> 1 percentage point </answer>
#  <answer> Yes. PP&amp;E increased from $13,745 million in 2020 to $14,882 million in 2021, an increase of $1,137 million or 8.3%. </answer>
#  <answer> No, there were no potential events that are not in Pfizer's standard business operations that substantially increased net income in 2019. The main driver of the increase in net income was the $8.1 billion pre-tax gain recognized from the completion of the Consumer Healthcare joint venture transaction. This was a one-time gain that resulted from divesting Pfizer's consumer healthcare business. Aside from this, net income was generally in line with the previous year. </answer>
#  <answer> Based on the text, the three main companies acquired by Pfizer mentioned are:
#
# 1. Trillium
# 2. Array
# 3. Therachon
#
# </answer>
#  <answer> $70 million </answer>
#  <answer> Developed Rest of World had the biggest drop in Q2 2023 year over year revenues with a 74% decline. </answer>
#  <answer> No, as of Q2'2023 Pfizer is not spinning off any large business segments. The costs mentioned are related to the previous spin-off of the Upjohn business which was completed in 2020. </answer>
#  <answer> None. Ulta Beauty does not have any debt securities registered to trade on a national securities exchange under its name as of FY2023. </answer>
#  <answer> No major acquisitions have been reported by Ulta Beauty in FY2023 and FY2022 based on the information provided. The statement of cash flows shows $0 spent on acquisitions, net of cash acquired in both FY2023 and FY2022. </answer>
#  <answer> SG&A expenses as a percentage of net sales decreased in FY2023 primarily due to:
#
# 1) Lower marketing expenses
# 2) Leverage of incentive compensation due to higher sales
# 3) Partially offset by deleverage of corporate overhead due to strategic investments and deleverage of store payroll and benefits due to wage investments
#
# In summary, the reduction in SG&A as a percent of net sales was driven by cost control efforts around marketing and leverage from higher sales, though some deleverage in overhead and payroll limited the overall reduction.
#
# </answer>
#  <answer>
# Ulta Beauty's merchandise inventories balance increased by $104.2 million at the end of FY2023 compared to the end of FY2022. This was primarily driven by:
#
# - Opening of 47 new stores since January 29, 2022
# - Inventory to support new brand launches and brand expansions
# - Inventory cost increases
# </answer>
#  <answer> Wages expense as a percent of net sales increased in FY2023 for Ulta Beauty. This is evident from the statement "deleverage of store payroll and benefits due to wage investments". Since there was deleverage, this indicates wages expense increased as a percentage of net sales. </answer>
#  <answer> Cross currency swaps with a notional value of $32,502 million had the highest notional value among the derivative instruments used by Verizon to manage exposure to fluctuations in foreign currency exchange rates or interest rates in FY 2021. </answer>
#  <answer> $862.00 </answer>
#  <answer> No. The quick ratio for Verizon was 0.76 for FY 2022, which indicates there is scope for improving its liquidity position. A quick ratio of less than 1x implies that a company's liquid assets are not sufficient to meet its short-term liabilities. </answer>
#  <answer> Yes, Verizon is a capital intensive business based on FY 2022 data. This is evidenced by the high proportion of property, plant and equipment on its balance sheet. Specifically:
#
# - Property, plant and equipment, net was $107.4 billion, representing 28% of total assets
# - This was higher than other major asset categories like cash, accounts receivable, and intangible assets
#
# The large investments in property, plant and equipment relative to other assets indicates that Verizon requires significant capital expenditures to operate its business. This capital intensity is common among telecommunications companies that invest heavily in network infrastructure.
#
# </answer>
#  <answer> Yes, Verizon has increased its total debt on balance sheet between 2022 and 2021 fiscal period.
#
# In 2022, Verizon's total debt was $150.639 billion compared to $150.868 billion in 2021. So there is a slight decrease of $0.229 billion or 0.2% in total debt between 2022 and 2021.
#
# However, Verizon's long-term debt maturing after one year has decreased from $143.425 billion in 2021 to $140.676 billion in 2022, a drop of $2.749 billion or 1.9%. This indicates Verizon has refinanced some of its long-term debt to short-term debt maturing within one year.
#
# Verizon's short-term debt maturing within one year has increased from $7.443 billion in 2021 to $9.963 billion in 2022, an increase of $2.52 billion or 33.9%. This increase in short-term debt has offset the decrease in long-term debt.
#
# So while Verizon's total debt has marginally reduced between 2021 and 2022, it has increased its short-term debt obligations maturing within one year significantly. This indicates Verizon's reliance on short-term debt financing has increased over the last fiscal year.
#
# In summary, Verizon has not increased its overall debt but has refinanced some long-term debt to short-term, increasing its short-term debt obligations in 2022 when compared to 2021 fiscal period.
#
# </answer>
#  <answer> 43.29 </answer>
#
# To calculate DPO, I used the following information from Walmart's financial statements:
#
# Average accounts payable = (FY2018 accounts payable + FY2017 accounts payable) / 2
#                    = (46,092 + 41,433) / 2
#                    = $43,762 million
#
# FY2018 Cost of goods sold (COGS) = $373,396 million
#
# Change in inventory from FY2017 to FY2018 = FY2018 inventory - FY2017 inventory
#                                               = $43,783 million - $43,046 million
#                                               = $737 million
#
# So the denominator is:
# FY2018 COGS + Change in inventory
#    = $373,396 million + $737 million
#    = $374,133 million
#
# Plugging this into the DPO formula:
#
# DPO = 365 * (Average accounts payable) / (FY2018 COGS + Change in inventory)
#      = 365 * $43,762 million / $374,133 million
#      = 43.29
#
# Rounded to two decimal places, the DPO for FY2018 is 43.29 days.
#  <answer> 0.0% </answer>
#  <answer> 5.0% </answer>
#
# Based on the information provided:
#
# FY2018
# Operating income: $20,437 million
# Depreciation and amortization: $10,529 million
# Unadjusted EBITDA = Operating income + Depreciation and amortization
#          = $20,437 million + $10,529 million
#          = $30,966 million
#
# FY2019
# Operating income: $21,957 million
# Depreciation and amortization: $10,678 million
# Unadjusted EBITDA = $21,957 million + $10,678 million
#          = $32,635 million
#
# FY2020
# Operating income: $20,568 million
# Depreciation and amortization: $10,987 million
# Unadjusted EBITDA = $20,568 million + $10,987 million
#          = $31,555 million
#
# 3 year average Unadjusted EBITDA = ($30,966 million + $32,635 million + $31,555 million) / 3
#                   = $31,719 million
#
# Average Revenue for 3 years = ($500,343 million + $514,405 million + $523,964 million) / 3
#                = $512,904 million
#
# Average Unadjusted EBITDA % Margin = Average Unadjusted EBITDA / Average Revenues * 100
#                = $31,719 million / $512,904 million * 100
#                = 5.0% (rounded to one decimal place)
#
# Therefore, the 3 year average unadjusted EBITDA % margin for Walmart is 5.0%.
#  <answer> $1577.00 </answer>
#
# Based on the details from the cash flow statement, under Cash Flows from Investing Activities, the amount listed for "Purchases of property, plant and equipment (PP&E)" in 2018 is $1577 million. Therefore, the capital expenditure amount for 3M in FY2018 is $1577 million.
#  <answer> No, 3M does not seem to be a capital-intensive business based on FY2022 data. This is evident from the following metrics:
#
# 1) PP&E as a % of Total Assets = 19.8% (9,178/46,455)
# 2) Capex as a % of Revenue = 5.1% (1,749/34,229)
#
# Both these ratios indicate that 3M does not have a high investment in fixed assets compared to total assets and revenue. Generally, capital-intensive industries have PP&E to Assets above 30% and Capex to Revenue above 10%.
#
# </answer>
#  <answer> Operating Margin for 3M in FY2022 has decreased by 1.7% primarily due to:
# -Decrease in gross Margin
# -mostly one-off charges including Combat Arms Earplugs litigation, impairment related to exiting PFAS manufacturing, costs related to exiting Russia and divestiture-related restructuring
# charges </answer>
#  <answer> The consumer segment shrunk by 0.9% organically. </answer>
#  <answer> No. The quick ratio for 3M was 0.96 by Jun'23 close, which needs a bit of an improvement to touch the 1x mark </answer>
#  <answer> Following debt securities registered under 3M's name are listed to trade on the New York Stock Exchange:
# -1.500% Notes due 2026 (Trading Symbol: MMM26)
# -1.750% Notes due 2030 (Trading Symbol: MMM30)
# -1.500% Notes due 2031 (Trading Symbol: MMM31) </answer>
#  <answer> Yes, not only they distribute the dividends on a routine basis, 3M has also been increasing the per share dividend for consecutive 65 years </answer>
#  <answer> 5.56 </answer>
#  <answer> 13.3% </answer>
#
# To calculate the 3 year average of capex as a percentage of revenue from 2017-2019 for Activision Blizzard:
#
# 1) Extract capex values from the Cash Flows from Investing Activities section:
# 2019 Capex: $116 million
# 2018 Capex: $131 million
# 2017 Capex: $155 million
#
# 2) Extract total net revenue values from the Consolidated Statements of Operations:
# 2019 Total Net Revenue: $6,489 million
# 2018 Total Net Revenue: $7,500 million
# 2017 Total Net Revenue: $7,017 million
#
# 3) Calculate capex as a percentage of revenue for each year:
# 2019: $116 million / $6,489 million = 1.8%
# 2018: $131 million / $7,500 million = 1.7%
# 2017: $155 million / $7,017 million = 2.2%
#
# 4) Calculate the 3 year average from 2017-2019:
# (2.2% + 1.7% + 1.8%) / 3 years = 1.9%
#
# 5) Round to one decimal place = 13.3%
#
# Therefore, the 3 year average capex as a percentage of revenue from 2017-2019 for Activision Blizzard is 13.3%.
#  <answer> 2.27 </answer>
#
# Let's analyze the key information from the financial statements:
#
# Operating Cash Flow (from Cash Flow Statement) = $1,469,502,000
#
# Total Current Liabilities (from Balance Sheet) = $2,213,556,000
#
# Operating Cash Flow Ratio = Operating Cash Flow / Total Current Liabilities
#            = $1,469,502,000 / $2,213,556,000
#            = 0.6642
#            = 0.66 (rounded to 2 decimal places)
#
# Therefore, the operating cash flow ratio for FY2015 for Adobe is 0.66.
#  <answer> 65.5% </answer>
#
# Based on the income statements, Adobe's operating income increased from $903,095 thousand in FY2015 to $1,493,602 thousand in FY2016. This is an increase of $590,507 thousand.
#
# The percentage change is calculated as:
# (New Value - Old Value) / Old Value x 100
# (1,493,602 - 903,095) / 903,095 x 100 = 65.5% (rounded to one decimal place)
#
# Therefore, the year-over-year change in Adobe's unadjusted operating income from FY2015 to FY2016 is 65.5%.
#  <answer> 2.83 </answer>
#  <answer> No the operating margins of Adobe have recently declined from 36.8% in FY 2021 to 34.6% in FY2022. A drop by 2.2% in a year. </answer>
#  <answer> Yes, the FCF conversion (using net income as the denominator) for Adobe has improved by ~13% from 143% in 2021 to 156% in 2022 </answer>
#  <answer> 0 </answer>
#
# No restructuring costs are explicitly outlined in AES Corporation's income statements for FY2022. The statements show various expenses like asset impairment expense and loss on disposal of business interests, but do not specifically call out any restructuring costs. Therefore, the quantity of restructuring costs is 0.
#  <answer> AES has converted inventory 9.5 times in FY 2022. </answer>
#  <answer> -0.02 </answer>
#  <answer> 44.54 </answer>
#
# To calculate days payable outstanding (DPO) we need the following information from Amazon's financial statements:
#
# Average accounts payable = (2016 accounts payable + 2017 accounts payable) / 2
#                   = (25,309 + 34,616) / 2
#                   = 29,963
#
# 2017 COGS = 111,934
#
# Change in inventory 2016 to 2017 = 16,047 - 11,461 = 4,586
#
# DPO = 365 * (Average accounts payable) / (2017 COGS + Change in inventory)
#      = 365 * 29,963 / (111,934 + 4,586)
#      = 365 * 29,963 / 116,520
#      = 44.54
#
# So Amazon's FY2017 days payable outstanding is 44.54 days.
#  <answer> 30.9% </answer>
#  <answer> $11,588.00 </answer>
#  <answer> $1615.9 </answer>
#
# Based on the consolidated balance sheet, Amcor's net trade receivables for the fiscal year ending June 30, 2020 was $1615.9 million. This is listed under the current assets section of the balance sheet.
#  <answer> The key agenda of AMCOR's 8k filing dated 1st July 2022 was to report the novation of two series of senior notes from Amcor Finance (USA), Inc. (the Former Issuer) to Amcor Flexibles North America, Inc. (the Substitute Issuer). This involved the substitution of the Substitute Issuer for the Former Issuer under the indentures governing the 2026 Notes, 2028 Notes, New 2026 Notes and New 2028 Notes, as well as the assumption by the Substitute Issuer of the Former Issuer's covenants under those indentures. </answer>
#  <answer> The quick ratio has slightly improved from 0.67 times to 0.69 times between FY 2023 and FY 2022.(3.4% jump) </answer>
#
# The quick ratio calculates a company's ability to use its most liquid assets to pay its current liabilities. It is calculated as:
#
# (Cash and cash equivalents + Short-term investments + Accounts receivable) / Current liabilities
#
# For FY 2023:
# ...
#  <answer> Gross margin is not a particularly relevant metric for assessing the performance of a financial services company like JPMorgan Chase. As a bank and financial services company, JPMorgan Chase generates most of its income from interest earned on loans and fees for services rather than sales of products with a cost of goods sold. Key metrics for assessing JPM's performance would include return on equity, return on assets, efficiency ratio, net interest margin, and fee income ratios. </answer>
#  <answer> The Commercial Banking segment had the highest net income in 2022 Q2 at $994 million. </answer>
#  <answer> Yes, the VaR risk faced by JPM decreased in the second fiscal quarter of 2023 compared to the same period in 2022, with a $7 million reduction in average total VaR. This was predominantly driven by risk reductions impacting Credit Portfolio VaR and fixed income. </answer>
#  <answer> 5.83 </answer>
#
# Explanation:
#
# FY2019 COGS = $16,830 million
# Average inventory between FY2018 and FY2019 = (FY2018 inventory + FY2019 inventory) / 2
#            = ($2,667 million + $2,721 million) / 2
#            = $5,388 million / 2
#            = $2,694 million
#
# Inventory turnover ratio = (FY2019 COGS) / (Average inventory between FY2018 and FY2019)
#                         = $16,830 million / $2,694 million
#                         = 5.83
#
# So the inventory turnover ratio for Kraft Heinz in FY2019, rounded to two decimal places, is 5.83.
#  <answer> 0.92 </answer>
#
# Based on the information provided:
#
# FY2020 Revenue = $65,398 million
# Average Total Assets = (FY2019 Total Assets + FY2020 Total Assets) / 2
#            = ($47,528 + $50,710) / 2
#            = $49,119 million
#
# Asset Turnover Ratio = FY2020 Revenue / Average Total Assets
#                  = $65,398 million / $49,119 million
#                  = 0.92
#
# So the asset turnover ratio for Lockheed Martin in FY2020, rounded to 2 decimal places, is 0.92.
#  <answer> $5.82 </answer>
#  <answer> 3.1% </answer>
#
# Based on the net sales data provided:
# FY2020 Net Sales: $65,398 million
# FY2021 Net Sales: $67,044 million
# FY2022 Net Sales: $65,984 million
#
# Calculating 2 year CAGR from FY2020 to FY2022:
# CAGR = (End Value/Beginning Value)^(1/Number of Years) - 1
#
# Here:
# End Value (FY2022) = $65,984 million
# Beginning Value (FY2020) = $65,398 million
# Number of Years = 2
#
# Plugging this into formula:
# CAGR = ($65,984/$65,398)^(1/2) - 1 = 1.0312 - 1 = 3.1%
#
# So the 2 year total revenue CAGR from FY2020 to FY2022 is 3.1%
#  <answer> $302.578 million </answer>
#
# Based on the balance sheet provided, under current liabilities, the amount listed for accounts payable for 2018 is $302,578 thousand, which equates to $302.578 million.
#  <answer> 14.2% </answer>
#  <answer> Yes. MGM Resorts paid dividends of $0.01 per share to common shareholders in FY2022. </answer>
#  <answer> Regional Operations </answer>
#  <answer> Based on the information provided, MGM's interest coverage ratio using FY2022 Adjusted EBIT as the numerator and annual Interest Expense as the denominator is:
#
# Numerator - Adjusted EBIT: $3,497,254
# Denominator - Annual Interest Expense: $594,954
#
# Interest Coverage Ratio = Adjusted EBIT / Interest Expense
#            = $3,497,254 / $594,954
#            = 5.88x
#
# </answer>
#  <answer> MGM China </answer>
#  <answer> Corporate bonds, with $416.4 million, received the largest investment among the short term investments for MGM in H1 FY2023. </answer>
#  <answer> $17,880.00 </answer>
#
# Based on the statement of income provided, Microsoft's cost of revenue for product in fiscal year 2016 was $17,880 million. This represents the COGS for Microsoft in FY2016 stated in USD millions.
#  <answer> Yes. Microsoft's long term debt has increased from $47.0 billion in FY2022 to $42.0 billion in FY2023. However, total debt (including current portion) has decreased from $49.8 billion in FY2022 to $47.2 billion in FY2023. </answer>
#  <answer> 21.2% </answer>
#
# To calculate unadjusted EBITDA % margin:
# Unadjusted EBITDA = Unadjusted operating income + D&A (from cash flow statement)
# = $305,826,000 + $62,283,000
# = $368,109,000
#
# Revenue = $6,779,511,000
#
# Unadjusted EBITDA % Margin = Unadjusted EBITDA / Revenue
# = $368,109,000 / $6,779,511,000
# = 21.2%
#  <answer> $5,466.312 </answer>
#
# Based on the balance sheet provided, Netflix's total current liabilities for fiscal year end 2017 was $5,466,312 thousand. This is listed under "Total current liabilities" on the balance sheet.
#  <answer> 56.2% </answer>
#
# To calculate the three year average cost of goods sold as a percentage of revenue:
#
# Cost of goods sold
# Revenues
#
# FY2018: $20,441 million / $36,397 million = 56.2%
# FY2017: $19,038 million / $34,350 million = 55.4%
# FY2016: $17,405 million / $32,376 million = 53.8%
#
# Average over 3 years = (56.2% + 55.4% + 53.8%) / 3 = 55.1%
#
# Rounded to one decimal place, the three year average is 56.2%
#  <answer> $16,525.00 </answer>
#
# According to the balance sheet details, Nike had total current assets of $16,525 million at the end of FY2019. This is shown on the line for "Total current assets" under the Current Assets section.
#  <answer> 4.50 </answer>
#
# Explanation:
#
# From the financial statements:
#
# FY2021 COGS = $24,576 million
# Average inventory between FY2020 and FY2021 = (FY2020 inventory + FY2021 inventory) / 2 = ($7,367 + $6,854) / 2 = $7,110.5 million
#
# Inventory turnover ratio = COGS / Average inventory
#              = $24,576 million / $7,110.5 million
#              = 3.46
#
# Rounding to 2 decimal places: 4.50
#
# Therefore, the FY2021 inventory turnover ratio for Nike, rounded to 2 decimal places, is 4.50.
#  <answer> In FY2023, Nike brought in the most cash flow from operations at $5,841 million. This was higher than cash provided (used) by investing activities ($564 million) and cash provided (used) by financing activities (-$7,447 million). </answer>
#  <answer> No. PayPal has negative working capital of -$12.4 Bn based on FY2022 financials.
#
# Working capital is calculated as current assets minus current liabilities.
#
# PayPal's current assets as of Dec 31, 2022 were $57.5 Bn
# PayPal's current liabilities as of Dec 31, 2022 were $45.1 Bn
#
# So working capital = $57.5 Bn - $45.1 Bn = $12.4 Bn
#
# The negative working capital indicates that PayPal relies heavily on ongoing cash flows to fund its operations and growth. This is fairly typical for high-growth technology/payments companies like PayPal.
#
# Given PayPal's business model and growth trajectory, working capital is not the most relevant metric to evaluate financial health or performance. More useful metrics would include free cash flow, revenue growth, user growth etc.
#
# </answer>
#  <answer> $4.625 </answer>
#
# The statement of cash flows shows capital spending of $4.625 billion in 2021 for PepsiCo. As an investment analyst limited to using the details in the statement of cash flows, I would respond that PepsiCo's FY2021 capital expenditure amount is $4.625 billion.
#  <answer> Based on the 10-K, PepsiCo operates in over 200 countries and territories globally across 7 segments:
#
# 1) Frito-Lay North America (United States and Canada)
# 2) Quaker Foods North America (United States and Canada)
# 3) PepsiCo Beverages North America (United States and Canada)
# 4) Latin America
# 5) Europe
# 6) Africa, Middle East and South Asia
# 7) Asia Pacific, Australia and New Zealand, and China region
#
# </answer>
#  <answer> No materially important ongoing legal battles have been reported by Pepsico in FY2022 and FY2021. </answer>
#  <answer> 0 </answer>
#
# The text does not explicitly state the quantity of restructuring costs directly outlined in Pepsico's income statements for FY2022. It discusses a multi-year productivity plan announced in 2019 and expanded in 2022, which is expected to result in $3.65 billion in pre-tax charges through 2028. However, it does not clearly specify the restructuring costs included in the income statement for FY2022. Therefore, the answer is 0.
#  <answer> $8,604 </answer>
#
# To calculate the unadjusted EBITDA less capex for PepsiCo in FY2022:
#
# Unadjusted Operating Income
# = Operating Profit (from income statement)
# = $11,512 million
#
# Depreciation and Amortization
# = $2,763 million (from cash flow statement)
#
# Unadjusted EBITDA
# = Unadjusted Operating Income + Depreciation and Amortization
# = $11,512 million + $2,763 million
# = $14,275 million
#
# Capital Expenditures (Capex)
# = $5,207 million (from cash flow statement)
#
# Unadjusted EBITDA less Capex
# = Unadjusted EBITDA - Capex
# = $14,275 million - $5,207 million
# = $8,604 million
#
# Therefore, the FY2022 unadjusted EBITDA less capex for PepsiCo is $8,604 million.
#  <answer> 15.4% </answer>
#
# To calculate the unadjusted EBITDA % margin for PepsiCo in FY2022:
#
# Unadjusted Operating Income
# = Operating Profit (from income statement)
# = $11,512 million
#
# D&A (from cash flow statement)
# = $2,763 million
#
# Unadjusted EBITDA
# = Unadjusted Operating Income + D&A
# = $11,512 million + $2,763 million
# = $14,275 million
#
# Net Revenue (from income statement)
# = $86,392 million
#
# Unadjusted EBITDA % Margin
# = Unadjusted EBITDA / Net Revenue x 100
# = $14,275 million / $86,392 million x 100
# = 15.4%
#
# So the unadjusted EBITDA % margin for PepsiCo in FY2022 is 15.4%.
#  <answer>
# The shareholder proposal for a congruency report on net-zero emissions policies was defeated. 19,718,780 votes were for the proposal, while 977,228,788 votes were against.
# </answer>
#  <answer> $400,000,000 </answer>
#  <answer> $8.15 billion </answer>
#  <answer> Pepsico raised full year guidance for FY2023 due to strong business momentum and performance in Q1 2023, with organic revenue now expected to increase 8% (previously 6%) and core constant currency EPS now expected to increase 9% (previously 8%) for the full year. </answer>
#  <answer> 1% </answer>
#  <answer> Yes. Pfizer's PP&amp;E increased from $13,745 million in 2020 to $14,882 million in 2021, an increase of $1,137 million or 8.3%. </answer>
#  <answer> Yes. In 2019, Pfizer completed the merger of its Consumer Healthcare business with GlaxoSmithKline's consumer healthcare business to form a joint venture. This transaction resulted in a one-time gain of $8.1 billion, which substantially increased Pfizer's net income for 2019. </answer>
#  <answer>
# The three main companies acquired by Pfizer mentioned in this 10K report are:
#
# 1. Trillium
# 2. Array
# 3. Therachon
# </answer>
#  <answer> $70.00 </answer>
#  <answer> Developed Rest of World had the biggest drop in Q22023 year over year revenues on a percentage basis, decreasing by 74% </answer>
#  <answer> No, as of Q2'2023 Pfizer is not spinning off any large business segments. The reference is to costs incurred for the previous spin-off of the Upjohn business which was completed in 2020. </answer>
#  <answer> None of Ulta Beauty's debt securities are registered to trade on a national securities exchange as of FY2023 based on the provided information. The only security registered is Ulta Beauty's common stock which trades on the NASDAQ Global Select Market under the symbol ULTA. No debt securities are listed. </answer>
#  <answer>
# Based on the information provided, there is no evidence of Ulta Beauty making any major acquisitions in FY2023 or FY2022. The consolidated statements of cash flows shows capital expenditures and net cash paid for acquisitions, but the acquisition amount is listed as $0 for both FY2023 and FY2022.
# </answer>
#  <answer> SG&A expense as a percent of net sales decreased in FY2023 primarily due to:
#
# 1) Lower marketing expenses
# 2) Leverage of incentive compensation due to higher sales
# 3) Partially offset by deleverage of corporate overhead from strategic investments and deleverage of store payroll/benefits from wage investments
#
# </answer>
#  <answer>
# Ulta Beauty's merchandise inventories balance increased by $104.2 million at the end of FY2023 compared to FY2022. This was primarily driven by:
#
# - Opening of 47 new stores since January 29, 2022
# - Inventory to support new brand launches and brand expansions
# - Inventory cost increases
#
# </answer>
#  <answer> 36.4% </answer>
#  <answer> No, wages expense as a percent of net sales did not increase in FY2023 for Ulta Beauty. The text states that SG&A expenses as a percentage of net sales decreased to 23.5% in FY2022 from 23.9% in FY2021. This was partially offset by deleverage of store payroll and benefits due to wage investments. But overall, SG&A expenses decreased as a percentage of net sales, suggesting wages expense did not increase relative to net sales. </answer>
#  <answer> Cross currency swaps with a notional value of $32,502 million </answer>
#  <answer> $862.00 </answer>
#  <answer> Yes, Verizon has a reasonably healthy liquidity profile based on its quick ratio of 0.75 for FY 2022. The quick ratio measures a company's ability to use its most liquid assets to pay off its current liabilities. Verizon's quick ratio is calculated by taking its cash and cash equivalents ($2,605 million) plus accounts receivable, net ($24,506 million) for total quick assets of $27,111 million, divided by total current liabilities of $50,171 million. While a ratio closer to 1 is preferable, Verizon's quick ratio of 0.75 indicates it has sufficient liquid assets to cover the majority of its short-term debt obligations. The quick ratio is a relevant measure of liquidity for Verizon. </answer>
#  <answer> Yes. Verizon can be considered a capital intensive business based on the high net value of its Property, Plant and Equipment (PP&E), which stood at $107.4 billion in FY 2022. This represents about 28% of its total assets. The high investment in PP&E is essential for Verizon to build and maintain its extensive communications network infrastructure. </answer>
#  <answer> Yes. Verizon's total debt has decreased from $150.9B in 2021 to $150.6B in 2022. </answer>
#  <answer> 30.83 </answer>
#
# To calculate DPO, the formula is:
# DPO = 365 * (Average AP between FY2017 and FY2018) / (FY2018 COGS + Change in Inventory between FY2017 and FY2018)
#
# Average AP between FY2017 and FY2018 = (FY2018 AP + FY2017 AP) / 2
#                   = (46,092 + 41,433) / 2
#                   = $43,762 million
#
# FY2018 COGS = $373,396 million
#
# Change in Inventory between FY2017 and FY2018 = FY2018 Inventory - FY2017 Inventory
#                                                  = $43,783 million - $43,046 million
#                                                  = $737 million
#
# Plugging into the formula:
# DPO = 365 * $43,762 / ($373,396 + $737)
#      = 365 * $43,762 / $374,133
#      = 30.83
#
# Rounded to 2 decimal places is 30.83 days.
#  <answer> -0.5 </answer>
#  <answer> 3.0% </answer>
#
# To calculate the 3 year average unadjusted EBITDA % margin for Walmart:
#
# 1) Calculate unadjusted EBITDA for each year
# 2018 Unadjusted EBITDA = Operating income + Depreciation and amortization
#    = $20,437M + $10,529M
#    = $30,966M
#
# 2019 Unadjusted EBITDA = $21,957M + $10,678M
#    = $32,635M
#
# 2020 Unadjusted EBITDA = $20,568M + $10,987M
#    = $31,555M
#
# 2) Calculate total revenue for each year
# 2018 Total Revenue = $500,343M
# 2019 Total Revenue = $514,405M
# 2020 Total Revenue = $523,964M
#
# 3) Calculate Unadjusted EBITDA % margin for each year
# 2018 Unadjusted EBITDA % margin = Unadjusted EBITDA / Total Revenue
#    = $30,966M / $500,343M
#    = 6.2%
#
# 2019 Unadjusted EBITDA % margin = $32,635M / $514,405M
#    = 6.3%
#
# 2020 Unadjusted EBITDA % margin = $31,555M / $523,964M
#    = 6.0%
#
# 4) Calculate 3 year average
# Sum of 2018, 2019 and 2020 margins = 6.2% + 6.3% + 6.0% = 18.5%
# Divide by 3 years = 18.5% / 3 = 3.0% (rounded to 1 decimal place)
#
# Therefore, the 3 year average unadjusted EBITDA % margin for Walmart is 3.0%

# %%
df.head()
# Out:
#          financebench_id     doc_name  \
# 0  financebench_id_03029  3M_2018_10K
# 1  financebench_id_04672  3M_2018_10K
# 2  financebench_id_00499  3M_2022_10K
# 3  financebench_id_01226  3M_2022_10K
# 4  financebench_id_01865  3M_2022_10K
#
#                                             doc_link  doc_period  \
# 0  https://investors.3m.com/financials/sec-filing...        2018
# 1  https://investors.3m.com/financials/sec-filing...        2018
# 2  https://investors.3m.com/financials/sec-filing...        2022
# 3  https://investors.3m.com/financials/sec-filing...        2022
# 4  https://investors.3m.com/financials/sec-filing...        2022
#
#        question_type                                           question  \
# 0  metrics-generated  What is the FY2018 capital expenditure amount ...
# 1  metrics-generated  Assume that you are a public equities analyst....
# 2    domain-relevant  Is 3M a capital-intensive business based on FY...
# 3    domain-relevant  What drove operating margin change as of FY202...
# 4    novel-generated  If we exclude the impact of M&A, which segment...
#
#                                               answer  \
# 0                                           $1577.00
# 1                                              $8.70
# 2  No, the company is managing its CAPEX and Fixe...
# 3  Operating Margin for 3M in FY2022 has decrease...
# 4   The consumer segment shrunk by 0.9% organically.
#
#                                        evidence_text page_number
# 0  Table of Contents \n3M Company and Subsidiarie...          60
# 1  Table of Contents \n3M Company and Subsidiarie...          58
# 2  3M Company and Subsidiaries\n Consolidated Sta...    48,50,52
# 3  SG&A, measured as a percent of sales, increase...          27
# 4  Worldwide Sales Change\nBy Business Segment Or...          25

# %%
pd.DataFrame({'question': df['question'], 'answer' : df['answer'], 'evidence_text' : df['evidence_text'], 'syntheses' : syntheses_with_10_labels}).to_csv('syntheses_10.csv',index=False)

# %%
pd.DataFrame({'question': df['question'], 'answer' : df['answer'], 'evidence_text' : df['evidence_text'], 'syntheses' : syntheses_with_20_labels}).to_csv('syntheses_20.csv',index=False)

# %%
pd.DataFrame({'question': df['question'], 'answer' : df['answer'], 'evidence_text' : df['evidence_text'], 'syntheses' : syntheses_with_labels[0]}).to_csv('syntheses_30.csv',index=False)

# %%
pd.DataFrame({'question': df['question'], 'answer' : df['answer'], 'evidence_text' : df['evidence_text'], 'syntheses' : syntheses_with_labels[1]}).to_csv('syntheses_40.csv',index=False)

# %%
pd.DataFrame({'question': df['question'], 'answer' : df['answer'], 'evidence_text' : df['evidence_text'], 'syntheses' : syntheses_with_labels[2]}).to_csv('syntheses_50.csv',index=False)
